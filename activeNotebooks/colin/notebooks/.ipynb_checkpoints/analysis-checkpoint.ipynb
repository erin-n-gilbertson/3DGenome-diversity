# %% [markdown]
# # Analysis

# %% [markdown]
# This notebook contains the code necessary to conduct all data analyses for the Pan 3D Genome project. I have organized this largely by order of appearance in the manuscript; however, a few sections may be out of order. Use the Table of Contents below to navigate to specific analyses.

# %% [markdown]
# Note that the genomic windows used to predict the 3D genome are in 0-based coordinates.

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# - [Load Packages and Main Dataframe](#loaddataframe)
# - [Data Description](#datadescription)
# - [Compare Cell Types](#comparecelltypes)
# - [Individually Driven Windows](#individuallydrivenwindows)
#     - [IDW In Silico Mutagenesis](#idwindividuallydrivenwindows)
# - [Doubleton and Quadrupleton Driven Windows](#doubleandquadruple)
# - [Lineage Comparison](#lineagecomparison)
# - [Divergent Windows](#divergentwindows)
#     - [In Silico Mutagenesis](#divergentwindowsinsilicomutagenesis)
#     - [Genes](#divergentwindowsgenes)
#     - [Differential Gene Expression](#divergentwindowsexpression)
# - [Sequence Divergence](#sequencedivergence)

# %% [markdown]
# ## Load Packages and Main Dataframe <a class = 'anchor' id = 'loaddataframe'></a>

# %% [markdown]
# Load all needed packages, change directories, and load the main dataframe (HFF) that we previously generated.

# %%
import json
import numpy as np
import pandas as pd
import pybedtools

from scipy.stats import fisher_exact
from scipy.stats import spearmanr

pd.options.display.max_columns = 100
pd.options.display.max_rows = 500

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from scipy.spatial.distance import pdist

# %%
import matplotlib.font_manager as font_manager
arial_path = '/wynton/home/capra/cbrand/miniconda3/envs/jupyter/fonts/Arial.ttf'
arial = font_manager.FontProperties(fname = arial_path)

# %%
cd ../../data
# Out:
# /wynton/group/capra/projects/pan_3d_genome/data

# %%
comparisons = pd.read_csv('dataframes/HFF_comparisons.txt', sep = '\t', header = 0)
comparisons.head(5)
# Out:
#           ind1    ind2 dyad_type    chr  window_start         window  \
# 0  Akwaya-Jean  Alfred   pte-ptt  chr10       1572864  chr10_1572864
# 1  Akwaya-Jean  Alfred   pte-ptt  chr10       2097152  chr10_2097152
# 2  Akwaya-Jean  Alfred   pte-ptt  chr10       2621440  chr10_2621440
# 3  Akwaya-Jean  Alfred   pte-ptt  chr10       3145728  chr10_3145728
# 4  Akwaya-Jean  Alfred   pte-ptt  chr10       3670016  chr10_3670016
#
#         mse  spearman  divergence  seq_diff
# 0  0.000168  0.987655    0.012345      2803
# 1  0.000481  0.969809    0.030191      2715
# 2  0.001675  0.996398    0.003602      2849
# 3  0.000323  0.997899    0.002101      2606
# 4  0.000143  0.996732    0.003268      2594

# %% [markdown]
# Double check that the frame is the size it should be.

# %%
len(comparisons)
# Out:
# 6669390

# %% [markdown]
# ## Data Description <a class = 'anchor' id = 'datadescription'></a>

# %% [markdown]
# Let's generate some basic statistics for this dataset before diving into specific analyses.

# %% [markdown]
# How many windows are there per chromosome?

# %%
comparisons.groupby(['chr','window']).size().to_frame('N')
# Out:
#                         N
# chr  window
# chr1 chr1_100139008  1540
#      chr1_100663296  1540
#      chr1_101187584  1540
#      chr1_101711872  1540
#      chr1_103284736  1540
# ...                   ...
# chrX chrX_94371840    630
#      chrX_94896128    630
#      chrX_95420416    630
#      chrX_99090432    630
#      chrX_99614720    630
#
# [4420 rows x 1 columns]

# %%
comparisons.groupby('chr').size().to_frame('N')
# Out:
#             N
# chr
# chr1   525140
# chr10  320320
# chr11  348040
# chr12  323400
# chr13  255640
# chr14  232540
# chr15  184800
# chr16  157080
# chr17  152460
# chr18  194040
# chr19  107800
# chr20  147840
# chr21   89320
# chr22   73920
# chr2A  249480
# chr2B  343420
# chr3   532840
# chr4   498960
# chr5   392700
# chr6   449680
# chr7   357280
# chr8   363440
# chr9   274120
# chrX    95130

# %% [markdown]
# Let's count the total number of dyads.

# %%
comparisons.groupby('dyad_type').size().to_frame('N').sort_values(by = 'N', ascending = False)
# Out:
#                  N
# dyad_type
# ppn-pt     1836440
# pts-ptt    1179439
# pts-ptv     661462
# ptt-ptv     623041
# pts         588889
# ptt         520585
# pte-pts     366187
# pte-ptt     344842
# pte-ptv     193615
# ppn         156855
# ptv         155194
# pte          42841

# %% [markdown]
# Let's add all the within chimpanzee comparisons together.

# %%
1179439+661462+623041+366187+344842+193615
# Out:
# 3368586

# %% [markdown]
# How many dyads comparisons are there for a single autosomal window?

# %%
comparisons[comparisons['window'] == 'chr1_1048576'].groupby('dyad_type').size().to_frame('N').sort_values(by = 'N', ascending = False)
# Out:
#              N
# dyad_type
# ppn-pt     423
# pts-ptt    272
# pts-ptv    153
# ptt-ptv    144
# pts        136
# ptt        120
# pte-pts     85
# pte-ptt     80
# pte-ptv     45
# ppn         36
# ptv         36
# pte         10

# %% [markdown]
# How many dyads comparisons are there for a single chrX window?

# %%
comparisons[comparisons['window'] == 'chrX_4718592'].groupby('dyad_type').size().to_frame('N').sort_values(by = 'N', ascending = False)
# Out:
#              N
# dyad_type
# ppn-pt     203
# pts-ptt    121
# pts         55
# pts-ptv     55
# ptt         55
# ptt-ptv     55
# pte-pts     22
# pte-ptt     22
# ppn         21
# pte-ptv     10
# ptv         10
# pte          1

# %% [markdown]
# Add the within chimpanzee comparisons again.

# %%
272+153+144+85+80+45
# Out:
# 779

# %% [markdown]
# What is the range of the divergence metric?

# %%
comparisons['divergence'].min()
# Out:
# 2.492599999737166e-07

# %%
comparisons['divergence'].max()
# Out:
# 0.873604563894

# %% [markdown]
# What does the 0 end of the distribution look like?

# %%
len(comparisons[comparisons['divergence'] < 0.01])
# Out:
# 5539567

# %%
5539567/6669390
# Out:
# 0.830595751635457

# %%
maxes = comparisons.groupby(['window'])['divergence'].max().to_frame('max').reset_index()
maxes
# Out:
#                window       max
# 0     chr10_100139008  0.128959
# 1     chr10_100663296  0.101497
# 2     chr10_101187584  0.033608
# 3     chr10_101711872  0.138848
# 4     chr10_102236160  0.031867
# ...               ...       ...
# 4415    chrX_94371840  0.076931
# 4416    chrX_94896128  0.044540
# 4417    chrX_95420416  0.002984
# 4418    chrX_99090432  0.030925
# 4419    chrX_99614720  0.027077
#
# [4420 rows x 2 columns]

# %%
len(maxes[maxes['max'] < 0.005])
# Out:
# 245

# %%
len(maxes[maxes['max'] < 0.01])
# Out:
# 874

# %%
comparisons.sort_values(by = 'divergence', ascending = True).head(10).reset_index()
# Out:
#      index   ind1    ind2 dyad_type    chr  window_start          window  \
# 0  1281542  Berta   Linda       ptv   chrX      63963136   chrX_63963136
# 1  2011332  Bosco   Clint       ptv  chr18      30408704  chr18_30408704
# 2  6211267   Maya   Washu       pts   chr4      77594624   chr4_77594624
# 3  6211263   Maya   Washu       pts   chr4      74448896   chr4_74448896
# 4  6211268   Maya   Washu       pts   chr4      78118912   chr4_78118912
# 5  1234648  Berta  Jimmie       ptv  chr18      30408704  chr18_30408704
# 6  6211265   Maya   Washu       pts   chr4      75497472   chr4_75497472
# 7  6211270   Maya   Washu       pts   chr4      79167488   chr4_79167488
# 8  6211269   Maya   Washu       pts   chr4      78643200   chr4_78643200
# 9  1156145  Berta   Bosco       ptv  chr18      30408704  chr18_30408704
#
#             mse  spearman    divergence  seq_diff
# 0  1.002406e-07  1.000000  2.492600e-07        28
# 1  1.512933e-07  1.000000  3.000030e-07        12
# 2  1.090777e-07  1.000000  4.526210e-07        11
# 3  2.951117e-07  0.999999  9.595860e-07        16
# 4  2.513768e-07  0.999999  1.000161e-06        16
# 5  5.041597e-07  0.999999  1.196607e-06        27
# 6  4.510030e-07  0.999998  1.994036e-06        21
# 7  6.245179e-07  0.999998  2.295157e-06        22
# 8  5.665585e-07  0.999997  2.748579e-06        14
# 9  2.477392e-06  0.999997  2.755416e-06        42

# %% [markdown]
# Let's take a peek at some of the very divergent windows. How many are very (>= 0.3) divergent?

# %%
len(comparisons[comparisons['divergence'] >= 0.25])
# Out:
# 8745

# %%
len(comparisons[comparisons['divergence'] >= 0.3])
# Out:
# 5251

# %%
len(comparisons[comparisons['divergence'] >= 0.3]['window'].unique())
# Out:
# 87

# %%
thing = comparisons[comparisons['divergence'] >= 0.3].groupby(['window']).size().to_frame()
thing
# Out:
#                    0
# window
# chr10_106954752    7
# chr10_19922944    16
# chr10_48758784     6
# chr10_52428800   108
# chr10_52953088    53
# chr11_20447232    28
# chr11_20971520    41
# chr12_126353408    2
# chr12_80216064     1
# chr13_43515904   107
# chr13_45613056   423
# chr13_49283072   108
# chr13_49807360   108
# chr13_70778880   260
# chr14_21495808    23
# chr14_22020096    41
# chr14_26738688    44
# chr14_27262976     2
# chr14_65536000     4
# chr14_66060288    27
# chr14_66584576     1
# chr15_74973184    13
# chr16_31981568    37
# chr16_49283072     3
# chr16_7864320     18
# chr18_46137344    30
# chr18_46661632    39
# chr18_58720256    19
# chr18_59244544    17
# chr19_49807360     7
# chr1_103284736    25
# chr1_152043520     3
# chr1_163577856    10
# chr1_168820736    55
# chr1_169345024    55
# chr1_169869312    37
# chr1_72351744     52
# chr2A_21495808   188
# chr2A_22020096   284
# chr2A_34078720    10
# chr2A_51904512    50
# chr2A_76021760    55
# chr3_1048576      47
# chr3_1572864      51
# chr3_2097152      55
# chr3_85983232     26
# chr4_101711872     1
# chr4_127401984    10
# chr4_135266304     8
# chr4_15728640     52
# chr4_169869312   103
# chr4_62390272    201
# chr4_68681728    358
# chr4_69206016     13
# chr4_82837504     55
# chr4_92798976      2
# chr5_11534336    326
# chr5_19922944      2
# chr5_27787264      3
# chr5_80740352      1
# chr5_94896128     30
# chr5_95420416     49
# chr6_142606336    46
# chr6_158859264    80
# chr6_50331648     20
# chr6_90177536    188
# chr7_105906176    55
# chr7_111673344   227
# chr7_115867648    53
# chr7_128450560     1
# chr7_128974848    10
# chr7_143130624    16
# chr7_143654912    69
# chr7_84934656    156
# chr7_8912896       8
# chr8_111673344    16
# chr8_112197632    55
# chr8_128974848    55
# chr8_133693440     9
# chr8_34078720      1
# chr8_34603008     46
# chr8_35127296     62
# chr8_90177536      9
# chr9_10485760     10
# chrX_108527616    52
# chrX_120586240   175
# chrX_121110528    22

# %% [markdown]
# Explore the dataframe.

# %%
comparisons.sort_values(by = 'divergence', ascending = False).head(10).reset_index()
# Out:
#      index   ind1         ind2 dyad_type   chr  window_start          window  \
# 0  1239468  Berta   Julie-A959   ptt-ptv  chr1     169345024  chr1_169345024
# 1  1187032  Berta        Clint       ptv  chr1     169345024  chr1_169345024
# 2  1178192  Berta  Cindy-verus       ptv  chr1     169345024  chr1_169345024
# 3   475742  Alice        Berta       ptv  chr1     169345024  chr1_169345024
# 4  1235048  Berta       Jimmie       ptv  chr1     169345024  chr1_169345024
# 5  1252728  Berta         Koby       ptv  chr1     169345024  chr1_169345024
# 6  1318575  Berta     SeppToni       ptv  chr1     169345024  chr1_169345024
# 7  1278946  Berta        Linda       ptv  chr1     169345024  chr1_169345024
# 8  1156545  Berta        Bosco       ptv  chr1     169345024  chr1_169345024
# 9  1327264  Berta         Tibe   ptt-ptv  chr1     169345024  chr1_169345024
#
#         mse  spearman  divergence  seq_diff
# 0  0.029880  0.126395    0.873605      2419
# 1  0.027221  0.138562    0.861438       556
# 2  0.027594  0.138759    0.861241      1056
# 3  0.027315  0.140083    0.859917       844
# 4  0.027005  0.143166    0.856834       850
# 5  0.027171  0.144921    0.855079       855
# 6  0.026837  0.145195    0.854805       996
# 7  0.026589  0.148939    0.851061       933
# 8  0.026644  0.150587    0.849413       864
# 9  0.026827  0.162322    0.837678      2953

# %% [markdown]
# Get divergence scores for Figure 1C examples.

# %%
comparisons[(comparisons['window'] == 'chr4_77594624') & (comparisons['ind1'] == 'Maya') & (comparisons['ind2'] == 'Washu')]
# Out:
#          ind1   ind2 dyad_type   chr  window_start         window  \
# 6211267  Maya  Washu       pts  chr4      77594624  chr4_77594624
#
#                   mse  spearman    divergence  seq_diff
# 6211267  1.090777e-07       1.0  4.526210e-07        11

# %%
comparisons[(comparisons['window'] == 'chr18_46137344') & (comparisons['ind1'] == 'Julie-A959') & (comparisons['ind2'] == 'Vincent')]
# Out:
#                ind1     ind2 dyad_type    chr  window_start          window  \
# 5136420  Julie-A959  Vincent   pts-ptt  chr18      46137344  chr18_46137344
#
#               mse  spearman  divergence  seq_diff
# 5136420  0.020585  0.350611    0.649389      3049

# %% [markdown]
# ## Hierarchical Clustering

# %% [markdown]
# Run a script to generate trees per window, grab the cluster identity per individual, and catch the y-coordinates of the top four nodes in the tree.

# %%
complete_linkage_trees = pd.read_csv('dataframes/complete_linkage_clustering_per_window.txt', sep = '\t', header = None)

# %%
autosomal_complete_linkage_trees = complete_linkage_trees[~complete_linkage_trees[0].str.startswith('chrX_')]
chrX_complete_linkage_trees = complete_linkage_trees[complete_linkage_trees[0].str.startswith('chrX_')]

# %%
autosomal_trees_header = ['window','Akwaya-Jean','Alfred','Alice','Andromeda','Athanga','Berta','Bihati','Blanquita','Bono','Bosco','Brigitta','Bwamble','Cindy-schwein','Cindy-troglodytes','Cindy-verus','Cleo','Clint','Coco-chimp','Damian','Desmond','Doris','Dzeeta','Frederike','Gamin','Hermien','Hortense','Ikuru','Jimmie','Julie-A959','Julie-LWC21','Kidongo','Koby','Kombote','Kosana','Koto','Kumbuka','Lara','Linda','Luky','Marlin','Maya','Mgbadolite','Mirinda','Nakuu','Natalie','Negrita','SeppToni','Taweh','Tibe','Tongo','Trixie','Ula','Vaillant','Vincent','Washu','Yogui','node_0','node_1','node_2','node_3']
chrX_trees_header = ['window','Alice','Andromeda','Berta','Bihati','Blanquita','Cindy-schwein','Cindy-troglodytes','Cindy-verus','Cleo','Coco-chimp','Doris','Dzeeta','Frederike','Hermien','Hortense','Ikuru','Jimmie','Julie-A959','Julie-LWC21','Kidongo','Kombote','Kosana','Kumbuka','Lara','Linda','Luky','Marlin','Maya','Mirinda','Nakuu','Natalie','Negrita','Taweh','Tibe','Trixie','Ula','node_0','node_1','node_2','node_3']

autosomal_complete_linkage_trees.columns = autosomal_trees_header
chrX_complete_linkage_trees = chrX_complete_linkage_trees.dropna(axis = 1)
chrX_complete_linkage_trees.columns = chrX_trees_header

# %%
autosomal_complete_linkage_trees.head(5)
# Out:
#           window Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati  \
# 0  chr10_1572864          C3     C3    C3        C2      C2    C3     C3
# 1  chr10_2097152          C2     C2    C2        C2      C2    C2     C2
# 2  chr10_2621440          C2     C2    C2        C2      C2    C2     C2
# 3  chr10_3145728          C2     C2    C1        C2      C2    C2     C2
# 4  chr10_3670016          C2     C2    C2        C2      C2    C2     C2
#
#   Blanquita Bono Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes  \
# 0        C2   C1    C3       C3      C2            C2                C3
# 1        C2   C2    C2       C2      C2            C2                C1
# 2        C2   C2    C2       C2      C2            C2                C1
# 3        C2   C2    C2       C2      C2            C2                C2
# 4        C2   C1    C2       C2      C2            C2                C2
#
#   Cindy-verus Cleo Clint Coco-chimp Damian Desmond Doris Dzeeta Frederike  \
# 0          C3   C2    C3         C2     C3      C1    C2     C1        C3
# 1          C2   C2    C2         C2     C2      C2    C1     C2        C2
# 2          C2   C2    C2         C2     C2      C2    C1     C2        C2
# 3          C1   C2    C2         C2     C2      C2    C2     C2        C2
# 4          C2   C2    C2         C2     C2      C1    C2     C1        C2
#
#   Gamin Hermien Hortense Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby  \
# 0    C3      C1       C1    C3     C3         C3          C3      C2   C3
# 1    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 2    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 3    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 4    C2      C1       C1    C2     C2         C2          C2      C2   C2
#
#   Kombote Kosana Koto Kumbuka Lara Linda Luky Marlin Maya Mgbadolite Mirinda  \
# 0      C1     C1   C3      C1   C2    C3   C3     C3   C2         C2      C2
# 1      C2     C2   C2      C2   C2    C2   C1     C1   C2         C2      C2
# 2      C2     C2   C2      C2   C2    C2   C1     C1   C2         C2      C2
# 3      C2     C2   C2      C2   C2    C2   C1     C2   C2         C2      C2
# 4      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2      C2
#
#   Nakuu Natalie Negrita SeppToni Taweh Tibe Tongo Trixie Ula Vaillant Vincent  \
# 0    C2      C1      C2       C3    C3   C3    C2     C2  C3       C3      C2
# 1    C2      C2      C2       C2    C2   C2    C2     C2  C2       C2      C2
# 2    C2      C2      C2       C2    C2   C2    C2     C2  C2       C2      C2
# 3    C2      C2      C2       C2    C2   C2    C2     C2  C2       C2      C2
# 4    C2      C1      C2       C2    C2   C2    C2     C2  C2       C2      C2
#
#   Washu Yogui    node_0    node_1    node_2    node_3
# 0    C2    C2  0.014522  0.091748  0.091748  0.067514
# 1    C2    C2  0.038838  0.269334  0.269334  0.115208
# 2    C2    C2  0.005674  0.012824  0.012824  0.006737
# 3    C2    C2  0.002904  0.010145  0.010145  0.006418
# 4    C2    C2  0.005140  0.096248  0.096248  0.048080

# %%
chrX_complete_linkage_trees.head(5)
# Out:
#              window Alice Andromeda Berta Bihati Blanquita Cindy-schwein  \
# 4269   chrX_4718592    C1        C2    C1     C2        C2            C2
# 4270   chrX_5242880    C2        C2    C2     C2        C2            C2
# 4271   chrX_6815744    C1        C3    C3     C3        C3            C3
# 4272   chrX_9437184    C1        C1    C1     C1        C1            C1
# 4273  chrX_11010048    C2        C1    C2     C2        C2            C2
#
#      Cindy-troglodytes Cindy-verus Cleo Coco-chimp Doris Dzeeta Frederike  \
# 4269                C2          C2   C2         C2    C2     C2        C2
# 4270                C2          C2   C2         C2    C1     C2        C2
# 4271                C3          C3   C3         C3    C3     C3        C3
# 4272                C1          C1   C1         C1    C1     C1        C1
# 4273                C2          C2   C2         C2    C2     C2        C2
#
#      Hermien Hortense Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Kombote  \
# 4269      C2       C2    C2     C2         C2          C2      C2      C2
# 4270      C2       C2    C2     C2         C0          C2      C2      C2
# 4271      C3       C3    C3     C1         C3          C3      C3      C3
# 4272      C1       C1    C1     C1         C1          C1      C1      C1
# 4273      C2       C2    C2     C2         C2          C2      C2      C2
#
#      Kosana Kumbuka Lara Linda Luky Marlin Maya Mirinda Nakuu Natalie Negrita  \
# 4269     C2      C2   C2    C2   C2     C2   C2      C2    C2      C2      C2
# 4270     C2      C2   C2    C2   C1     C2   C2      C2    C2      C2      C2
# 4271     C2      C3   C3    C1   C3     C3   C3      C3    C3      C2      C3
# 4272     C1      C1   C1    C1   C0     C1   C1      C1    C1      C1      C1
# 4273     C2      C2   C2    C2   C2     C2   C1      C2    C2      C2      C2
#
#      Taweh Tibe Trixie Ula                 node_0              node_1  \
# 4269    C2   C2     C2  C2         0.000386870517  0.0942329238279999
# 4270    C2   C2     C2  C2                    0.0      0.018755481251
# 4271    C3   C3     C3  C3     0.0004348450219999  0.0176649495409999
# 4272    C1   C1     C1  C1                    0.0  0.0653681878299999
# 4273    C2   C2     C2  C2  7.667215399997929e-05      0.063108737967
#
#                   node_2              node_3
# 4269  0.0942329238279999  0.0244069347169999
# 4270      0.018755481251  0.0144252191229999
# 4271  0.0176649495409999      0.014919062537
# 4272  0.0653681878299999      0.020195340661
# 4273      0.063108737967  0.0414393167169999

# %% [markdown]
# Write a function that creates a cluster composition string. We will sort clusters by increasing size and delineate them by a '/'.

# %%
def generate_autosomal_clusters_lists(dataframe, window):
    row_index = dataframe[dataframe['window'] == window].index
    row = dataframe.loc[row_index,['Akwaya-Jean','Alfred','Alice','Andromeda','Athanga','Berta','Bihati','Blanquita','Bono','Bosco','Brigitta','Bwamble','Cindy-schwein','Cindy-troglodytes','Cindy-verus','Cleo','Clint','Coco-chimp','Damian','Desmond','Doris','Dzeeta','Frederike','Gamin','Hermien','Hortense','Ikuru','Jimmie','Julie-A959','Julie-LWC21','Kidongo','Koby','Kombote','Kosana','Koto','Kumbuka','Lara','Linda','Luky','Marlin','Maya','Mgbadolite','Mirinda','Nakuu','Natalie','Negrita','SeppToni','Taweh','Tibe','Tongo','Trixie','Ula','Vaillant','Vincent','Washu','Yogui']].values[0].tolist()
    cluster_values = sorted(list(set(row)))
    clusters_list = []
    single_clusters = 0
    
    for c in cluster_values:
        cluster_samples = dataframe.loc[row_index].apply(lambda row: row[row == c].index, axis = 1).values[0].tolist()
        if len(cluster_samples) == 1:
            single_clusters += 1
        cluster_samples = ' '.join(cluster_samples)
        clusters_list.append(cluster_samples)
    
    clusters_list.sort(key = len)
    cluster_composition = '/'.join(clusters_list)
    return len(clusters_list), cluster_composition, single_clusters

# %%
def generate_chrX_clusters_lists(dataframe, window):
    row_index = dataframe[dataframe['window'] == window].index
    row = dataframe.loc[row_index,['Alice','Andromeda','Berta','Bihati','Blanquita','Cindy-schwein','Cindy-troglodytes','Cindy-verus','Cleo','Coco-chimp','Doris','Dzeeta','Frederike','Hermien','Hortense','Ikuru','Jimmie','Julie-A959','Julie-LWC21','Kidongo','Kombote','Kosana','Kumbuka','Lara','Linda','Luky','Marlin','Maya','Mirinda','Nakuu','Natalie','Negrita','Taweh','Tibe','Trixie','Ula']].values[0].tolist()
    cluster_values = sorted(list(set(row)))
    clusters_list = []
    single_clusters = 0
    
    for c in cluster_values:
        cluster_samples = dataframe.loc[row_index].apply(lambda row: row[row == c].index, axis = 1).values[0].tolist()
        if len(cluster_samples) == 1:
            single_clusters += 1
        cluster_samples = ' '.join(cluster_samples)
        clusters_list.append(cluster_samples)
    
    clusters_list.sort(key = len)
    cluster_composition = '/'.join(clusters_list)
    return len(clusters_list), cluster_composition, single_clusters

# %%
autosomal_complete_linkage_trees[['n_clusters','cluster_composition','single_clusters']] = pd.DataFrame(autosomal_complete_linkage_trees.apply(lambda row: generate_autosomal_clusters_lists(autosomal_complete_linkage_trees, row['window']), axis=1).tolist(), index=autosomal_complete_linkage_trees.index)
# Out:
# /scratch/cbrand/ipykernel_34378/2577967575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autosomal_complete_linkage_trees[['n_clusters','cluster_composition','single_clusters']] = pd.DataFrame(autosomal_complete_linkage_trees.apply(lambda row: generate_autosomal_clusters_lists(autosomal_complete_linkage_trees, row['window']), axis=1).tolist(), index=autosomal_complete_linkage_trees.index)
# /scratch/cbrand/ipykernel_34378/2577967575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autosomal_complete_linkage_trees[['n_clusters','cluster_composition','single_clusters']] = pd.DataFrame(autosomal_complete_linkage_trees.apply(lambda row: generate_autosomal_clusters_lists(autosomal_complete_linkage_trees, row['window']), axis=1).tolist(), index=autosomal_complete_linkage_trees.index)
# /scratch/cbrand/ipykernel_34378/2577967575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autosomal_complete_linkage_trees[['n_clusters','cluster_composition','single_clusters']] = pd.DataFrame(autosomal_complete_linkage_trees.apply(lambda row: generate_autosomal_clusters_lists(autosomal_complete_linkage_trees, row['window']), axis=1).tolist(), index=autosomal_complete_linkage_trees.index)

# %%
autosomal_complete_linkage_trees.head(5)
# Out:
#           window Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati  \
# 0  chr10_1572864          C3     C3    C3        C2      C2    C3     C3
# 1  chr10_2097152          C2     C2    C2        C2      C2    C2     C2
# 2  chr10_2621440          C2     C2    C2        C2      C2    C2     C2
# 3  chr10_3145728          C2     C2    C1        C2      C2    C2     C2
# 4  chr10_3670016          C2     C2    C2        C2      C2    C2     C2
#
#   Blanquita Bono Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes  \
# 0        C2   C1    C3       C3      C2            C2                C3
# 1        C2   C2    C2       C2      C2            C2                C1
# 2        C2   C2    C2       C2      C2            C2                C1
# 3        C2   C2    C2       C2      C2            C2                C2
# 4        C2   C1    C2       C2      C2            C2                C2
#
#   Cindy-verus Cleo Clint Coco-chimp Damian Desmond Doris Dzeeta Frederike  \
# 0          C3   C2    C3         C2     C3      C1    C2     C1        C3
# 1          C2   C2    C2         C2     C2      C2    C1     C2        C2
# 2          C2   C2    C2         C2     C2      C2    C1     C2        C2
# 3          C1   C2    C2         C2     C2      C2    C2     C2        C2
# 4          C2   C2    C2         C2     C2      C1    C2     C1        C2
#
#   Gamin Hermien Hortense Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby  \
# 0    C3      C1       C1    C3     C3         C3          C3      C2   C3
# 1    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 2    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 3    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 4    C2      C1       C1    C2     C2         C2          C2      C2   C2
#
#   Kombote Kosana Koto Kumbuka Lara Linda Luky Marlin Maya Mgbadolite Mirinda  \
# 0      C1     C1   C3      C1   C2    C3   C3     C3   C2         C2      C2
# 1      C2     C2   C2      C2   C2    C2   C1     C1   C2         C2      C2
# 2      C2     C2   C2      C2   C2    C2   C1     C1   C2         C2      C2
# 3      C2     C2   C2      C2   C2    C2   C1     C2   C2         C2      C2
# 4      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2      C2
#
#   Nakuu Natalie Negrita SeppToni Taweh Tibe Tongo Trixie Ula Vaillant Vincent  \
# 0    C2      C1      C2       C3    C3   C3    C2     C2  C3       C3      C2
# 1    C2      C2      C2       C2    C2   C2    C2     C2  C2       C2      C2
# 2    C2      C2      C2       C2    C2   C2    C2     C2  C2       C2      C2
# 3    C2      C2      C2       C2    C2   C2    C2     C2  C2       C2      C2
# 4    C2      C1      C2       C2    C2   C2    C2     C2  C2       C2      C2
#
#   Washu Yogui    node_0    node_1    node_2    node_3  n_clusters  \
# 0    C2    C2  0.014522  0.091748  0.091748  0.067514           3
# 1    C2    C2  0.038838  0.269334  0.269334  0.115208           2
# 2    C2    C2  0.005674  0.012824  0.012824  0.006737           2
# 3    C2    C2  0.002904  0.010145  0.010145  0.006418           2
# 4    C2    C2  0.005140  0.096248  0.096248  0.048080           2
#
#                                  cluster_composition  single_clusters
# 0  Bono Desmond Dzeeta Hermien Hortense Kombote K...                0
# 1  Cindy-troglodytes Doris Luky Marlin/Akwaya-Jea...                0
# 2  Cindy-troglodytes Doris Luky Marlin/Akwaya-Jea...                0
# 3  Alice Cindy-verus Luky/Akwaya-Jean Alfred Andr...                0
# 4  Bono Desmond Dzeeta Hermien Hortense Kombote K...                0

# %%
chrX_complete_linkage_trees[['n_clusters','cluster_composition','single_clusters']]= pd.DataFrame(chrX_complete_linkage_trees.apply(lambda row: generate_chrX_clusters_lists(chrX_complete_linkage_trees, row['window']), axis=1).tolist(), index=chrX_complete_linkage_trees.index)

# %%
chrX_complete_linkage_trees.head(5)
# Out:
#              window Alice Andromeda Berta Bihati Blanquita Cindy-schwein  \
# 4269   chrX_4718592    C1        C2    C1     C2        C2            C2
# 4270   chrX_5242880    C2        C2    C2     C2        C2            C2
# 4271   chrX_6815744    C1        C3    C3     C3        C3            C3
# 4272   chrX_9437184    C1        C1    C1     C1        C1            C1
# 4273  chrX_11010048    C2        C1    C2     C2        C2            C2
#
#      Cindy-troglodytes Cindy-verus Cleo Coco-chimp Doris Dzeeta Frederike  \
# 4269                C2          C2   C2         C2    C2     C2        C2
# 4270                C2          C2   C2         C2    C1     C2        C2
# 4271                C3          C3   C3         C3    C3     C3        C3
# 4272                C1          C1   C1         C1    C1     C1        C1
# 4273                C2          C2   C2         C2    C2     C2        C2
#
#      Hermien Hortense Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Kombote  \
# 4269      C2       C2    C2     C2         C2          C2      C2      C2
# 4270      C2       C2    C2     C2         C0          C2      C2      C2
# 4271      C3       C3    C3     C1         C3          C3      C3      C3
# 4272      C1       C1    C1     C1         C1          C1      C1      C1
# 4273      C2       C2    C2     C2         C2          C2      C2      C2
#
#      Kosana Kumbuka Lara Linda Luky Marlin Maya Mirinda Nakuu Natalie Negrita  \
# 4269     C2      C2   C2    C2   C2     C2   C2      C2    C2      C2      C2
# 4270     C2      C2   C2    C2   C1     C2   C2      C2    C2      C2      C2
# 4271     C2      C3   C3    C1   C3     C3   C3      C3    C3      C2      C3
# 4272     C1      C1   C1    C1   C0     C1   C1      C1    C1      C1      C1
# 4273     C2      C2   C2    C2   C2     C2   C1      C2    C2      C2      C2
#
#      Taweh Tibe Trixie Ula                 node_0              node_1  \
# 4269    C2   C2     C2  C2         0.000386870517  0.0942329238279999
# 4270    C2   C2     C2  C2                    0.0      0.018755481251
# 4271    C3   C3     C3  C3     0.0004348450219999  0.0176649495409999
# 4272    C1   C1     C1  C1                    0.0  0.0653681878299999
# 4273    C2   C2     C2  C2  7.667215399997929e-05      0.063108737967
#
#                   node_2              node_3  n_clusters  \
# 4269  0.0942329238279999  0.0244069347169999           2
# 4270      0.018755481251  0.0144252191229999           3
# 4271  0.0176649495409999      0.014919062537           3
# 4272  0.0653681878299999      0.020195340661           2
# 4273      0.063108737967  0.0414393167169999           2
#
#                                     cluster_composition  single_clusters
# 4269  Alice Berta/Andromeda Bihati Blanquita Cindy-s...                0
# 4270  Julie-A959/Doris Luky/Alice Andromeda Berta Bi...                1
# 4271  Kosana Natalie/Alice Jimmie Linda/Andromeda Be...                0
# 4272  Luky/Alice Andromeda Berta Bihati Blanquita Ci...                1
# 4273  Andromeda Maya/Alice Berta Bihati Blanquita Ci...                0

# %% [markdown]
# Take a look at the number of clusters.

# %%
autosomal_complete_linkage_trees.groupby(['n_clusters'])['window'].count().to_frame('N')
# Out:
#                N
# n_clusters
# 2           3488
# 3            731
# 4             46
# 5              4

# %%
chrX_complete_linkage_trees.groupby(['n_clusters'])['window'].count().to_frame('N')
# Out:
#               N
# n_clusters
# 2           134
# 3            17

# %% [markdown]
# Let's get a table of unique cluster compositions for each set.

# %%
autosomal_complete_summary = autosomal_complete_linkage_trees.groupby(['cluster_composition'])['window'].count().to_frame('N')
chrX_complete_summary = chrX_complete_linkage_trees.groupby(['cluster_composition'])['window'].count().to_frame('N')

# %%
len(autosomal_complete_summary)
# Out:
# 2744

# %%
len(chrX_complete_summary)
# Out:
# 104

# %%
autosomal_complete_summary.sort_values(by = 'N', ascending = False).head(100)
# Out:
#                                                       N
# cluster_composition
# Bono Desmond Dzeeta Hermien Hortense Kombote Ko...  315
# Luky/Akwaya-Jean Alfred Alice Andromeda Athanga...   33
# Desmond/Akwaya-Jean Alfred Alice Andromeda Atha...   30
# Doris/Akwaya-Jean Alfred Alice Andromeda Athang...   29
# Marlin/Akwaya-Jean Alfred Alice Andromeda Athan...   29
# Koto/Akwaya-Jean Alfred Alice Andromeda Athanga...   21
# Alfred/Akwaya-Jean Alice Andromeda Athanga Bert...   21
# Hortense/Akwaya-Jean Alfred Alice Andromeda Ath...   20
# Cindy-troglodytes/Akwaya-Jean Alfred Alice Andr...   20
# Lara/Akwaya-Jean Alfred Alice Andromeda Athanga...   19
# Yogui/Akwaya-Jean Alfred Alice Andromeda Athang...   19
# Gamin/Akwaya-Jean Alfred Alice Andromeda Athang...   18
# Tibe/Akwaya-Jean Alfred Alice Andromeda Athanga...   18
# Kidongo/Akwaya-Jean Alfred Alice Andromeda Atha...   18
# Bono/Akwaya-Jean Alfred Alice Andromeda Athanga...   18
# Kombote/Akwaya-Jean Alfred Alice Andromeda Atha...   17
# Natalie/Akwaya-Jean Alfred Alice Andromeda Atha...   17
# Ula/Akwaya-Jean Alfred Alice Andromeda Athanga ...   17
# Akwaya-Jean/Alfred Alice Andromeda Athanga Bert...   16
# Damian/Akwaya-Jean Alfred Alice Andromeda Athan...   16
# Julie-A959/Akwaya-Jean Alfred Alice Andromeda A...   16
# Vaillant/Akwaya-Jean Alfred Alice Andromeda Ath...   16
# Blanquita/Akwaya-Jean Alfred Alice Andromeda At...   16
# Negrita/Akwaya-Jean Alfred Alice Andromeda Atha...   16
# Mirinda/Akwaya-Jean Alfred Alice Andromeda Atha...   15
# Julie-LWC21/Akwaya-Jean Alfred Alice Andromeda ...   14
# Kumbuka/Akwaya-Jean Alfred Alice Andromeda Atha...   13
# Athanga/Akwaya-Jean Alfred Alice Andromeda Bert...   13
# Tongo/Akwaya-Jean Alfred Alice Andromeda Athang...   13
# Kosana/Akwaya-Jean Alfred Alice Andromeda Athan...   12
# Andromeda/Akwaya-Jean Alfred Alice Athanga Bert...   12
# Brigitta/Akwaya-Jean Alfred Alice Andromeda Ath...   12
# Hermien/Akwaya-Jean Alfred Alice Andromeda Atha...   12
# Koby/Akwaya-Jean Alfred Alice Andromeda Athanga...   12
# Washu/Akwaya-Jean Alfred Alice Andromeda Athang...   12
# Dzeeta/Akwaya-Jean Alfred Alice Andromeda Athan...   12
# SeppToni/Akwaya-Jean Alfred Alice Andromeda Ath...   11
# Damian Taweh/Akwaya-Jean Alfred Alice Andromeda...   11
# Cleo/Akwaya-Jean Alfred Alice Andromeda Athanga...   11
# Trixie/Akwaya-Jean Alfred Alice Andromeda Athan...   11
# Jimmie/Akwaya-Jean Alfred Alice Andromeda Athan...   10
# Bwamble/Akwaya-Jean Alfred Alice Andromeda Atha...   10
# Ikuru/Akwaya-Jean Alfred Alice Andromeda Athang...    9
# Frederike/Akwaya-Jean Alfred Alice Andromeda At...    9
# Taweh/Akwaya-Jean Alfred Alice Andromeda Athang...    9
# Bono Desmond Hermien Hortense Kombote Kosana Ku...    9
# Desmond Kombote/Akwaya-Jean Alfred Alice Androm...    8
# Kosana Natalie/Akwaya-Jean Alfred Alice Androme...    8
# Maya/Akwaya-Jean Alfred Alice Andromeda Athanga...    8
# Alice Berta Bosco Cindy-verus Clint Jimmie Koby...    8
# Bihati/Akwaya-Jean Alfred Alice Andromeda Athan...    8
# Akwaya-Jean Koto/Alfred Alice Andromeda Athanga...    8
# Cindy-schwein/Akwaya-Jean Alfred Alice Andromed...    8
# Alice/Akwaya-Jean Alfred Andromeda Athanga Bert...    8
# Clint/Akwaya-Jean Alfred Alice Andromeda Athang...    7
# Damian Koto/Akwaya-Jean Alfred Alice Andromeda ...    7
# Cindy-verus/Akwaya-Jean Alfred Alice Andromeda ...    7
# Coco-chimp/Akwaya-Jean Alfred Alice Andromeda A...    7
# Bono Desmond Dzeeta Hermien Hortense Kombote Ku...    6
# Alfred Ula/Akwaya-Jean Alice Andromeda Athanga ...    6
# Brigitta Mirinda/Akwaya-Jean Alfred Alice Andro...    6
# Vincent/Akwaya-Jean Alfred Alice Andromeda Atha...    6
# Bosco/Akwaya-Jean Alfred Alice Andromeda Athang...    6
# Bono Desmond Dzeeta Hermien Hortense Kombote Ko...    5
# Bono Desmond Dzeeta Hortense Kombote Kosana Kum...    5
# Kumbuka Natalie/Akwaya-Jean Alfred Alice Androm...    5
# Nakuu/Akwaya-Jean Alfred Alice Andromeda Athang...    5
# Bono Dzeeta Hermien Hortense Kombote Kosana Kum...    5
# Berta/Akwaya-Jean Alfred Alice Andromeda Athang...    5
# Blanquita Ula/Akwaya-Jean Alfred Alice Andromed...    4
# Jimmie Linda/Akwaya-Jean Alfred Alice Andromeda...    4
# Koto Taweh/Akwaya-Jean Alfred Alice Andromeda A...    4
# Alice Berta Bosco Linda/Akwaya-Jean Alfred Andr...    4
# Akwaya-Jean Damian Taweh/Alfred Alice Andromeda...    4
# Cindy-schwein Trixie/Akwaya-Jean Alfred Alice A...    4
# Andromeda Vincent/Akwaya-Jean Alfred Alice Atha...    4
# Akwaya-Jean Julie-LWC21/Alfred Alice Andromeda ...    4
# Bono Desmond Dzeeta Gamin Hermien Hortense Komb...    4
# Bihati Mgbadolite/Akwaya-Jean Alfred Alice Andr...    4
# Bono Desmond Dzeeta Hermien Kombote Kosana Kumb...    4
# Brigitta Yogui/Akwaya-Jean Alfred Alice Androme...    4
# Alfred Luky/Akwaya-Jean Alice Andromeda Athanga...    4
# Dzeeta Hermien/Akwaya-Jean Alfred Alice Androme...    4
# Hortense Kumbuka/Akwaya-Jean Alfred Alice Andro...    4
# Bono Desmond Dzeeta Hermien Hortense Kombote Ko...    4
# Bono Desmond Doris Dzeeta Hermien Hortense Komb...    4
# Bono Desmond Dzeeta Hermien Hortense Kosana Kum...    3
# Koby Linda/Akwaya-Jean Alfred Alice Andromeda A...    3
# Alfred Doris/Akwaya-Jean Alice Andromeda Athang...    3
# Bono Damian Desmond Dzeeta Hermien Hortense Kom...    3
# Luky Mirinda/Akwaya-Jean Alfred Alice Andromeda...    3
# Bono Cleo Desmond Dzeeta Hermien Hortense Kombo...    3
# Bono Desmond Dzeeta Kombote Kosana Kumbuka Nata...    3
# Dzeeta Hortense Kombote/Akwaya-Jean Alfred Alic...    3
# Blanquita Tibe/Akwaya-Jean Alfred Alice Androme...    3
# Desmond Dzeeta Hermien Hortense Kombote Kumbuka...    3
# Damian Ula/Akwaya-Jean Alfred Alice Andromeda A...    3
# Bono Kombote/Akwaya-Jean Alfred Alice Andromeda...    3
# Bono Dzeeta Hermien Hortense Kosana Kumbuka Nat...    3
# Alice Jimmie/Akwaya-Jean Alfred Andromeda Athan...    3

# %% [markdown]
# Let's look for different types of clusters. Starting with individually driven windows.

# %%
len(autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['single_clusters'] == 1])
# Out:
# 1012

# %%
len(chrX_complete_linkage_trees[chrX_complete_linkage_trees['single_clusters'] == 1])
# Out:
# 35

# %% [markdown]
# What about windows with bonobo - chimpanzee clusters?

# %%
len(autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['cluster_composition'] == 'Bono Desmond Dzeeta Hermien Hortense Kombote Kosana Kumbuka Natalie/Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati Blanquita Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes Cindy-verus Cleo Clint Coco-chimp Damian Doris Frederike Gamin Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby Koto Lara Linda Luky Marlin Maya Mgbadolite Mirinda Nakuu Negrita SeppToni Taweh Tibe Tongo Trixie Ula Vaillant Vincent Washu Yogui'])
# Out:
# 315

# %%
len(chrX_complete_linkage_trees[chrX_complete_linkage_trees['cluster_composition'] == 'Dzeeta Hermien Hortense Kombote Kosana Kumbuka Natalie/Alice Andromeda Berta Bihati Blanquita Cindy-schwein Cindy-troglodytes Cindy-verus Cleo Coco-chimp Doris Frederike Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Lara Linda Luky Marlin Maya Mirinda Nakuu Negrita Taweh Tibe Trixie Ula'])
# Out:
# 24

# %% [markdown]
# What about windows where one chimpanzee subspecies clusters separately?

# %% [markdown]
# Central chimpanzees?

# %%
len(autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['cluster_composition'] == 'Alfred Blanquita Brigitta Cindy-troglodytes Doris Gamin Julie_A959 Lara Luky Marlin Mirinda Negrita Tibe Ula Vaillant Yogui/Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati Blanquita Bono Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes Cindy-verus Cleo Clint Coco-chimp Damian Desmond Doris Dzeeta Frederike Gamin Hermien Hortense Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby Kombote Kosana Koto Kumbuka Lara Linda Luky Marlin Maya Mgbadolite Mirinda Nakuu Natalie Negrita SeppToni Taweh Tibe Tongo Trixie Ula Vaillant Vincent Washu Yogui'])
# Out:
# 0

# %%
len(chrX_complete_linkage_trees[chrX_complete_linkage_trees['cluster_composition'] == 'Blanquita Cindy-troglodytes Doris Julie_A959 Lara Luky Marlin Mirinda Negrita Tibe Ula/Alice Andromeda Berta Bihati Cindy-schwein Cindy-verus Cleo Coco-chimp Dzeeta Frederike Hermien Hortense Jimmie Julie-LWC21 Kidongo Kombote Kosana Kumbuka Linda Maya Nakuu Natalie Taweh Trixie'])
# Out:
# 0

# %% [markdown]
# Eastern chimpanzees?

# %%
len(autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['cluster_composition'] == 'Andromeda Athanga Bihati Cindy-schwein Cleo Coco-chimp Frederike Ikuru Kidongo Maya Mgbadolite Nakuu Tongo Trixie Vincent Washu/Akwaya-Jean Alfred Alice Berta Blanquita Bono Bosco Brigitta Cindy-troglodytes Cindy-verus Clint Damian Desmond Doris Dzeeta Gamin Hermien Hortense Jimmie Julie-A959 Julie-LWC21 Koby Kombote Kosana Koto Kumbuka Lara Linda Luky Marlin Mirinda Natalie Negrita SeppToni Taweh Tibe Ula Vaillant Yogui'])
# Out:
# 0

# %%
len(chrX_complete_linkage_trees[chrX_complete_linkage_trees['cluster_composition'] == 'Andromeda Bihati Cindy_schwein Cleo Coco-chimp Frederike Ikuru Kidongo Maya Nakuu Trixie/Alice Berta Blanquita Cindy-troglodytes Cindy-verus Doris Dzeeta Hermien Hortense Jimmie Julie-A959 Julie-LWC21 Kombote Kosana Kumbuka Lara Linda Luky Marlin Mirinda Natalie Negrita Taweh Tibe Ula'])
# Out:
# 0

# %% [markdown]
# Nigeria-Cameroon chimpanzees?

# %%
len(autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['cluster_composition'] == 'Akwaya-Jean Damian Julie-LWC21 Koto Taweh/Alfred Alice Andromeda Athanga Berta Bihati Blanquita Bono Bosco Brigitta Bwamble Cindy_schwein Cindy_troglodytes Cindy_verus Cleo Clint Coco_chimp Desmond Doris Dzeeta Frederike Gamin Hermien Hortense Ikuru Jimmie Julie-A959 Kidongo Koby Kombote Kosana Kumbuka Lara Linda Luky Marlin Maya Mgbadolite Mirinda Nakuu Natalie Negrita SeppToni Tibe Tongo Trixie Ula Vaillant Vincent Washu Yogui'])
# Out:
# 0

# %%
len(chrX_complete_linkage_trees[chrX_complete_linkage_trees['cluster_composition'] == 'Julie-LWC21/Alice Andromeda Berta Bihati Blanquita Bono Cindy_schwein Cindy_troglodytes Cindy_verus Cleo Coco_chimp Doris Dzeeta Frederike Hermien Hortense Ikuru Jimmie Kidongo Kombote Kosana Kumbuka Lara Linda Luky Marlin Maya Mirinda Nakuu Natalie Negrita Tibe Trixie Ula'])
# Out:
# 0

# %% [markdown]
# Western chimpanzees?

# %%
len(autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['cluster_composition'] == 'Alice Berta Bosco Cindy-verus Clint Jimmie Koby Linda SeppToni/Akwaya-Jean Alfred Andromeda Athanga Bihati Blanquita Bono Brigitta Bwamble Cindy-schwein Cindy-troglodytes Cleo Coco-chimp Damian Desmond Doris Dzeeta Frederike Gamin Hermien Hortense Ikuru Julie-A959 Julie-LWC21 Kidongo Kombote Kosana Koto Kumbuka Lara Luky Marlin Maya Mgbadolite Mirinda Nakuu Natalie Negrita Taweh Tibe Tongo Trixie Ula Vaillant Vincent Washu Yogui'])
# Out:
# 8

# %%
len(chrX_complete_linkage_trees[chrX_complete_linkage_trees['cluster_composition'] == 'Alice Berta Cindy-verus Jimmie Linda/Andromeda Bihati Blanquita Cindy-schwein Cindy-troglodytes Cleo Coco-chimp Doris Dzeeta Frederike Hermien Hortense Ikuru Julie-A959 Julie-LWC21 Kidongo Kombote Kosana Kumbuka Lara Luky Marlin Maya Mirinda Nakuu Natalie Negrita Taweh Tibe Trixie Ula'])
# Out:
# 0

# %% [markdown]
# Let's look at these eight windows.

# %%
autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['cluster_composition'] == 'Alice Berta Bosco Cindy-verus Clint Jimmie Koby Linda SeppToni/Akwaya-Jean Alfred Andromeda Athanga Bihati Blanquita Bono Brigitta Bwamble Cindy-schwein Cindy-troglodytes Cleo Coco-chimp Damian Desmond Doris Dzeeta Frederike Gamin Hermien Hortense Ikuru Julie-A959 Julie-LWC21 Kidongo Kombote Kosana Koto Kumbuka Lara Luky Marlin Maya Mgbadolite Mirinda Nakuu Natalie Negrita Taweh Tibe Tongo Trixie Ula Vaillant Vincent Washu Yogui']
# Out:
#               window Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati  \
# 998   chr15_28835840          C2     C2    C1        C2      C2    C1     C2
# 1020  chr15_40370176          C2     C2    C1        C2      C2    C1     C2
# 1798  chr1_210239488          C2     C2    C1        C2      C2    C1     C2
# 2708  chr3_169345024          C2     C2    C1        C2      C2    C1     C2
# 3153   chr5_44564480          C2     C2    C1        C2      C2    C1     C2
# 3154   chr5_45088768          C2     C2    C1        C2      C2    C1     C2
# 3425   chr6_52428800          C2     C2    C1        C2      C2    C1     C2
# 3426   chr6_52953088          C2     C2    C1        C2      C2    C1     C2
#
#      Blanquita Bono Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes  \
# 998         C2   C2    C1       C2      C2            C2                C2
# 1020        C2   C2    C1       C2      C2            C2                C2
# 1798        C2   C2    C1       C2      C2            C2                C2
# 2708        C2   C2    C1       C2      C2            C2                C2
# 3153        C2   C2    C1       C2      C2            C2                C2
# 3154        C2   C2    C1       C2      C2            C2                C2
# 3425        C2   C2    C1       C2      C2            C2                C2
# 3426        C2   C2    C1       C2      C2            C2                C2
#
#      Cindy-verus Cleo Clint Coco-chimp Damian Desmond Doris Dzeeta Frederike  \
# 998           C1   C2    C1         C2     C2      C2    C2     C2        C2
# 1020          C1   C2    C1         C2     C2      C2    C2     C2        C2
# 1798          C1   C2    C1         C2     C2      C2    C2     C2        C2
# 2708          C1   C2    C1         C2     C2      C2    C2     C2        C2
# 3153          C1   C2    C1         C2     C2      C2    C2     C2        C2
# 3154          C1   C2    C1         C2     C2      C2    C2     C2        C2
# 3425          C1   C2    C1         C2     C2      C2    C2     C2        C2
# 3426          C1   C2    C1         C2     C2      C2    C2     C2        C2
#
#      Gamin Hermien Hortense Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby  \
# 998     C2      C2       C2    C2     C1         C2          C2      C2   C1
# 1020    C2      C2       C2    C2     C1         C2          C2      C2   C1
# 1798    C2      C2       C2    C2     C1         C2          C2      C2   C1
# 2708    C2      C2       C2    C2     C1         C2          C2      C2   C1
# 3153    C2      C2       C2    C2     C1         C2          C2      C2   C1
# 3154    C2      C2       C2    C2     C1         C2          C2      C2   C1
# 3425    C2      C2       C2    C2     C1         C2          C2      C2   C1
# 3426    C2      C2       C2    C2     C1         C2          C2      C2   C1
#
#      Kombote Kosana Koto Kumbuka Lara Linda Luky Marlin Maya Mgbadolite  \
# 998       C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
# 1020      C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
# 1798      C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
# 2708      C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
# 3153      C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
# 3154      C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
# 3425      C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
# 3426      C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
#
#      Mirinda Nakuu Natalie Negrita SeppToni Taweh Tibe Tongo Trixie Ula  \
# 998       C2    C2      C2      C2       C1    C2   C2    C2     C2  C2
# 1020      C2    C2      C2      C2       C1    C2   C2    C2     C2  C2
# 1798      C2    C2      C2      C2       C1    C2   C2    C2     C2  C2
# 2708      C2    C2      C2      C2       C1    C2   C2    C2     C2  C2
# 3153      C2    C2      C2      C2       C1    C2   C2    C2     C2  C2
# 3154      C2    C2      C2      C2       C1    C2   C2    C2     C2  C2
# 3425      C2    C2      C2      C2       C1    C2   C2    C2     C2  C2
# 3426      C2    C2      C2      C2       C1    C2   C2    C2     C2  C2
#
#      Vaillant Vincent Washu Yogui    node_0    node_1    node_2    node_3  \
# 998        C2      C2    C2    C2  0.000993  0.007565  0.007565  0.004479
# 1020       C2      C2    C2    C2  0.002281  0.009507  0.009507  0.006044
# 1798       C2      C2    C2    C2  0.000710  0.019751  0.019751  0.013096
# 2708       C2      C2    C2    C2  0.002744  0.014599  0.014599  0.007954
# 3153       C2      C2    C2    C2  0.000428  0.011706  0.011706  0.004777
# 3154       C2      C2    C2    C2  0.000929  0.023077  0.023077  0.014528
# 3425       C2      C2    C2    C2  0.001113  0.009093  0.009093  0.003563
# 3426       C2      C2    C2    C2  0.006607  0.030093  0.030093  0.016993
#
#       n_clusters                                cluster_composition  \
# 998            2  Alice Berta Bosco Cindy-verus Clint Jimmie Kob...
# 1020           2  Alice Berta Bosco Cindy-verus Clint Jimmie Kob...
# 1798           2  Alice Berta Bosco Cindy-verus Clint Jimmie Kob...
# 2708           2  Alice Berta Bosco Cindy-verus Clint Jimmie Kob...
# 3153           2  Alice Berta Bosco Cindy-verus Clint Jimmie Kob...
# 3154           2  Alice Berta Bosco Cindy-verus Clint Jimmie Kob...
# 3425           2  Alice Berta Bosco Cindy-verus Clint Jimmie Kob...
# 3426           2  Alice Berta Bosco Cindy-verus Clint Jimmie Kob...
#
#       single_clusters
# 998                 0
# 1020                0
# 1798                0
# 2708                0
# 3153                0
# 3154                0
# 3425                0
# 3426                0

# %%
comparisons[comparisons['window'] == 'chr5_45088768'].sort_values(by = 'divergence', ascending = False).reset_index().head(100)
# Out:
#       index               ind1           ind2 dyad_type   chr  window_start  \
# 0   2625131      Cindy-schwein         Jimmie   pts-ptv  chr5      45088768
# 1   2642811      Cindy-schwein           Koby   pts-ptv  chr5      45088768
# 2   2669029      Cindy-schwein          Linda   pts-ptv  chr5      45088768
# 3   1170774              Berta  Cindy-schwein   pts-ptv  chr5      45088768
# 4   2577115      Cindy-schwein          Clint   pts-ptv  chr5      45088768
# 5   2568275      Cindy-schwein    Cindy-verus   pts-ptv  chr5      45088768
# 6   1996078              Bosco  Cindy-schwein   pts-ptv  chr5      45088768
# 7   2708658      Cindy-schwein       SeppToni   pts-ptv  chr5      45088768
# 8    507500              Alice  Cindy-schwein   pts-ptv  chr5      45088768
# 9   5407876               Koby           Maya   pts-ptv  chr5      45088768
# 10  4963378             Jimmie           Maya   pts-ptv  chr5      45088768
# 11  2269294           Brigitta           Koby   ptt-ptv  chr5      45088768
# 12  3180582               Cleo           Koby   pts-ptv  chr5      45088768
# 13  5941419              Linda           Maya   pts-ptv  chr5      45088768
# 14  5442028               Koby           Tibe   ptt-ptv  chr5      45088768
# 15  3045223        Cindy-verus           Maya   pts-ptv  chr5      45088768
# 16  1293628              Berta           Maya   pts-ptv  chr5      45088768
# 17  2664609      Cindy-schwein           Lara   pts-ptt  chr5      45088768
# 18  5454835               Koby            Ula   ptt-ptv  chr5      45088768
# 19  1987540              Bosco       Brigitta   ptt-ptv  chr5      45088768
# 20  2149762              Bosco           Tibe   ptt-ptv  chr5      45088768
# 21  2115610              Bosco           Maya   pts-ptv  chr5      45088768
# 22  5390800               Koby           Lara   ptt-ptv  chr5      45088768
# 23  5463373               Koby        Vincent   pts-ptv  chr5      45088768
# 24  2008885              Bosco           Cleo   pts-ptv  chr5      45088768
# 25  4674678           Hortense           Koby    ppn-pt  chr5      45088768
# 26  5373724               Koby        Kombote    ppn-pt  chr5      45088768
# 27  2717347      Cindy-schwein           Tibe   pts-ptt  chr5      45088768
# 28  4126818             Dzeeta           Koby    ppn-pt  chr5      45088768
# 29  1677756          Blanquita           Koby   ptt-ptv  chr5      45088768
# 30  5020234             Jimmie        Vincent   pts-ptv  chr5      45088768
# 31  3162902               Cleo         Jimmie   pts-ptv  chr5      45088768
# 32  3206800               Cleo          Linda   pts-ptv  chr5      45088768
# 33  5399338               Koby           Luky   ptt-ptv  chr5      45088768
# 34  2162569              Bosco            Ula   ptt-ptv  chr5      45088768
# 35  2098534              Bosco           Lara   ptt-ptv  chr5      45088768
# 36  5416414               Koby        Mirinda   ptt-ptv  chr5      45088768
# 37  5998275              Linda        Vincent   pts-ptv  chr5      45088768
# 38  2252218           Brigitta         Jimmie   ptt-ptv  chr5      45088768
# 39  3102079        Cindy-verus        Vincent   pts-ptv  chr5      45088768
# 40  5446297               Koby          Tongo   pts-ptv  chr5      45088768
# 41  4656998           Hortense         Jimmie    ppn-pt  chr5      45088768
# 42   361750             Alfred           Koby   ptt-ptv  chr5      45088768
# 43  3827274            Desmond           Koby    ppn-pt  chr5      45088768
# 44  4543437            Hermien           Koby    ppn-pt  chr5      45088768
# 45  2294908           Brigitta          Linda   ptt-ptv  chr5      45088768
# 46  2935629        Cindy-verus           Cleo   pts-ptv  chr5      45088768
# 47  1350484              Berta        Vincent   pts-ptv  chr5      45088768
# 48  1184034              Berta           Cleo   pts-ptv  chr5      45088768
# 49  5976477              Linda           Tibe   ptt-ptv  chr5      45088768
# 50  4998436             Jimmie           Tibe   ptt-ptv  chr5      45088768
# 51  2633971      Cindy-schwein    Julie-LWC21   pte-pts  chr5      45088768
# 52  5382262               Koby           Koto   pte-ptv  chr5      45088768
# 53  2826488  Cindy-troglodytes           Koby   ptt-ptv  chr5      45088768
# 54  2051575              Bosco       Hortense    ppn-pt  chr5      45088768
# 55  3387910              Clint           Maya   pts-ptv  chr5      45088768
# 56  2034499              Bosco         Dzeeta    ppn-pt  chr5      45088768
# 57  1880815               Bono           Koby    ppn-pt  chr5      45088768
# 58  4928169             Jimmie        Kombote    ppn-pt  chr5      45088768
# 59  2081458              Bosco        Kombote    ppn-pt  chr5      45088768
# 60  3080281        Cindy-verus           Tibe   ptt-ptv  chr5      45088768
# 61  5471911               Koby          Yogui   ptt-ptv  chr5      45088768
# 62   630354              Alice           Maya   pts-ptv  chr5      45088768
# 63  2171107              Bosco        Vincent   pts-ptv  chr5      45088768
# 64  3978048              Doris           Koby   ptt-ptv  chr5      45088768
# 65  2196721           Brigitta    Cindy-verus   ptt-ptv  chr5      45088768
# 66  2747683      Cindy-schwein          Yogui   pts-ptt  chr5      45088768
# 67  5429221               Koby        Negrita   ptt-ptv  chr5      45088768
# 68  5011545             Jimmie            Ula   ptt-ptv  chr5      45088768
# 69  1162236              Berta       Brigitta   ptt-ptv  chr5      45088768
# 70  6176777               Maya       SeppToni   pts-ptv  chr5      45088768
# 71  5989586              Linda            Ula   ptt-ptv  chr5      45088768
# 72  1581573          Blanquita          Bosco   ptt-ptv  chr5      45088768
# 73  5420683               Koby          Nakuu   pts-ptv  chr5      45088768
# 74  4109138             Dzeeta         Jimmie    ppn-pt  chr5      45088768
# 75  2107072              Bosco           Luky   ptt-ptv  chr5      45088768
# 76  5459104               Koby       Vaillant   ptt-ptv  chr5      45088768
# 77  4525757            Hermien         Jimmie    ppn-pt  chr5      45088768
# 78  4700896           Hortense          Linda    ppn-pt  chr5      45088768
# 79  1328686              Berta           Tibe   ptt-ptv  chr5      45088768
# 80  5493709            Kombote          Linda    ppn-pt  chr5      45088768
# 81  1038133            Athanga           Koby   pts-ptv  chr5      45088768
# 82  5041881         Julie-A959           Koby   ptt-ptv  chr5      45088768
# 83  1468163             Bihati           Koby   pts-ptv  chr5      45088768
# 84  3810198            Desmond         Jimmie    ppn-pt  chr5      45088768
# 85  1703974          Blanquita          Linda   ptt-ptv  chr5      45088768
# 86  4271168          Frederike           Koby   pts-ptv  chr5      45088768
# 87  2124148              Bosco        Mirinda   ptt-ptv  chr5      45088768
# 88  1660076          Blanquita         Jimmie   ptt-ptv  chr5      45088768
# 89  4153036             Dzeeta          Linda    ppn-pt  chr5      45088768
# 90  3093390        Cindy-verus            Ula   ptt-ptv  chr5      45088768
# 91  4954538             Jimmie           Luky   ptt-ptv  chr5      45088768
# 92  5412145               Koby     Mgbadolite   pts-ptv  chr5      45088768
# 93  5849656               Lara          Linda   ptt-ptv  chr5      45088768
# 94  1341795              Berta            Ula   ptt-ptv  chr5      45088768
# 95  1227630              Berta       Hortense    ppn-pt  chr5      45088768
# 96  2179645              Bosco          Yogui   ptt-ptv  chr5      45088768
# 97  2154031              Bosco          Tongo   pts-ptv  chr5      45088768
# 98  1603220          Blanquita    Cindy-verus   ptt-ptv  chr5      45088768
# 99  2047306              Bosco        Hermien    ppn-pt  chr5      45088768
#
#            window       mse  spearman  divergence  seq_diff
# 0   chr5_45088768  0.006429  0.976923    0.023077      2542
# 1   chr5_45088768  0.005925  0.978855    0.021145      2508
# 2   chr5_45088768  0.005712  0.979613    0.020387      2541
# 3   chr5_45088768  0.005739  0.979689    0.020311      2406
# 4   chr5_45088768  0.005707  0.980094    0.019906      2422
# 5   chr5_45088768  0.005575  0.980712    0.019288      2422
# 6   chr5_45088768  0.005390  0.980907    0.019093      2478
# 7   chr5_45088768  0.005406  0.980924    0.019076      2544
# 8   chr5_45088768  0.005299  0.981589    0.018411      2627
# 9   chr5_45088768  0.004663  0.984122    0.015878      2592
# 10  chr5_45088768  0.004489  0.984544    0.015456      2630
# 11  chr5_45088768  0.004728  0.984610    0.015390      2597
# 12  chr5_45088768  0.005502  0.984645    0.015355      2191
# 13  chr5_45088768  0.004531  0.984708    0.015292      2655
# 14  chr5_45088768  0.005013  0.984711    0.015289      2510
# 15  chr5_45088768  0.004520  0.984807    0.015193      2498
# 16  chr5_45088768  0.004332  0.985193    0.014807      2490
# 17  chr5_45088768  0.004646  0.985472    0.014528      2668
# 18  chr5_45088768  0.004969  0.985483    0.014517      2494
# 19  chr5_45088768  0.004526  0.985490    0.014510      2571
# 20  chr5_45088768  0.004823  0.985524    0.014476      2504
# 21  chr5_45088768  0.004253  0.985741    0.014259      2562
# 22  chr5_45088768  0.005062  0.985836    0.014164      2512
# 23  chr5_45088768  0.004283  0.985892    0.014108      2282
# 24  chr5_45088768  0.005193  0.985907    0.014093      2183
# 25  chr5_45088768  0.005048  0.985942    0.014058      3220
# 26  chr5_45088768  0.004928  0.985950    0.014050      3323
# 27  chr5_45088768  0.004313  0.986070    0.013930      2728
# 28  chr5_45088768  0.005171  0.986116    0.013884      3096
# 29  chr5_45088768  0.004484  0.986144    0.013856      2588
# 30  chr5_45088768  0.004180  0.986170    0.013830      2334
# 31  chr5_45088768  0.004776  0.986185    0.013815      2243
# 32  chr5_45088768  0.005100  0.986387    0.013613      2238
# 33  chr5_45088768  0.005047  0.986400    0.013600      2612
# 34  chr5_45088768  0.004748  0.986481    0.013519      2466
# 35  chr5_45088768  0.004915  0.986509    0.013491      2474
# 36  chr5_45088768  0.004797  0.986510    0.013490      2649
# 37  chr5_45088768  0.004109  0.986562    0.013438      2377
# 38  chr5_45088768  0.003987  0.986646    0.013354      2675
# 39  chr5_45088768  0.004114  0.986706    0.013294      2316
# 40  chr5_45088768  0.004453  0.986751    0.013249      2192
# 41  chr5_45088768  0.004489  0.986785    0.013215      3234
# 42  chr5_45088768  0.005212  0.986822    0.013178      2490
# 43  chr5_45088768  0.004944  0.986836    0.013164      3067
# 44  chr5_45088768  0.004631  0.986889    0.013111      3196
# 45  chr5_45088768  0.004219  0.986900    0.013100      2614
# 46  chr5_45088768  0.004856  0.986922    0.013078      2277
# 47  chr5_45088768  0.003972  0.986940    0.013060      2222
# 48  chr5_45088768  0.004628  0.986949    0.013051      2133
# 49  chr5_45088768  0.004526  0.986966    0.013034      2553
# 50  chr5_45088768  0.004142  0.986987    0.013013      2582
# 51  chr5_45088768  0.004061  0.986996    0.013004      2825
# 52  chr5_45088768  0.004545  0.987039    0.012961      1923
# 53  chr5_45088768  0.004842  0.987062    0.012938      2543
# 54  chr5_45088768  0.004777  0.987065    0.012935      3174
# 55  chr5_45088768  0.003943  0.987090    0.012910      2498
# 56  chr5_45088768  0.004937  0.987115    0.012885      3050
# 57  chr5_45088768  0.004699  0.987122    0.012878      2919
# 58  chr5_45088768  0.004298  0.987124    0.012876      3343
# 59  chr5_45088768  0.004649  0.987136    0.012864      3275
# 60  chr5_45088768  0.004338  0.987147    0.012853      2570
# 61  chr5_45088768  0.003419  0.987170    0.012830      2535
# 62  chr5_45088768  0.003906  0.987177    0.012823      2693
# 63  chr5_45088768  0.003954  0.987201    0.012799      2264
# 64  chr5_45088768  0.005270  0.987217    0.012783      2639
# 65  chr5_45088768  0.004048  0.987252    0.012748      2667
# 66  chr5_45088768  0.003439  0.987258    0.012742      2539
# 67  chr5_45088768  0.004449  0.987279    0.012721      2582
# 68  chr5_45088768  0.004172  0.987285    0.012715      2552
# 69  chr5_45088768  0.003872  0.987360    0.012640      2491
# 70  chr5_45088768  0.003908  0.987378    0.012622      2652
# 71  chr5_45088768  0.004549  0.987380    0.012620      2505
# 72  chr5_45088768  0.004179  0.987385    0.012615      2562
# 73  chr5_45088768  0.004222  0.987410    0.012590      2314
# 74  chr5_45088768  0.004482  0.987425    0.012575      3108
# 75  chr5_45088768  0.004784  0.987449    0.012551      2602
# 76  chr5_45088768  0.004458  0.987463    0.012537      2636
# 77  chr5_45088768  0.004179  0.987505    0.012495      3216
# 78  chr5_45088768  0.004674  0.987512    0.012488      3243
# 79  chr5_45088768  0.004083  0.987512    0.012488      2418
# 80  chr5_45088768  0.004565  0.987517    0.012483      3356
# 81  chr5_45088768  0.004480  0.987541    0.012459      2189
# 82  chr5_45088768  0.004047  0.987547    0.012453      2307
# 83  chr5_45088768  0.004722  0.987560    0.012440      2208
# 84  chr5_45088768  0.004400  0.987605    0.012395      3081
# 85  chr5_45088768  0.004158  0.987620    0.012380      2615
# 86  chr5_45088768  0.004287  0.987635    0.012365      2269
# 87  chr5_45088768  0.004512  0.987656    0.012344      2601
# 88  chr5_45088768  0.003817  0.987717    0.012283      2642
# 89  chr5_45088768  0.004788  0.987749    0.012251      3127
# 90  chr5_45088768  0.004315  0.987753    0.012247      2476
# 91  chr5_45088768  0.004336  0.987808    0.012192      2650
# 92  chr5_45088768  0.004647  0.987847    0.012153      2233
# 93  chr5_45088768  0.004600  0.987866    0.012134      2489
# 94  chr5_45088768  0.004095  0.987871    0.012129      2460
# 95  chr5_45088768  0.004259  0.987883    0.012117      3122
# 96  chr5_45088768  0.003264  0.987906    0.012094      2523
# 97  chr5_45088768  0.004181  0.987907    0.012093      2168
# 98  chr5_45088768  0.003996  0.987929    0.012071      2674
# 99  chr5_45088768  0.004388  0.987929    0.012071      3154

# %% [markdown]
# Now let's look at the topologies for an entire chromosome.

# %%
autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['window'].str.startswith('chr21_')]
# Out:
#               window Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati  \
# 1915   chr21_1048576          C2     C2    C2        C2      C2    C2     C2
# 1916   chr21_1572864          C2     C2    C2        C2      C2    C2     C2
# 1917   chr21_2097152          C3     C1    C1        C2      C3    C1     C3
# 1918   chr21_2621440          C2     C2    C2        C2      C2    C2     C2
# 1919   chr21_3145728          C1     C1    C1        C1      C1    C1     C1
# 1920   chr21_3670016          C2     C2    C2        C2      C2    C2     C2
# 1921   chr21_4194304          C2     C2    C2        C2      C2    C2     C2
# 1922   chr21_4718592          C1     C1    C1        C1      C1    C1     C1
# 1923   chr21_5242880          C1     C1    C1        C1      C1    C1     C1
# 1924   chr21_5767168          C1     C1    C1        C1      C1    C1     C2
# 1925   chr21_6291456          C2     C2    C2        C2      C2    C2     C1
# 1926   chr21_6815744          C2     C2    C2        C2      C2    C2     C2
# 1927   chr21_7340032          C1     C1    C1        C1      C1    C1     C1
# 1928   chr21_7864320          C1     C1    C1        C1      C1    C1     C1
# 1929   chr21_8388608          C1     C1    C1        C1      C1    C1     C1
# 1930   chr21_8912896          C1     C1    C1        C1      C1    C1     C1
# 1931   chr21_9437184          C1     C1    C1        C1      C1    C1     C1
# 1932   chr21_9961472          C2     C2    C2        C2      C2    C2     C2
# 1933  chr21_10485760          C1     C1    C1        C1      C1    C1     C1
# 1934  chr21_11010048          C1     C1    C1        C1      C1    C1     C1
# 1935  chr21_11534336          C2     C2    C2        C2      C2    C2     C2
# 1936  chr21_12058624          C1     C1    C3        C3      C1    C3     C3
# 1937  chr21_12582912          C3     C1    C1        C3      C1    C1     C3
# 1938  chr21_13107200          C3     C3    C2        C3      C2    C2     C2
# 1939  chr21_13631488          C2     C2    C1        C2      C1    C1     C2
# 1940  chr21_14155776          C1     C2    C3        C2      C1    C2     C3
# 1941  chr21_14680064          C2     C2    C1        C2      C2    C1     C2
# 1942  chr21_15204352          C2     C2    C1        C2      C2    C1     C2
# 1943  chr21_15728640          C1     C1    C1        C2      C3    C1     C2
# 1944  chr21_16252928          C2     C2    C2        C2      C2    C2     C2
# 1945  chr21_16777216          C2     C1    C2        C1      C2    C2     C2
# 1946  chr21_17301504          C2     C2    C2        C2      C2    C2     C2
# 1947  chr21_18874368          C2     C2    C2        C1      C1    C2     C1
# 1948  chr21_19398656          C2     C2    C2        C2      C2    C2     C2
# 1949  chr21_19922944          C2     C2    C2        C2      C2    C2     C2
# 1950  chr21_20447232          C2     C2    C2        C2      C2    C2     C2
# 1951  chr21_20971520          C2     C2    C2        C2      C2    C2     C2
# 1952  chr21_21495808          C3     C3    C1        C3      C3    C1     C3
# 1953  chr21_22020096          C2     C3    C2        C3      C3    C2     C3
# 1954  chr21_22544384          C2     C2    C2        C2      C2    C2     C1
# 1955  chr21_23068672          C3     C3    C3        C3      C3    C3     C1
# 1956  chr21_23592960          C1     C2    C2        C2      C2    C2     C2
# 1957  chr21_24117248          C2     C2    C2        C2      C2    C2     C2
# 1958  chr21_24641536          C2     C2    C2        C2      C2    C2     C1
# 1959  chr21_25165824          C1     C1    C1        C1      C1    C1     C1
# 1960  chr21_25690112          C1     C1    C1        C1      C1    C1     C1
# 1961  chr21_26214400          C2     C2    C2        C2      C2    C2     C2
# 1962  chr21_26738688          C2     C2    C2        C2      C2    C2     C2
# 1963  chr21_27262976          C1     C2    C1        C2      C2    C1     C1
# 1964  chr21_27787264          C1     C1    C1        C1      C1    C1     C1
# 1965  chr21_28311552          C1     C1    C1        C1      C1    C1     C1
# 1966  chr21_28835840          C1     C1    C1        C1      C1    C1     C1
# 1967  chr21_29360128          C2     C2    C1        C1      C1    C1     C2
# 1968  chr21_29884416          C2     C2    C2        C2      C2    C2     C2
# 1969  chr21_30408704          C2     C2    C2        C2      C2    C2     C2
# 1970  chr21_30932992          C1     C1    C1        C1      C1    C1     C1
# 1971  chr21_31457280          C1     C1    C1        C1      C1    C1     C1
# 1972  chr21_31981568          C2     C2    C2        C2      C2    C2     C2
#
#      Blanquita Bono Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes  \
# 1915        C2   C2    C2       C2      C2            C2                C1
# 1916        C2   C2    C2       C2      C2            C2                C1
# 1917        C3   C3    C1       C1      C1            C3                C3
# 1918        C2   C1    C2       C2      C2            C2                C2
# 1919        C1   C1    C1       C1      C1            C1                C1
# 1920        C2   C1    C2       C2      C2            C2                C2
# 1921        C1   C2    C2       C2      C2            C2                C1
# 1922        C1   C1    C1       C1      C1            C1                C1
# 1923        C1   C1    C1       C1      C1            C1                C1
# 1924        C1   C1    C1       C1      C2            C1                C1
# 1925        C2   C2    C2       C2      C1            C2                C2
# 1926        C2   C1    C2       C2      C2            C2                C2
# 1927        C1   C1    C1       C1      C1            C1                C1
# 1928        C1   C1    C1       C1      C1            C1                C1
# 1929        C1   C1    C1       C1      C1            C1                C1
# 1930        C1   C1    C1       C1      C1            C1                C1
# 1931        C1   C1    C0       C1      C1            C1                C1
# 1932        C2   C1    C2       C2      C2            C2                C2
# 1933        C1   C1    C1       C1      C1            C1                C0
# 1934        C1   C1    C1       C1      C1            C1                C0
# 1935        C2   C1    C2       C2      C2            C2                C2
# 1936        C3   C2    C3       C1      C3            C3                C3
# 1937        C3   C1    C3       C3      C3            C3                C2
# 1938        C2   C3    C2       C2      C3            C3                C2
# 1939        C2   C2    C1       C1      C2            C2                C1
# 1940        C3   C2    C1       C3      C2            C2                C3
# 1941        C2   C2    C1       C2      C2            C2                C2
# 1942        C2   C2    C1       C2      C2            C2                C2
# 1943        C3   C2    C1       C3      C2            C2                C1
# 1944        C2   C2    C2       C2      C2            C2                C2
# 1945        C1   C1    C2       C1      C2            C1                C1
# 1946        C1   C1    C2       C2      C2            C2                C1
# 1947        C2   C2    C2       C1      C1            C1                C2
# 1948        C2   C1    C2       C2      C2            C2                C2
# 1949        C2   C1    C2       C2      C2            C2                C2
# 1950        C2   C1    C2       C2      C2            C2                C2
# 1951        C2   C2    C2       C1      C1            C1                C2
# 1952        C3   C2    C1       C3      C3            C3                C3
# 1953        C3   C3    C2       C3      C3            C3                C3
# 1954        C2   C2    C2       C2      C2            C2                C2
# 1955        C3   C2    C3       C3      C3            C3                C3
# 1956        C2   C1    C1       C2      C2            C2                C2
# 1957        C2   C1    C2       C2      C2            C2                C2
# 1958        C2   C1    C2       C2      C2            C2                C2
# 1959        C1   C1    C1       C1      C1            C1                C1
# 1960        C1   C1    C1       C1      C1            C1                C1
# 1961        C2   C2    C2       C2      C2            C2                C2
# 1962        C2   C2    C2       C2      C2            C2                C2
# 1963        C2   C2    C1       C2      C2            C2                C2
# 1964        C1   C2    C1       C1      C1            C1                C1
# 1965        C1   C1    C1       C1      C1            C1                C1
# 1966        C1   C1    C1       C1      C1            C1                C1
# 1967        C2   C1    C1       C1      C2            C2                C1
# 1968        C2   C2    C2       C2      C2            C2                C2
# 1969        C2   C2    C2       C2      C2            C2                C2
# 1970        C1   C1    C1       C1      C1            C1                C1
# 1971        C1   C1    C1       C1      C1            C1                C1
# 1972        C2   C1    C2       C2      C2            C2                C2
#
#      Cindy-verus Cleo Clint Coco-chimp Damian Desmond Doris Dzeeta Frederike  \
# 1915          C2   C2    C2         C2     C2      C2    C2     C2        C2
# 1916          C2   C2    C2         C2     C2      C2    C2     C2        C2
# 1917          C3   C2    C1         C2     C3      C3    C3     C3        C2
# 1918          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1919          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1920          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1921          C2   C2    C2         C2     C2      C2    C2     C2        C2
# 1922          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1923          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1924          C1   C1    C1         C1     C1      C1    C1     C1        C2
# 1925          C2   C2    C2         C2     C2      C2    C2     C2        C1
# 1926          C2   C2    C2         C2     C2      C2    C2     C1        C2
# 1927          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1928          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1929          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1930          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1931          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1932          C2   C2    C2         C2     C2      C1    C1     C1        C2
# 1933          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1934          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1935          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1936          C3   C3    C3         C1     C3      C2    C3     C2        C3
# 1937          C1   C3    C3         C3     C3      C1    C3     C1        C3
# 1938          C2   C3    C3         C3     C3      C3    C3     C3        C3
# 1939          C1   C2    C2         C2     C2      C2    C2     C2        C2
# 1940          C3   C2    C1         C3     C3      C2    C2     C2        C2
# 1941          C2   C2    C2         C2     C2      C2    C2     C2        C2
# 1942          C2   C2    C2         C2     C2      C2    C2     C2        C2
# 1943          C1   C3    C1         C2     C1      C2    C3     C2        C2
# 1944          C2   C1    C2         C2     C2      C2    C2     C2        C2
# 1945          C2   C2    C2         C2     C2      C2    C1     C1        C1
# 1946          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1947          C2   C1    C2         C2     C2      C2    C2     C2        C1
# 1948          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1949          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1950          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1951          C2   C2    C2         C2     C2      C2    C2     C2        C2
# 1952          C3   C3    C1         C3     C2      C2    C3     C2        C3
# 1953          C2   C3    C2         C3     C3      C3    C3     C3        C3
# 1954          C2   C1    C2         C1     C2      C2    C1     C2        C2
# 1955          C3   C1    C3         C3     C3      C2    C3     C2        C3
# 1956          C2   C2    C1         C2     C2      C2    C2     C2        C2
# 1957          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1958          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1959          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1960          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1961          C2   C2    C2         C2     C1      C2    C2     C2        C2
# 1962          C2   C2    C2         C2     C1      C2    C2     C2        C2
# 1963          C1   C1    C1         C2     C2      C2    C2     C2        C2
# 1964          C1   C1    C1         C1     C1      C2    C1     C2        C1
# 1965          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1966          C1   C1    C1         C1     C1      C1    C1     C1        C1
# 1967          C1   C1    C2         C2     C2      C1    C2     C1        C2
# 1968          C2   C2    C2         C2     C2      C2    C2     C2        C1
# 1969          C2   C2    C2         C2     C2      C2    C2     C2        C1
# 1970          C1   C1    C1         C1     C0      C1    C1     C1        C1
# 1971          C1   C1    C1         C1     C0      C1    C1     C1        C1
# 1972          C2   C2    C2         C2     C2      C2    C2     C2        C2
#
#      Gamin Hermien Hortense Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby  \
# 1915    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1916    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1917    C3      C3       C3    C2     C1         C2          C2      C2   C1
# 1918    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1919    C1      C1       C0    C1     C1         C1          C1      C1   C1
# 1920    C2      C2       C1    C2     C2         C2          C2      C2   C2
# 1921    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1922    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1923    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1924    C1      C1       C1    C1     C1         C2          C1      C1   C1
# 1925    C2      C2       C2    C2     C2         C1          C2      C2   C2
# 1926    C2      C2       C1    C2     C2         C2          C2      C2   C2
# 1927    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1928    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1929    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1930    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1931    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1932    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1933    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1934    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1935    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1936    C3      C2       C2    C3     C3         C1          C1      C3   C1
# 1937    C3      C1       C1    C3     C3         C3          C3      C3   C1
# 1938    C2      C3       C3    C2     C2         C3          C1      C2   C2
# 1939    C1      C2       C2    C1     C1         C2          C2      C2   C1
# 1940    C3      C2       C2    C3     C3         C2          C2      C3   C3
# 1941    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1942    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1943    C1      C2       C2    C2     C1         C3          C3      C2   C1
# 1944    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1945    C1      C2       C1    C1     C2         C2          C2      C2   C1
# 1946    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1947    C2      C2       C2    C1     C2         C2          C2      C1   C2
# 1948    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1949    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1950    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1951    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1952    C3      C2       C2    C3     C1         C3          C2      C3   C1
# 1953    C1      C3       C3    C3     C2         C1          C3      C3   C2
# 1954    C2      C2       C2    C1     C2         C2          C2      C1   C2
# 1955    C3      C2       C2    C3     C3         C3          C3      C3   C3
# 1956    C2      C2       C2    C2     C1         C2          C2      C2   C2
# 1957    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1958    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1959    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1960    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1961    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1962    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1963    C2      C2       C2    C2     C1         C1          C2      C2   C1
# 1964    C1      C2       C2    C1     C1         C1          C1      C1   C1
# 1965    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1966    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1967    C2      C1       C1    C1     C2         C2          C2      C1   C1
# 1968    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1969    C2      C2       C2    C2     C2         C2          C2      C2   C2
# 1970    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1971    C1      C1       C1    C1     C1         C1          C1      C1   C1
# 1972    C2      C2       C2    C2     C2         C2          C2      C2   C2
#
#      Kombote Kosana Koto Kumbuka Lara Linda Luky Marlin Maya Mgbadolite  \
# 1915      C2     C1   C2      C2   C2    C2   C2     C2   C2         C2
# 1916      C2     C1   C2      C2   C2    C2   C2     C2   C2         C2
# 1917      C3     C3   C3      C3   C2    C1   C3     C3   C1         C2
# 1918      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1919      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1920      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1921      C2     C2   C2      C2   C2    C2   C2     C2   C2         C2
# 1922      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1923      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1924      C1     C1   C1      C1   C1    C1   C0     C1   C1         C2
# 1925      C2     C2   C2      C2   C2    C2   C2     C2   C2         C1
# 1926      C1     C2   C2      C1   C2    C2   C2     C2   C2         C2
# 1927      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1928      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1929      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1930      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1931      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1932      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1933      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1934      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1935      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1936      C2     C2   C1      C2   C3    C3   C1     C3   C3         C1
# 1937      C1     C1   C1      C1   C3    C1   C1     C3   C3         C3
# 1938      C3     C3   C3      C3   C3    C2   C2     C3   C2         C2
# 1939      C2     C2   C2      C2   C2    C1   C2     C2   C1         C1
# 1940      C2     C2   C3      C2   C3    C3   C3     C3   C2         C1
# 1941      C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
# 1942      C2     C2   C2      C2   C2    C1   C2     C2   C2         C2
# 1943      C2     C2   C3      C2   C3    C1   C3     C3   C2         C2
# 1944      C2     C2   C2      C2   C2    C2   C2     C2   C2         C2
# 1945      C1     C1   C2      C1   C2    C2   C1     C1   C1         C2
# 1946      C1     C1   C2      C1   C2    C2   C1     C2   C2         C2
# 1947      C2     C2   C2      C2   C1    C2   C2     C1   C1         C1
# 1948      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1949      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1950      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1951      C2     C2   C2      C2   C2    C2   C2     C2   C2         C2
# 1952      C2     C3   C2      C2   C3    C1   C3     C3   C3         C3
# 1953      C3     C3   C3      C3   C3    C2   C3     C3   C3         C3
# 1954      C2     C2   C2      C2   C2    C2   C2     C2   C1         C1
# 1955      C2     C2   C3      C2   C1    C3   C1     C3   C1         C3
# 1956      C2     C2   C2      C2   C2    C2   C2     C2   C2         C2
# 1957      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1958      C1     C1   C1      C1   C2    C2   C2     C0   C2         C2
# 1959      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1960      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1961      C2     C2   C2      C2   C2    C2   C2     C2   C2         C2
# 1962      C2     C2   C2      C2   C2    C2   C2     C2   C2         C2
# 1963      C2     C2   C2      C2   C2    C1   C2     C1   C2         C2
# 1964      C2     C2   C1      C2   C1    C1   C1     C1   C1         C1
# 1965      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1966      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1967      C1     C1   C2      C1   C1    C1   C1     C2   C2         C2
# 1968      C2     C2   C2      C2   C2    C2   C2     C2   C1         C1
# 1969      C2     C2   C2      C2   C2    C2   C2     C2   C1         C1
# 1970      C1     C1   C1      C1   C1    C1   C1     C1   C1         C1
# 1971      C1     C1   C1      C0   C1    C1   C1     C1   C1         C1
# 1972      C2     C2   C2      C1   C2    C2   C2     C2   C2         C2
#
#      Mirinda Nakuu Natalie Negrita SeppToni Taweh Tibe Tongo Trixie Ula  \
# 1915      C2    C2      C2      C2       C2    C2   C2    C2     C2  C2
# 1916      C2    C2      C2      C2       C2    C2   C2    C2     C2  C2
# 1917      C3    C3      C3      C1       C1    C3   C1    C1     C2  C1
# 1918      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1919      C1    C1      C1      C1       C1    C1   C1    C1     C1  C1
# 1920      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1921      C2    C2      C2      C2       C2    C2   C2    C2     C2  C1
# 1922      C1    C1      C1      C1       C0    C1   C1    C1     C1  C1
# 1923      C1    C1      C1      C1       C0    C1   C1    C1     C1  C1
# 1924      C1    C1      C1      C1       C1    C1   C1    C2     C1  C1
# 1925      C2    C2      C2      C2       C2    C2   C2    C1     C2  C2
# 1926      C2    C2      C2      C2       C2    C2   C2    C2     C2  C2
# 1927      C1    C1      C0      C1       C1    C1   C1    C1     C1  C1
# 1928      C1    C1      C0      C1       C1    C1   C1    C1     C1  C1
# 1929      C1    C1      C1      C1       C1    C1   C1    C1     C1  C1
# 1930      C1    C1      C1      C1       C1    C1   C1    C1     C1  C1
# 1931      C1    C1      C1      C1       C1    C1   C1    C1     C1  C1
# 1932      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1933      C1    C1      C1      C1       C1    C1   C1    C1     C1  C1
# 1934      C1    C1      C1      C1       C1    C1   C1    C1     C1  C1
# 1935      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1936      C3    C3      C2      C3       C3    C3   C3    C3     C3  C1
# 1937      C2    C3      C1      C3       C3    C1   C3    C1     C3  C1
# 1938      C2    C3      C3      C2       C2    C2   C1    C3     C3  C2
# 1939      C2    C2      C2      C2       C1    C2   C1    C2     C2  C1
# 1940      C2    C3      C2      C3       C2    C2   C3    C2     C2  C3
# 1941      C2    C2      C2      C2       C2    C2   C2    C2     C2  C2
# 1942      C2    C2      C2      C2       C2    C2   C2    C2     C2  C2
# 1943      C3    C3      C2      C1       C3    C1   C3    C2     C2  C3
# 1944      C2    C2      C2      C2       C2    C2   C2    C2     C2  C1
# 1945      C1    C2      C1      C1       C2    C2   C1    C2     C2  C1
# 1946      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1947      C2    C2      C2      C2       C2    C2   C2    C1     C1  C2
# 1948      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1949      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1950      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1951      C2    C2      C2      C2       C2    C2   C1    C1     C2  C2
# 1952      C3    C3      C2      C3       C1    C2   C3    C3     C3  C3
# 1953      C3    C3      C3      C3       C2    C3   C3    C3     C3  C3
# 1954      C2    C1      C2      C2       C2    C2   C2    C2     C1  C2
# 1955      C3    C3      C2      C1       C3    C3   C3    C3     C3  C3
# 1956      C2    C2      C2      C2       C2    C2   C2    C2     C2  C2
# 1957      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1958      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1959      C1    C1      C1      C0       C1    C1   C1    C1     C1  C1
# 1960      C1    C1      C1      C0       C1    C1   C1    C1     C1  C1
# 1961      C2    C2      C2      C2       C2    C1   C2    C2     C2  C2
# 1962      C2    C2      C2      C2       C2    C1   C2    C2     C2  C2
# 1963      C2    C2      C2      C2       C1    C2   C2    C1     C2  C2
# 1964      C1    C1      C2      C1       C1    C1   C1    C1     C1  C1
# 1965      C1    C1      C1      C0       C1    C1   C1    C1     C1  C1
# 1966      C1    C1      C1      C0       C1    C1   C1    C1     C1  C1
# 1967      C2    C2      C1      C2       C1    C1   C1    C1     C2  C2
# 1968      C2    C2      C2      C2       C2    C2   C2    C2     C1  C2
# 1969      C2    C2      C2      C2       C2    C2   C2    C2     C1  C2
# 1970      C1    C1      C1      C1       C1    C1   C1    C1     C1  C1
# 1971      C1    C1      C1      C1       C1    C1   C1    C1     C1  C1
# 1972      C2    C2      C2      C2       C2    C2   C2    C2     C2  C2
#
#      Vaillant Vincent Washu Yogui    node_0    node_1    node_2    node_3  \
# 1915       C2      C2    C2    C2  0.007273  0.101743  0.101743  0.018713
# 1916       C2      C2    C2    C2  0.009908  0.092433  0.092433  0.030027
# 1917       C3      C2    C3    C1  0.008533  0.016795  0.016795  0.013133
# 1918       C2      C2    C2    C2  0.001896  0.012374  0.012374  0.008402
# 1919       C1      C1    C1    C1  0.000000  0.058120  0.058120  0.038627
# 1920       C2      C2    C2    C2  0.005336  0.025069  0.025069  0.007850
# 1921       C2      C2    C2    C2  0.001153  0.017037  0.017037  0.009157
# 1922       C1      C1    C1    C1  0.000000  0.056423  0.056423  0.021865
# 1923       C1      C1    C1    C1  0.000000  0.119308  0.119308  0.041856
# 1924       C1      C2    C2    C1  0.049416  0.123899  0.123899  0.108459
# 1925       C2      C1    C1    C2  0.029523  0.155177  0.155177  0.064509
# 1926       C2      C2    C2    C2  0.002659  0.064121  0.064121  0.027898
# 1927       C1      C1    C1    C1  0.000000  0.075647  0.075647  0.026706
# 1928       C1      C1    C1    C1  0.000000  0.183761  0.183761  0.053167
# 1929       C0      C1    C1    C1  0.000000  0.142003  0.142003  0.023950
# 1930       C0      C1    C1    C1  0.000000  0.037891  0.037891  0.011049
# 1931       C1      C1    C1    C1  0.000000  0.025588  0.025588  0.004655
# 1932       C2      C2    C2    C2  0.022009  0.075191  0.075191  0.048403
# 1933       C1      C1    C1    C1  0.000000  0.143209  0.143209  0.067397
# 1934       C1      C1    C1    C1  0.000000  0.179972  0.179972  0.084036
# 1935       C2      C2    C2    C2  0.000866  0.006946  0.006946  0.004649
# 1936       C3      C3    C3    C3  0.004243  0.007764  0.007764  0.007669
# 1937       C3      C3    C3    C3  0.006425  0.009628  0.009628  0.007451
# 1938       C3      C2    C3    C2  0.001945  0.011701  0.011701  0.009078
# 1939       C2      C2    C2    C1  0.007718  0.030535  0.030535  0.016379
# 1940       C3      C1    C2    C2  0.002078  0.016118  0.016118  0.011492
# 1941       C2      C2    C2    C2  0.000191  0.052577  0.052577  0.013309
# 1942       C2      C2    C2    C2  0.000181  0.019700  0.019700  0.012599
# 1943       C2      C2    C2    C3  0.001821  0.004103  0.004103  0.003296
# 1944       C2      C2    C1    C2  0.004971  0.049261  0.049261  0.018393
# 1945       C2      C2    C2    C1  0.044758  0.105713  0.105713  0.046932
# 1946       C2      C2    C2    C2  0.004207  0.025882  0.025882  0.012505
# 1947       C2      C1    C1    C2  0.001572  0.006887  0.006887  0.003752
# 1948       C2      C2    C2    C2  0.003290  0.006391  0.006391  0.004359
# 1949       C2      C2    C2    C2  0.002029  0.024514  0.024514  0.005010
# 1950       C2      C2    C2    C2  0.002951  0.028111  0.028111  0.016831
# 1951       C2      C2    C2    C2  0.001637  0.010048  0.010048  0.005598
# 1952       C3      C3    C3    C3  0.007069  0.034957  0.034957  0.031945
# 1953       C3      C3    C3    C3  0.001332  0.004596  0.004596  0.003950
# 1954       C2      C2    C2    C2  0.001901  0.007092  0.007092  0.004085
# 1955       C3      C3    C3    C3  0.009465  0.018354  0.018354  0.016051
# 1956       C2      C1    C1    C2  0.002276  0.009771  0.009771  0.006670
# 1957       C2      C2    C2    C2  0.005625  0.034644  0.034644  0.011145
# 1958       C2      C2    C2    C2  0.000000  0.015595  0.015595  0.013081
# 1959       C1      C1    C1    C1  0.000000  0.009962  0.009962  0.003332
# 1960       C1      C1    C1    C1  0.000000  0.031645  0.031645  0.013932
# 1961       C2      C2    C2    C2  0.006477  0.032148  0.032148  0.022181
# 1962       C2      C2    C2    C2  0.000385  0.046547  0.046547  0.018381
# 1963       C2      C1    C1    C2  0.002623  0.008421  0.008421  0.005637
# 1964       C1      C1    C1    C1  0.021100  0.048625  0.048625  0.031750
# 1965       C1      C1    C1    C1  0.000000  0.055626  0.055626  0.029203
# 1966       C1      C1    C1    C1  0.000000  0.029190  0.029190  0.017642
# 1967       C2      C1    C1    C2  0.002349  0.004950  0.004950  0.002586
# 1968       C2      C2    C2    C2  0.001061  0.010507  0.010507  0.005920
# 1969       C2      C2    C2    C2  0.003379  0.019816  0.019816  0.007892
# 1970       C1      C1    C1    C1  0.000000  0.043778  0.043778  0.025046
# 1971       C1      C1    C1    C1  0.000000  0.028066  0.028066  0.020042
# 1972       C2      C2    C2    C2  0.001392  0.028204  0.028204  0.019390
#
#       n_clusters                                cluster_composition  \
# 1915           2  Cindy-troglodytes Kosana/Akwaya-Jean Alfred Al...
# 1916           2  Cindy-troglodytes Kosana/Akwaya-Jean Alfred Al...
# 1917           3  Andromeda Cleo Coco-chimp Frederike Ikuru Juli...
# 1918           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1919           2  Hortense/Akwaya-Jean Alfred Alice Andromeda At...
# 1920           2  Bono Desmond Dzeeta Hortense Kombote Kosana Ku...
# 1921           2  Blanquita Cindy-troglodytes Ula/Akwaya-Jean Al...
# 1922           2  SeppToni/Akwaya-Jean Alfred Alice Andromeda At...
# 1923           2  SeppToni/Akwaya-Jean Alfred Alice Andromeda At...
# 1924           3  Luky/Bihati Bwamble Frederike Julie-A959 Mgbad...
# 1925           2  Bihati Bwamble Frederike Julie-A959 Mgbadolite...
# 1926           2  Bono Dzeeta Hortense Kombote Kumbuka/Akwaya-Je...
# 1927           2  Natalie/Akwaya-Jean Alfred Alice Andromeda Ath...
# 1928           2  Natalie/Akwaya-Jean Alfred Alice Andromeda Ath...
# 1929           2  Vaillant/Akwaya-Jean Alfred Alice Andromeda At...
# 1930           2  Vaillant/Akwaya-Jean Alfred Alice Andromeda At...
# 1931           2  Bosco/Akwaya-Jean Alfred Alice Andromeda Athan...
# 1932           2  Bono Desmond Doris Dzeeta Hermien Hortense Kom...
# 1933           2  Cindy-troglodytes/Akwaya-Jean Alfred Alice And...
# 1934           2  Cindy-troglodytes/Akwaya-Jean Alfred Alice And...
# 1935           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1936           3  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1937           3  Cindy-troglodytes Mirinda/Alfred Alice Athanga...
# 1938           3  Julie-LWC21 Tibe/Alice Athanga Berta Bihati Bl...
# 1939           2  Alice Athanga Berta Bosco Brigitta Cindy-trogl...
# 1940           3  Akwaya-Jean Athanga Bosco Clint Mgbadolite Vin...
# 1941           2  Alice Berta Bosco Linda/Akwaya-Jean Alfred And...
# 1942           2  Alice Berta Bosco Linda/Akwaya-Jean Alfred And...
# 1943           3  Akwaya-Jean Alfred Alice Berta Bosco Cindy-tro...
# 1944           2  Cleo Ula Washu/Akwaya-Jean Alfred Alice Androm...
# 1945           2  Alfred Andromeda Blanquita Bono Brigitta Cindy...
# 1946           2  Blanquita Bono Cindy-troglodytes Desmond Dzeet...
# 1947           2  Andromeda Athanga Bihati Brigitta Bwamble Cind...
# 1948           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1949           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1950           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1951           2  Brigitta Bwamble Cindy-schwein Tibe Tongo/Akwa...
# 1952           3  Alice Berta Bosco Clint Jimmie Koby Linda Sepp...
# 1953           3  Gamin Julie-A959/Akwaya-Jean Alice Berta Bosco...
# 1954           2  Bihati Cleo Coco-chimp Doris Ikuru Kidongo May...
# 1955           3  Bihati Cleo Lara Luky Maya Negrita/Bono Desmon...
# 1956           2  Akwaya-Jean Bono Bosco Clint Jimmie Vincent Wa...
# 1957           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1958           3  Marlin/Bihati Bono Desmond Dzeeta Hermien Hort...
# 1959           2  Negrita/Akwaya-Jean Alfred Alice Andromeda Ath...
# 1960           2  Negrita/Akwaya-Jean Alfred Alice Andromeda Ath...
# 1961           2  Damian Taweh/Akwaya-Jean Alfred Alice Andromed...
# 1962           2  Damian Taweh/Akwaya-Jean Alfred Alice Andromed...
# 1963           2  Akwaya-Jean Alice Berta Bihati Bosco Cindy-ver...
# 1964           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1965           2  Negrita/Akwaya-Jean Alfred Alice Andromeda Ath...
# 1966           2  Negrita/Akwaya-Jean Alfred Alice Andromeda Ath...
# 1967           2  Akwaya-Jean Alfred Bihati Blanquita Bwamble Ci...
# 1968           2  Frederike Maya Mgbadolite Trixie/Akwaya-Jean A...
# 1969           2  Frederike Maya Mgbadolite Trixie/Akwaya-Jean A...
# 1970           2  Damian/Akwaya-Jean Alfred Alice Andromeda Atha...
# 1971           2  Damian Kumbuka/Akwaya-Jean Alfred Alice Androm...
# 1972           2  Bono Kumbuka/Akwaya-Jean Alfred Alice Andromed...
#
#       single_clusters
# 1915                0
# 1916                0
# 1917                0
# 1918                0
# 1919                1
# 1920                0
# 1921                0
# 1922                1
# 1923                1
# 1924                1
# 1925                0
# 1926                0
# 1927                1
# 1928                1
# 1929                1
# 1930                1
# 1931                1
# 1932                0
# 1933                1
# 1934                1
# 1935                0
# 1936                0
# 1937                0
# 1938                0
# 1939                0
# 1940                0
# 1941                0
# 1942                0
# 1943                0
# 1944                0
# 1945                0
# 1946                0
# 1947                0
# 1948                0
# 1949                0
# 1950                0
# 1951                0
# 1952                0
# 1953                0
# 1954                0
# 1955                0
# 1956                0
# 1957                0
# 1958                1
# 1959                1
# 1960                1
# 1961                0
# 1962                0
# 1963                0
# 1964                0
# 1965                1
# 1966                1
# 1967                0
# 1968                0
# 1969                0
# 1970                1
# 1971                0
# 1972                0

# %%
autosomal_complete_linkage_trees[(autosomal_complete_linkage_trees['window'].str.startswith('chr21_')) & (autosomal_complete_linkage_trees['cluster_composition'] == 'Bono Desmond Dzeeta Hermien Hortense Kombote Kosana Kumbuka Natalie/Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati Blanquita Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes Cindy-verus Cleo Clint Coco-chimp Damian Doris Frederike Gamin Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby Koto Lara Linda Luky Marlin Maya Mgbadolite Mirinda Nakuu Negrita SeppToni Taweh Tibe Tongo Trixie Ula Vaillant Vincent Washu Yogui')]
# Out:
#               window Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati  \
# 1918   chr21_2621440          C2     C2    C2        C2      C2    C2     C2
# 1935  chr21_11534336          C2     C2    C2        C2      C2    C2     C2
# 1948  chr21_19398656          C2     C2    C2        C2      C2    C2     C2
# 1949  chr21_19922944          C2     C2    C2        C2      C2    C2     C2
# 1950  chr21_20447232          C2     C2    C2        C2      C2    C2     C2
# 1957  chr21_24117248          C2     C2    C2        C2      C2    C2     C2
# 1964  chr21_27787264          C1     C1    C1        C1      C1    C1     C1
#
#      Blanquita Bono Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes  \
# 1918        C2   C1    C2       C2      C2            C2                C2
# 1935        C2   C1    C2       C2      C2            C2                C2
# 1948        C2   C1    C2       C2      C2            C2                C2
# 1949        C2   C1    C2       C2      C2            C2                C2
# 1950        C2   C1    C2       C2      C2            C2                C2
# 1957        C2   C1    C2       C2      C2            C2                C2
# 1964        C1   C2    C1       C1      C1            C1                C1
#
#      Cindy-verus Cleo Clint Coco-chimp Damian Desmond Doris Dzeeta Frederike  \
# 1918          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1935          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1948          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1949          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1950          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1957          C2   C2    C2         C2     C2      C1    C2     C1        C2
# 1964          C1   C1    C1         C1     C1      C2    C1     C2        C1
#
#      Gamin Hermien Hortense Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby  \
# 1918    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1935    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1948    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1949    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1950    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1957    C2      C1       C1    C2     C2         C2          C2      C2   C2
# 1964    C1      C2       C2    C1     C1         C1          C1      C1   C1
#
#      Kombote Kosana Koto Kumbuka Lara Linda Luky Marlin Maya Mgbadolite  \
# 1918      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1935      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1948      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1949      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1950      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1957      C1     C1   C2      C1   C2    C2   C2     C2   C2         C2
# 1964      C2     C2   C1      C2   C1    C1   C1     C1   C1         C1
#
#      Mirinda Nakuu Natalie Negrita SeppToni Taweh Tibe Tongo Trixie Ula  \
# 1918      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1935      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1948      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1949      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1950      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1957      C2    C2      C1      C2       C2    C2   C2    C2     C2  C2
# 1964      C1    C1      C2      C1       C1    C1   C1    C1     C1  C1
#
#      Vaillant Vincent Washu Yogui    node_0    node_1    node_2    node_3  \
# 1918       C2      C2    C2    C2  0.001896  0.012374  0.012374  0.008402
# 1935       C2      C2    C2    C2  0.000866  0.006946  0.006946  0.004649
# 1948       C2      C2    C2    C2  0.003290  0.006391  0.006391  0.004359
# 1949       C2      C2    C2    C2  0.002029  0.024514  0.024514  0.005010
# 1950       C2      C2    C2    C2  0.002951  0.028111  0.028111  0.016831
# 1957       C2      C2    C2    C2  0.005625  0.034644  0.034644  0.011145
# 1964       C1      C1    C1    C1  0.021100  0.048625  0.048625  0.031750
#
#       n_clusters                                cluster_composition  \
# 1918           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1935           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1948           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1949           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1950           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1957           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
# 1964           2  Bono Desmond Dzeeta Hermien Hortense Kombote K...
#
#       single_clusters
# 1918                0
# 1935                0
# 1948                0
# 1949                0
# 1950                0
# 1957                0
# 1964                0

# %% [markdown]
# ## TADs

# %%
TADs_header = ['chr','start','end','score','C3624_overlap','C3649_overlap','C3651_overlap','C40300_overlap']
TADs = pd.read_csv('annotations/panTro6_TADs.bed', sep = '\t', header = None, names = TADs_header)
TADs.head(5)
# Out:
#     chr    start      end     score  C3624_overlap  C3649_overlap  \
# 0  chr1   394452   543414  1.022634         150000         150000
# 1  chr1   553368   720938  0.825499              0         140000
# 2  chr1  1404000  2025870  1.463877         350000         520000
# 3  chr1  2426223  4649193  1.823161        2080000        1630000
# 4  chr1  2500179  3198029  1.480341         710000         260000
#
#    C3651_overlap  C40300_overlap
# 0         150000          150000
# 1         140000               0
# 2         520000          540000
# 3        2090000         2060000
# 4         710000          710000

# %%
len(TADs)
# Out:
# 7812

# %%
TADs.groupby(['chr'])['score'].count().to_frame('N')
# Out:
#                                N
# chr
# chr1                         737
# chr10                        405
# chr11                        408
# chr12                        389
# chr13                        265
# chr14                        279
# chr15                        264
# chr16                        216
# chr16_NW_019932886v1_random    4
# chr17                        221
# chr18                        260
# chr19                         84
# chr20                        198
# chr21                         91
# chr22                         93
# chr2A                        325
# chr2B                        433
# chr3                         668
# chr4                         515
# chr5                         448
# chr5_NW_019932883v1_random    14
# chr5_NW_019932884v1_random    24
# chr5_NW_019932885v1_random    22
# chr6                         526
# chr8                         434
# chr9                         328
# chrX                         161

# %%
TAD_lengths = TADs['end'] - TADs['start']
TAD_lengths
# Out:
# 0        148962
# 1        167570
# 2        621870
# 3       2222970
# 4        697850
#          ...
# 7807     681211
# 7808     157817
# 7809     269993
# 7810     219993
# 7811     197097
# Length: 7812, dtype: int64

# %%
TAD_lengths.mean()
# Out:
# 445882.1714029698

# %%
TAD_lengths.median()
# Out:
# 299426.0

# %%
TAD_lengths.mode()
# Out:
# 0    149998
# dtype: int64

# %%
import seaborn as sns

# %%
sns.kdeplot(np.array(TAD_lengths), bw=0.5)
# Out:
# /scratch/cbrand/ipykernel_34378/3651390979.py:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(np.array(TAD_lengths), bw=0.5)
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# Let's make a pybedtools BED file of our TADs.

# %%
TADs_BED = TADs[['chr','start','end']]
TADs_pbtBED = pybedtools.BedTool().from_dataframe(TADs_BED).sort()
TADs_pbtBED.head()
# Out:
# chr1	394452	543414
#  chr1	553368	720938
#  chr1	1404000	2025870
#  chr1	2426223	4649193
#  chr1	2500179	3198029
#  chr1	2510093	2734436
#  chr1	3258008	4074054
#  chr1	3268008	3387841
#  chr1	3448264	3736066
#  chr1	5186977	5364766

# %%
len(TADs_pbtBED)
# Out:
# 7812

# %% [markdown]
# Save this dataframe.

# %%
TADs_BED.to_csv('annotations/panTro6_TAD_coordinates.bed', sep = '\t', header = False, index = False)

# %% [markdown]
# ## Lineage Comparison <a class = 'anchor' id = 'lineagecomparison'></a>

# %% [markdown]
# Let's count the number of dyads.

# %%
comparisons.groupby('dyad_type').size().to_frame('N').sort_values(by = 'N', ascending = False)
# Out:
#                  N
# dyad_type
# ppn-pt     1836440
# pts-ptt    1179439
# pts-ptv     661462
# ptt-ptv     623041
# pts         588889
# ptt         520585
# pte-pts     366187
# pte-ptt     344842
# pte-ptv     193615
# ppn         156855
# ptv         155194
# pte          42841

# %%
1173727+658249+620017+364402+343162+192670
# Out:
# 3352227

# %% [markdown]
# Create a genome-wide average per dyad.

# %%
genome_wide_means = comparisons[['ind1','ind2','dyad_type','divergence']]
genome_wide_means = genome_wide_means.groupby(['ind1','ind2']).agg({'dyad_type':'first', 'divergence':'mean'}).reset_index()
genome_wide_means.head(5)
# Out:
#           ind1       ind2 dyad_type  divergence
# 0  Akwaya-Jean     Alfred   pte-ptt    0.007259
# 1  Akwaya-Jean      Alice   pte-ptv    0.005879
# 2  Akwaya-Jean  Andromeda   pte-pts    0.006831
# 3  Akwaya-Jean    Athanga   pte-pts    0.007520
# 4  Akwaya-Jean      Berta   pte-ptv    0.005879

# %%
genome_wide_means.groupby('dyad_type')['divergence'].median().to_frame('median')
# Out:
#              median
# dyad_type
# ppn        0.003276
# ppn-pt     0.011276
# pte        0.004634
# pte-pts    0.007169
# pte-ptt    0.007486
# pte-ptv    0.006095
# pts        0.005436
# pts-ptt    0.006962
# pts-ptv    0.007386
# ptt        0.006846
# ptt-ptv    0.007777
# ptv        0.002690

# %%
genome_wide_means['dyad_type'] = genome_wide_means['dyad_type'].replace({'pte-pts':'pt-pt', 'pte-ptt':'pt-pt', 'pte-ptv':'pt-pt', 'pts-ptt':'pt-pt', 'pts-ptv':'pt-pt', 'ptt-ptv':'pt-pt'})

# %%
genome_wide_means.groupby('dyad_type')['divergence'].median().to_frame('median')
# Out:
#              median
# dyad_type
# ppn        0.003276
# ppn-pt     0.011276
# pt-pt      0.007200
# pte        0.004634
# pts        0.005436
# ptt        0.006846
# ptv        0.002690

# %%
comparisons[(comparisons['window'] == 'chr2A_74973184') & (comparisons['ind1'] == 'Cleo') & (comparisons['ind2'] == 'Natalie')]
# Out:
#          ind1     ind2 dyad_type    chr  window_start          window  \
# 3236587  Cleo  Natalie    ppn-pt  chr2A      74973184  chr2A_74973184
#
#               mse  spearman  divergence  seq_diff
# 3236587  0.009087  0.960918    0.039082      4316

# %% [markdown]
# ## Bonobo-Chimpanzee Windows <a class = 'anchor' id = 'bonobochimpanzeewindows'></a>

# %% [markdown]
# Let's identify windows where there is evidence of 3d divergence between bonobos and chimpanzees. We will consider two sets of windows: 1) the bonobo-chimpanzee clusters from the hierarchical clustering and 2) the subset of those windows where all bonobo-chimpanzee dyads have greater divergence than all others (except bonobo-bonobo dyads). Hereafter, I'll refer to these as clustering and divergent windows, respectively.

# %% [markdown]
# Start with the bonobo-chimpanzee clusters.

# %%
ppn_pt_clustering_autosomal_windows = autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['cluster_composition'] == 'Bono Desmond Dzeeta Hermien Hortense Kombote Kosana Kumbuka Natalie/Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati Blanquita Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes Cindy-verus Cleo Clint Coco-chimp Damian Doris Frederike Gamin Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby Koto Lara Linda Luky Marlin Maya Mgbadolite Mirinda Nakuu Negrita SeppToni Taweh Tibe Tongo Trixie Ula Vaillant Vincent Washu Yogui']['window'].to_frame('window')
ppn_pt_clustering_autosomal_windows.head(5)
# Out:
#             window
# 4    chr10_3670016
# 5    chr10_4194304
# 34  chr10_23592960
# 43  chr10_28311552
# 48  chr10_30932992

# %%
ppn_pt_clustering_chrX_windows = chrX_complete_linkage_trees[chrX_complete_linkage_trees['cluster_composition'] == 'Dzeeta Hermien Hortense Kombote Kosana Kumbuka Natalie/Alice Andromeda Berta Bihati Blanquita Cindy-schwein Cindy-troglodytes Cindy-verus Cleo Coco-chimp Doris Frederike Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Lara Linda Luky Marlin Maya Mirinda Nakuu Negrita Taweh Tibe Trixie Ula']['window'].to_frame('window')
ppn_pt_clustering_chrX_windows.head(5)
# Out:
#              window
# 4280  chrX_14680064
# 4281  chrX_15204352
# 4284  chrX_20447232
# 4285  chrX_22020096
# 4287  chrX_24117248

# %%
ppn_pt_clustering_windows = pd.concat([ppn_pt_clustering_autosomal_windows, ppn_pt_clustering_chrX_windows], ignore_index = True)

# %%
ppn_pt_clustering_windows
# Out:
#               window
# 0      chr10_3670016
# 1      chr10_4194304
# 2     chr10_23592960
# 3     chr10_28311552
# 4     chr10_30932992
# 5     chr10_35651584
# 6     chr10_58720256
# 7     chr10_72876032
# 8     chr10_78118912
# 9     chr10_78643200
# 10    chr10_79167488
# 11    chr10_79691776
# 12    chr10_87031808
# 13    chr10_87556096
# 14    chr10_90701824
# 15    chr10_97517568
# 16   chr10_104333312
# 17   chr10_117440512
# 18   chr10_117964800
# 19   chr10_118489088
# 20    chr11_22544384
# 21    chr11_45613056
# 22    chr11_46137344
# 23    chr11_49807360
# 24    chr11_50331648
# 25    chr11_50855936
# 26    chr11_71303168
# 27    chr11_73924608
# 28    chr11_77070336
# 29    chr11_77594624
# 30    chr11_78118912
# 31    chr11_80740352
# 32    chr11_81264640
# 33    chr11_89128960
# 34   chr11_111149056
# 35   chr11_116916224
# 36   chr11_119537664
# 37    chr12_37748736
# 38    chr12_40894464
# 39    chr12_43515904
# 40    chr12_44040192
# 41    chr12_84934656
# 42   chr12_111673344
# 43   chr12_125829120
# 44     chr13_3145728
# 45     chr13_8912896
# 46    chr13_23592960
# 47    chr13_30408704
# 48    chr13_38797312
# 49    chr13_39321600
# 50    chr13_44564480
# 51    chr13_45088768
# 52    chr13_45613056
# 53    chr13_47185920
# 54    chr13_47710208
# 55    chr13_52428800
# 56    chr13_54001664
# 57    chr13_61341696
# 58    chr13_66584576
# 59    chr13_70778880
# 60    chr13_86507520
# 61     chr14_9437184
# 62    chr14_14155776
# 63    chr14_14680064
# 64    chr14_25690112
# 65    chr14_31981568
# 66    chr14_32505856
# 67    chr14_45088768
# 68    chr14_45613056
# 69    chr14_46661632
# 70    chr14_50331648
# 71    chr14_65011712
# 72    chr14_70778880
# 73    chr14_75497472
# 74    chr14_76021760
# 75     chr15_9437184
# 76    chr15_14680064
# 77    chr15_20447232
# 78    chr15_28311552
# 79    chr15_44040192
# 80    chr15_45088768
# 81    chr15_68681728
# 82    chr15_69206016
# 83    chr15_69730304
# 84    chr15_76546048
# 85    chr16_38797312
# 86    chr16_49283072
# 87    chr17_19398656
# 88    chr17_35651584
# 89    chr18_11010048
# 90    chr18_11534336
# 91    chr18_16252928
# 92    chr18_19922944
# 93    chr18_21495808
# 94    chr18_48758784
# 95    chr18_61865984
# 96    chr18_70254592
# 97    chr19_10485760
# 98    chr19_11010048
# 99    chr19_25690112
# 100   chr19_26214400
# 101   chr19_30932992
# 102   chr19_51380224
# 103     chr1_5242880
# 104    chr1_27262976
# 105    chr1_35651584
# 106    chr1_40370176
# 107    chr1_48758784
# 108    chr1_49283072
# 109    chr1_71827456
# 110    chr1_75497472
# 111    chr1_77594624
# 112    chr1_78118912
# 113    chr1_80216064
# 114    chr1_92274688
# 115   chr1_126353408
# 116   chr1_153092096
# 117   chr1_153616384
# 118   chr1_155189248
# 119   chr1_173015040
# 120   chr1_177733632
# 121   chr1_178257920
# 122   chr1_194510848
# 123   chr1_198705152
# 124   chr1_206569472
# 125   chr1_221249536
# 126    chr20_5242880
# 127   chr20_11534336
# 128   chr20_16777216
# 129   chr20_17301504
# 130   chr20_32505856
# 131   chr20_45088768
# 132   chr20_55050240
# 133   chr20_59768832
# 134    chr21_2621440
# 135   chr21_11534336
# 136   chr21_19398656
# 137   chr21_19922944
# 138   chr21_20447232
# 139   chr21_24117248
# 140   chr21_27787264
# 141   chr22_17825792
# 142   chr22_24641536
# 143    chr2A_1572864
# 144    chr2A_3670016
# 145    chr2A_9437184
# 146   chr2A_11534336
# 147   chr2A_24641536
# 148   chr2A_32505856
# 149   chr2A_44564480
# 150   chr2A_45088768
# 151   chr2A_46661632
# 152   chr2A_50331648
# 153   chr2A_58720256
# 154   chr2A_74973184
# 155   chr2A_82837504
# 156   chr2A_83361792
# 157   chr2A_91226112
# 158    chr2B_5767168
# 159    chr2B_6291456
# 160   chr2B_33030144
# 161   chr2B_42991616
# 162   chr2B_50331648
# 163   chr2B_70254592
# 164   chr2B_70778880
# 165   chr2B_73924608
# 166   chr2B_88080384
# 167   chr2B_89653248
# 168  chr2B_107479040
# 169  chr2B_108527616
# 170  chr2B_111149056
# 171  chr2B_113770496
# 172  chr2B_116916224
# 173  chr2B_118489088
# 174  chr2B_119013376
# 175  chr2B_119537664
# 176     chr3_7340032
# 177    chr3_20971520
# 178    chr3_45088768
# 179    chr3_47710208
# 180    chr3_60293120
# 181    chr3_65011712
# 182    chr3_66060288
# 183    chr3_77594624
# 184    chr3_79167488
# 185    chr3_82837504
# 186    chr3_85458944
# 187    chr3_88604672
# 188    chr3_90177536
# 189    chr3_92798976
# 190    chr3_93323264
# 191   chr3_103809024
# 192   chr3_104333312
# 193   chr3_112721920
# 194   chr3_122683392
# 195   chr3_126877696
# 196   chr3_137887744
# 197   chr3_144179200
# 198   chr3_144703488
# 199   chr3_179306496
# 200   chr3_193986560
# 201     chr4_5242880
# 202     chr4_5767168
# 203    chr4_10485760
# 204    chr4_17301504
# 205    chr4_20971520
# 206    chr4_32505856
# 207    chr4_49283072
# 208    chr4_61865984
# 209    chr4_62390272
# 210    chr4_62914560
# 211    chr4_63438848
# 212    chr4_82313216
# 213    chr4_88080384
# 214    chr4_88604672
# 215    chr4_89653248
# 216    chr4_94371840
# 217    chr4_96993280
# 218   chr4_108527616
# 219   chr4_113770496
# 220   chr4_122683392
# 221   chr4_133693440
# 222   chr4_134217728
# 223   chr4_148897792
# 224   chr4_155189248
# 225   chr4_171966464
# 226     chr5_1572864
# 227    chr5_16252928
# 228    chr5_20447232
# 229    chr5_34078720
# 230    chr5_35127296
# 231    chr5_40894464
# 232    chr5_41418752
# 233    chr5_44040192
# 234    chr5_55574528
# 235    chr5_61341696
# 236    chr5_81264640
# 237    chr5_90177536
# 238    chr5_98041856
# 239   chr5_128974848
# 240   chr5_145227776
# 241   chr5_145752064
# 242   chr5_146800640
# 243   chr5_149946368
# 244   chr5_150470656
# 245   chr5_150994944
# 246    chr6_26738688
# 247    chr6_27262976
# 248    chr6_27787264
# 249    chr6_55574528
# 250    chr6_63438848
# 251    chr6_63963136
# 252    chr6_69730304
# 253    chr6_96468992
# 254   chr6_106430464
# 255   chr6_106954752
# 256   chr6_113246208
# 257   chr6_113770496
# 258   chr6_114294784
# 259   chr6_115867648
# 260   chr6_130023424
# 261   chr6_143130624
# 262   chr6_144703488
# 263   chr6_145752064
# 264   chr6_149946368
# 265   chr6_150994944
# 266   chr6_153092096
# 267   chr6_159383552
# 268     chr7_2097152
# 269    chr7_14680064
# 270    chr7_15204352
# 271    chr7_20447232
# 272    chr7_24117248
# 273    chr7_34078720
# 274    chr7_40370176
# 275    chr7_44564480
# 276    chr7_54525952
# 277    chr7_83886080
# 278    chr7_84410368
# 279   chr7_133169152
# 280   chr7_137887744
# 281   chr7_138412032
# 282   chr7_138936320
# 283     chr8_5767168
# 284    chr8_25165824
# 285    chr8_33554432
# 286    chr8_34603008
# 287    chr8_39845888
# 288    chr8_63438848
# 289    chr8_64487424
# 290    chr8_65011712
# 291    chr8_86507520
# 292    chr8_87031808
# 293   chr8_104333312
# 294   chr8_113770496
# 295   chr8_134217728
# 296     chr9_3670016
# 297     chr9_7864320
# 298    chr9_13631488
# 299    chr9_20447232
# 300    chr9_20971520
# 301    chr9_36175872
# 302    chr9_36700160
# 303    chr9_60817408
# 304    chr9_62914560
# 305    chr9_70254592
# 306    chr9_78118912
# 307    chr9_81788928
# 308    chr9_87556096
# 309    chr9_88080384
# 310    chr9_91226112
# 311   chr9_100139008
# 312   chr9_100663296
# 313   chr9_104857600
# 314   chr9_105381888
# 315    chrX_14680064
# 316    chrX_15204352
# 317    chrX_20447232
# 318    chrX_22020096
# 319    chrX_24117248
# 320    chrX_31457280
# 321    chrX_31981568
# 322    chrX_45088768
# 323    chrX_49283072
# 324    chrX_72876032
# 325    chrX_87031808
# 326    chrX_94896128
# 327    chrX_99614720
# 328   chrX_100663296
# 329   chrX_105906176
# 330   chrX_106430464
# 331   chrX_108527616
# 332   chrX_109051904
# 333   chrX_116391936
# 334   chrX_119013376
# 335   chrX_120586240
# 336   chrX_121110528
# 337   chrX_132120576
# 338   chrX_141033472

# %%
len(ppn_pt_clustering_windows)
# Out:
# 339

# %% [markdown]
# Save these windows as a BED file.

# %%
ppn_pt_clustering_windows_BED = pd.DataFrame()
ppn_pt_clustering_windows_BED['window_split'] = ppn_pt_clustering_windows['window']
ppn_pt_clustering_windows_BED = ppn_pt_clustering_windows_BED['window_split'].str.split('_', expand=True)
ppn_pt_clustering_windows_BED.rename(columns = {0:'chr', 1:'window_start'}, inplace = True)
ppn_pt_clustering_windows_BED['window_start'] = ppn_pt_clustering_windows_BED['window_start'].astype(int)
ppn_pt_clustering_windows_BED['window_end'] = ppn_pt_clustering_windows_BED['window_start'] + 1048576
ppn_pt_clustering_windows_BED = ppn_pt_clustering_windows_BED.sort_values(by = 'chr')
ppn_pt_clustering_windows_BED.head(5)
# Out:
#       chr  window_start  window_end
# 103  chr1       5242880     6291456
# 124  chr1     206569472   207618048
# 123  chr1     198705152   199753728
# 122  chr1     194510848   195559424
# 121  chr1     178257920   179306496

# %%
ppn_pt_clustering_windows_BED.to_csv('clustering_windows/ppn_pt_clustering_windows.bed', sep = '\t', header = False, index = False)

# %% [markdown]
# Do any of these windows occur on chromosome 7? The Eres et al. 2019 TAD dataset did not include any TADs from chromosome 7.

# %%
ppn_pt_chr7_clustering_windows = ppn_pt_clustering_windows_BED[ppn_pt_clustering_windows_BED['chr'] == 'chr7']
ppn_pt_chr7_clustering_windows
# Out:
#       chr  window_start  window_end
# 276  chr7      54525952    55574528
# 282  chr7     138936320   139984896
# 280  chr7     137887744   138936320
# 279  chr7     133169152   134217728
# 278  chr7      84410368    85458944
# 277  chr7      83886080    84934656
# 275  chr7      44564480    45613056
# 281  chr7     138412032   139460608
# 273  chr7      34078720    35127296
# 272  chr7      24117248    25165824
# 271  chr7      20447232    21495808
# 270  chr7      15204352    16252928
# 269  chr7      14680064    15728640
# 268  chr7       2097152     3145728
# 274  chr7      40370176    41418752

# %% [markdown]
# Let's take a look at these windows and assess how many non-ppn-pt dyads have a higher divergence than the ppn-pt dyad with the lowest divergence per window. In other words, how well do the ppn-pt and non-ppn-pt distributions separate? We will not consider within bonobo variation.

# %%
def ppn_pt_dyad_separation_autosomes():
    
    counts_list = []
    
    for window in ppn_pt_clustering_autosomal_windows['window']:
        subset = comparisons[comparisons['window'] == window].sort_values(by = 'divergence', ascending = False).reset_index(drop = True)
        subset = subset[subset['dyad_type'] != 'ppn'].reset_index(drop = True)
        index = subset.index[subset['dyad_type'] == 'ppn-pt'][422]
        counts_list.append((index + 1) - 423)

    df = pd.DataFrame()
    df['window'] = ppn_pt_clustering_autosomal_windows['window']
    df['n_non_ppn_pt_dyads'] = counts_list
    return df

ppn_pt_dyad_separation_autosomes_df = ppn_pt_dyad_separation_autosomes()

# %%
def ppn_pt_dyad_separation_chrX():
    
    counts_list = []
    
    for window in ppn_pt_clustering_chrX_windows['window']:
        subset = comparisons[comparisons['window'] == window].sort_values(by = 'divergence', ascending = False).reset_index(drop = True)
        subset = subset[subset['dyad_type'] != 'ppn'].reset_index(drop = True)
        index = subset.index[subset['dyad_type'] == 'ppn-pt'][202]
        counts_list.append((index + 1) - 203)

    df = pd.DataFrame()
    df['window'] = ppn_pt_clustering_chrX_windows['window']
    df['n_non_ppn_pt_dyads'] = counts_list
    return df

ppn_pt_dyad_separation_chrX_df = ppn_pt_dyad_separation_chrX()

# %% [markdown]
# Merge these counts so that we can plot them in another notebook.

# %%
ppn_pt_dyad_separation_counts = pd.concat([ppn_pt_dyad_separation_autosomes_df, ppn_pt_dyad_separation_chrX_df])
ppn_pt_dyad_separation_counts.head(5)
# Out:
#             window  n_non_ppn_pt_dyads
# 4    chr10_3670016                 466
# 5    chr10_4194304                 527
# 34  chr10_23592960                 366
# 43  chr10_28311552                 866
# 48  chr10_30932992                  63

# %%
len(ppn_pt_dyad_separation_counts)
# Out:
# 339

# %%
ppn_pt_dyad_separation_counts.to_csv('dataframes/ppn_pt_dyad_separation_counts.txt', sep = '\t', header = False, index = False)

# %% [markdown]
# Now for the fully divergent subset. Let's write and apply a function.

# %%
def get_divergent_windows(target, ignored):
    subset = comparisons[~comparisons['dyad_type'].isin(ignored)]
    others_maxes = subset[~subset['dyad_type'].isin(target)].groupby(['window'])['divergence'].max().to_frame('max').reset_index()
    target_mins = subset[subset['dyad_type'].isin(target)].groupby(['window'])['divergence'].min().to_frame('min').reset_index()
    all_windows = pd.merge(others_maxes, target_mins, on = 'window')
    divergent_windows = all_windows[all_windows['min'] > all_windows['max']]
    
    return divergent_windows

# %%
ppn_pt_divergent_windows = get_divergent_windows(['ppn-pt'], ['ppn'])
ppn_pt_divergent_windows.head(65)
# Out:
#                window       max       min
# 180    chr10_87031808  0.002229  0.008621
# 181    chr10_87556096  0.004172  0.026767
# 389    chr11_77070336  0.014929  0.023994
# 390    chr11_77594624  0.018620  0.050357
# 547    chr12_44040192  0.039008  0.054170
# 683    chr13_30408704  0.004637  0.006264
# 711    chr13_45088768  0.025116  0.041128
# 712    chr13_45613056  0.022726  0.304855
# 716    chr13_47185920  0.027797  0.048146
# 746    chr13_61341696  0.006812  0.008538
# 850    chr14_32505856  0.008438  0.011372
# 876    chr14_45088768  0.004792  0.020095
# 877    chr14_45613056  0.010742  0.019686
# 938    chr14_75497472  0.004972  0.020010
# 1063   chr15_69206016  0.004109  0.009200
# 1080    chr15_9437184  0.003564  0.018129
# 1284   chr18_11010048  0.003375  0.004764
# 1285   chr18_11534336  0.007765  0.009006
# 1432   chr19_25690112  0.019410  0.029334
# 1433   chr19_26214400  0.014792  0.031516
# 1469   chr19_51380224  0.020150  0.038358
# 1508   chr1_126353408  0.014749  0.029323
# 1549   chr1_153092096  0.008637  0.013048
# 1550   chr1_153616384  0.007771  0.016506
# 1598   chr1_178257920  0.002564  0.003305
# 1933   chr21_19922944  0.005010  0.011285
# 2154   chr2A_74973184  0.012124  0.022455
# 2168   chr2A_82837504  0.043899  0.083284
# 2220  chr2B_116916224  0.006127  0.035112
# 2224  chr2B_119013376  0.011166  0.020651
# 2290   chr2B_42991616  0.006284  0.010204
# 2413   chr3_103809024  0.010280  0.014528
# 2414   chr3_104333312  0.010752  0.125485
# 2451   chr3_122683392  0.004188  0.010437
# 2489   chr3_144179200  0.017423  0.019147
# 2490   chr3_144703488  0.007761  0.040559
# 2688    chr3_66060288  0.004936  0.005914
# 2708    chr3_77594624  0.003047  0.005535
# 2733    chr3_90177536  0.001586  0.011794
# 2737    chr3_93323264  0.016031  0.017739
# 2947    chr4_32505856  0.024264  0.078218
# 3004    chr4_61865984  0.013093  0.051145
# 3005    chr4_62390272  0.129556  0.255510
# 3191    chr5_16252928  0.013600  0.024917
# 3518    chr6_46137344  0.010241  0.016445
# 3546    chr6_63438848  0.024432  0.035722
# 3547    chr6_63963136  0.022932  0.106935
# 3714    chr7_14680064  0.017236  0.038912
# 3722    chr7_15204352  0.016840  0.042102
# 3745    chr7_24117248  0.019860  0.035127
# 3830    chr7_83886080  0.022034  0.036591
# 3831    chr7_84410368  0.078849  0.108963
# 3920   chr8_134217728  0.004639  0.008453
# 4012     chr8_5767168  0.061594  0.067512
# 4091   chr9_100139008  0.013425  0.019218
# 4092   chr9_100663296  0.002735  0.009509
# 4102   chr9_104857600  0.011200  0.012055
# 4115    chr9_13631488  0.004581  0.004840
# 4205    chr9_62914560  0.008259  0.011466
# 4243    chr9_88080384  0.013683  0.027271
# 4330    chrX_15204352  0.009951  0.058026
# 4336    chrX_24117248  0.002424  0.005800
# 4349    chrX_31981568  0.006185  0.009131
# 4364    chrX_49283072  0.002632  0.003569
# 4419    chrX_99614720  0.006199  0.012607

# %%
len(ppn_pt_divergent_windows)
# Out:
# 65

# %% [markdown]
# Make a quick list of these windows and a dictionary from the maxes here using the window as the index. We'll need them later for identifying 3d-modifying variants.

# %%
ppn_pt_divergent_windows_list = ppn_pt_divergent_windows['window'].tolist()
ppn_pt_divergent_windows_chimp_maxes = pd.Series(ppn_pt_divergent_windows['max'].values, index = ppn_pt_divergent_windows['window']).to_dict()

# %% [markdown]
# Save the divergent windows as a BED file.

# %%
ppn_pt_divergent_windows_BED = pd.DataFrame()
ppn_pt_divergent_windows_BED['window_split'] = ppn_pt_divergent_windows['window']
ppn_pt_divergent_windows_BED = ppn_pt_divergent_windows_BED['window_split'].str.split('_', expand=True)
ppn_pt_divergent_windows_BED.rename(columns = {0:'chr', 1:'window_start'}, inplace = True)
ppn_pt_divergent_windows_BED['window_start'] = ppn_pt_divergent_windows_BED['window_start'].astype(int)
ppn_pt_divergent_windows_BED['window_end'] = ppn_pt_divergent_windows_BED['window_start'] + 1048576
ppn_pt_divergent_windows_BED = ppn_pt_divergent_windows_BED.sort_values(by = 'chr')
ppn_pt_divergent_windows_BED.head(5)
# Out:
#         chr  window_start  window_end
# 1508   chr1     126353408   127401984
# 1550   chr1     153616384   154664960
# 1598   chr1     178257920   179306496
# 1549   chr1     153092096   154140672
# 180   chr10      87031808    88080384

# %%
ppn_pt_divergent_windows_BED.to_csv('divergent_windows/ppn_pt_divergent_windows.bed', sep = '\t', header = False, index = False)

# %% [markdown]
# Check for chromosome 7 windows again.

# %%
ppn_pt_chr7_divergent_windows_BED = ppn_pt_divergent_windows_BED[ppn_pt_divergent_windows_BED['chr'] == 'chr7']
ppn_pt_chr7_divergent_windows_BED
# Out:
#        chr  window_start  window_end
# 3831  chr7      84410368    85458944
# 3745  chr7      24117248    25165824
# 3830  chr7      83886080    84934656
# 3714  chr7      14680064    15728640
# 3722  chr7      15204352    16252928

# %%
ppn_pt_divergent_windows['window'].isin(ppn_pt_clustering_windows['window'])
# Out:
# 180      True
# 181      True
# 389      True
# 390      True
# 547      True
# 683      True
# 711      True
# 712      True
# 716      True
# 746      True
# 850      True
# 876      True
# 877      True
# 938      True
# 1063     True
# 1080     True
# 1284     True
# 1285     True
# 1432     True
# 1433     True
# 1469     True
# 1508     True
# 1549     True
# 1550     True
# 1598     True
# 1933     True
# 2154     True
# 2168     True
# 2220     True
# 2224     True
# 2290     True
# 2413     True
# 2414     True
# 2451     True
# 2489     True
# 2490     True
# 2688     True
# 2708     True
# 2733     True
# 2737     True
# 2947     True
# 3004     True
# 3005     True
# 3191     True
# 3518    False
# 3546     True
# 3547     True
# 3714     True
# 3722     True
# 3745     True
# 3830     True
# 3831     True
# 3920     True
# 4012     True
# 4091     True
# 4092     True
# 4102     True
# 4115     True
# 4205     True
# 4243     True
# 4330     True
# 4336     True
# 4349     True
# 4364     True
# 4419     True
# Name: window, dtype: bool

# %%
ppn_pt_divergent_windows.loc[3518]
# Out:
# window    chr6_46137344
# max            0.010241
# min            0.016445
# Name: 3518, dtype: object

# %%
autosomal_complete_linkage_trees[autosomal_complete_linkage_trees['window'] == 'chr6_46137344']
# Out:
#              window Akwaya-Jean Alfred Alice Andromeda Athanga Berta Bihati  \
# 3413  chr6_46137344          C3     C3    C3        C3      C3    C3     C3
#
#      Blanquita Bono Bosco Brigitta Bwamble Cindy-schwein Cindy-troglodytes  \
# 3413        C3   C2    C3       C3      C3            C3                C3
#
#      Cindy-verus Cleo Clint Coco-chimp Damian Desmond Doris Dzeeta Frederike  \
# 3413          C3   C3    C3         C3     C3      C2    C3     C1        C3
#
#      Gamin Hermien Hortense Ikuru Jimmie Julie-A959 Julie-LWC21 Kidongo Koby  \
# 3413    C3      C2       C2    C3     C3         C3          C3      C3   C3
#
#      Kombote Kosana Koto Kumbuka Lara Linda Luky Marlin Maya Mgbadolite  \
# 3413      C2     C2   C3      C2   C3    C3   C3     C3   C3         C3
#
#      Mirinda Nakuu Natalie Negrita SeppToni Taweh Tibe Tongo Trixie Ula  \
# 3413      C3    C3      C1      C3       C3    C3   C3    C3     C3  C3
#
#      Vaillant Vincent Washu Yogui    node_0    node_1    node_2    node_3  \
# 3413       C3      C3    C3    C3  0.000142  0.052313  0.052313  0.050532
#
#       n_clusters                                cluster_composition  \
# 3413           3  Dzeeta Natalie/Bono Desmond Hermien Hortense K...
#
#       single_clusters
# 3413                0

# %%
windows = comparisons[['chr','window_start']]
windows = windows.drop_duplicates()
windows['window_end'] = windows['window_start'] + 1048576
windows.head(5)
# Out:
#      chr  window_start  window_end
# 0  chr10       1572864     2621440
# 1  chr10       2097152     3145728
# 2  chr10       2621440     3670016
# 3  chr10       3145728     4194304
# 4  chr10       3670016     4718592

# %%
windows_pbtBED = pybedtools.BedTool().from_dataframe(windows).sort()
windows_pbtBED.head()
# Out:
# chr1	1048576	2097152
#  chr1	1572864	2621440
#  chr1	2097152	3145728
#  chr1	2621440	3670016
#  chr1	3145728	4194304
#  chr1	3670016	4718592
#  chr1	5242880	6291456
#  chr1	5767168	6815744
#  chr1	6291456	7340032
#  chr1	6815744	7864320

# %%
genes_pbtBED = pybedtools.BedTool('annotations/panTro6_genes.bed')
genes_pbtBED.head(5)
# Out:
# chr1	344	12299	NM_001280424.1	INTS11
#  chr1	12400	16513	XM_016952033.2	CPTP
#  chr1	17887	23426	XM_003307748.4	TAS1R3
#  chr1	22943	36942	XM_016958290.2	DVL1
#  chr1	39619	45507	NM_001280245.1	MXRA8

# %%
windows_genes_intersection = windows_pbtBED.intersect(genes_pbtBED, c = True).to_dataframe(names=['window_chr','window_start','window_end','count'])
windows_genes_intersection.head(5)
# Out:
#   window_chr  window_start  window_end  count
# 0       chr1       1048576     2097152     14
# 1       chr1       1572864     2621440     13
# 2       chr1       2097152     3145728     10
# 3       chr1       2621440     3670016      1
# 4       chr1       3145728     4194304      2

# %%
windows_genes_intersection.groupby(['count']).size().to_frame('N')
# Out:
#          N
# count
# 0      318
# 1      524
# 2      445
# 3      367
# 4      336
# 5      331
# 6      291
# 7      258
# 8      230
# 9      197
# 10     168
# 11     123
# 12      94
# 13      99
# 14      64
# 15      57
# 16      45
# 17      47
# 18      38
# 19      34
# 20      34
# 21      31
# 22      21
# 23      25
# 24      22
# 25      20
# 26      12
# 27      18
# 28      14
# 29      13
# 30      13
# 31      10
# 32      12
# 33      16
# 34       6
# 35      13
# 36       8
# 37      11
# 38       9
# 39       8
# 40       3
# 41       3
# 42       2
# 43       2
# 44       3
# 45       2
# 46       2
# 47       1
# 48       2
# 49       1
# 50       1
# 52       2
# 53       3
# 54       1
# 55       2
# 58       2
# 60       1
# 62       1
# 63       2
# 65       1
# 67       1

# %%
ppn_pt_clustering_windows_pbtBED = pybedtools.BedTool().from_dataframe(ppn_pt_clustering_windows_BED).sort()
ppn_pt_clustering_windows_pbtBED.head()
# Out:
# chr1	5242880	6291456
#  chr1	27262976	28311552
#  chr1	35651584	36700160
#  chr1	40370176	41418752
#  chr1	48758784	49807360
#  chr1	49283072	50331648
#  chr1	71827456	72876032
#  chr1	75497472	76546048
#  chr1	77594624	78643200
#  chr1	78118912	79167488

# %%
ppn_pt_clustering_windows_genes_intersection.groupby('count').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [110], line 1
# ----> 1 ppn_pt_clustering_windows_genes_intersection.groupby('count').count()
#
# NameError: name 'ppn_pt_clustering_windows_genes_intersection' is not defined

# %%
#ppn_pt_clustering_windows_genes_intersection = ppn_pt_clustering_windows_pbtBED.intersect(genes_pbtBED, wa = True, wb = True).to_dataframe(names=['window_chr','window_start','window_end','gene_chr','gene_start','gene_end','transcript','gene'])
#ppn_pt_clustering_windows_genes_intersection.head(5)

# %%
ppn_pt_clustering_windows_with_genes = ppn_pt_clustering_windows_genes_intersection[['window_chr','window_start']]
ppn_pt_clustering_windows_with_genes = ppn_pt_clustering_windows_with_genes.drop_duplicates()

# %%
len(ppn_pt_clustering_windows_with_genes)

# %% [markdown]
# Now that we have two sets of windows, let's identify bonobo-specific variants in these window sets for in silico mutagenesis.

# %% [markdown]
# ### Clustering Windows: In Silico Mutagenesis <a class = 'anchor' id = 'clusteringwindowsinsilicomutagenesis'></a>

# %% [markdown]
# What variants are driving these patterns? Let's examine the results of in silico mutagenesis in clustering windows using bonobo-specific variants.

# %%
ppn_pt_clustering_window_variants = pd.read_csv('in_silico_mutagenesis/ppn_pt_clustering_window_variants.txt', sep = '\t', header = 0)
ppn_pt_clustering_window_variants.head(5)

# %% [markdown]
# Let's edit the window column to also include the chromosome.

# %%
ppn_pt_clustering_window_variants['window'] = ppn_pt_clustering_window_variants['chr'] + '_' + ppn_pt_clustering_window_variants['window'].astype(str)
ppn_pt_clustering_window_variants.head(5)

# %%
len(ppn_pt_clustering_window_variants)

# %% [markdown]
# How many windows are represented by these variants?

# %%
len(ppn_pt_clustering_window_variants['window'].unique())

# %% [markdown]
# To identify 3d modifying variants, let's find the value of the lowest bonobo-chimpanzee divergence score in clustering windows and then map that value to the above dataframe.

# %%
def get_clustering_window_minima(window):
    subset = comparisons[comparisons['window'] == window]
    subset = subset[subset['dyad_type'] == 'ppn-pt']
    minimum = subset['divergence'].min()
    
    return minimum

# %%
ppn_pt_dist_mins = [get_clustering_window_minima(window) for window in ppn_pt_clustering_windows['window']]
ppn_pt_dist_mins_dict = dict(zip(ppn_pt_clustering_windows['window'], ppn_pt_dist_mins))

# %%
ppn_pt_clustering_window_variants['min'] = ppn_pt_clustering_window_variants['window'].map(ppn_pt_dist_mins_dict)

# %%
ppn_pt_clustering_window_variants.head(5)

# %%
ppn_pt_clustering_3d_modifying_variants = ppn_pt_clustering_window_variants[ppn_pt_clustering_window_variants['1-spearman'] >= ppn_pt_clustering_window_variants['min']]
ppn_pt_clustering_3d_modifying_variants.head(5)

# %%
len(ppn_pt_clustering_3d_modifying_variants)

# %% [markdown]
# How many windows are covered by these variants?

# %%
len(ppn_pt_clustering_3d_modifying_variants['window'].unique())

# %%
159/339

# %% [markdown]
# Are there differences in the mutation frequency of these variants?

# %% [markdown]
# Let's create a BED file of the variants to complete intersections in the following steps. We will end up creating a BED file from a dataframe more than once so let's write a function.

# %%
def dataframe_to_BED(input_df):
    input_df_BED = input_df[['chr','pos']].copy()
    input_df_BED.rename(columns={ input_df_BED.columns[1]: 'end' }, inplace = True)
    input_df_BED['start'] = input_df_BED['end'].astype(int)-1
    input_df_BED = input_df_BED[['chr','start','end']]
    input_df_BED = input_df_BED.drop_duplicates()
    return input_df_BED

# %%
ppn_pt_clustering_3d_modifying_variants_BED = dataframe_to_BED(ppn_pt_clustering_3d_modifying_variants)
ppn_pt_clustering_3d_modifying_variants_BED.head(5)

# %%
len(ppn_pt_clustering_3d_modifying_variants_BED)

# %% [markdown]
# Save this dataframe.

# %%
ppn_pt_clustering_3d_modifying_variants_BED.to_csv('clustering_windows/ppn_pt_clustering_3d_modifying_variants.bed', sep = '\t', header = False, index = False)

# %% [markdown]
# Convert to pybedtools.

# %%
ppn_pt_clustering_3d_modifying_variants_pbtBED = pybedtools.BedTool().from_dataframe(ppn_pt_clustering_3d_modifying_variants_BED).sort()
ppn_pt_clustering_3d_modifying_variants_pbtBED.head()

# %%
len(ppn_pt_clustering_3d_modifying_variants_pbtBED)

# %% [markdown]
# Now let's link these variants to TADs and then to genes. Use TADs for features in "A" and variants for features in "B" to make the downstream gene intersection easier.

# %%
ppn_pt_clustering_3d_modifying_variant_TAD_intersection_pbtBED = TADs_pbtBED.intersect(ppn_pt_clustering_3d_modifying_variants_pbtBED, wa = True, wb = True)
ppn_pt_clustering_3d_modifying_variant_TAD_intersection_pbtBED.head(5)

# %%
len(ppn_pt_clustering_3d_modifying_variant_TAD_intersection_pbtBED)

# %% [markdown]
# Now load the gene annotations, perform the intersection, and convert to a dataframe.

# %%
genes_pbtBED = pybedtools.BedTool('annotations/panTro6_genes.bed')
genes_pbtBED.head(5)

# %%
ppn_pt_clustering_3d_modifying_variant_TAD_gene_intersection = genes_pbtBED.intersect(ppn_pt_clustering_3d_modifying_variant_TAD_intersection_pbtBED, wa = True, wb = True).to_dataframe(names=['gene_chr','gene_start','gene_end','transcript','gene','TAD_chr','TAD_start','TAD_end','variant_chr','variant_start','variant_end'])
ppn_pt_clustering_3d_modifying_variant_TAD_gene_intersection.head(5)

# %% [markdown]
# Now subset this dataframe to variants and genes. We will remove any duplicates because they represent nested TADs.

# %%
ppn_pt_clustering_3d_modified_genes = ppn_pt_clustering_3d_modifying_variant_TAD_gene_intersection[['variant_end','gene']]
ppn_pt_clustering_3d_modified_genes = ppn_pt_clustering_3d_modified_genes.drop_duplicates()

# %% [markdown]
# The Eres et al. 2019 TADs are missing from chromosome 7 so let's grab a list of nearby genes for any 3d-modifying variants found there.

# %%
ppn_pt_clustering_3d_modifying_chr7_variants = ppn_pt_clustering_3d_modifying_variants[ppn_pt_clustering_3d_modifying_variants['chr'] == 'chr7']
ppn_pt_clustering_3d_modifying_chr7_variants.head(9)

# %%
ppn_pt_clustering_3d_modifying_chr7_variants_BED = dataframe_to_BED(ppn_pt_clustering_3d_modifying_chr7_variants)
ppn_pt_clustering_3d_modifying_chr7_variants_BED.head(5)

# %% [markdown]
# Add 150,000 bp to both the start and end coordinate to generate an average sized TAD around the variant.

# %%
ppn_pt_clustering_3d_modifying_chr7_variants_BED['start'] = ppn_pt_clustering_3d_modifying_chr7_variants_BED['start'] - 150000
ppn_pt_clustering_3d_modifying_chr7_variants_BED['end'] = ppn_pt_clustering_3d_modifying_chr7_variants_BED['end'] + 150000
ppn_pt_clustering_3d_modifying_chr7_variants_BED.head(5)

# %% [markdown]
# Convert to pybedtools format.

# %%
ppn_pt_clustering_3d_modifying_chr7_variants_pbtBED = pybedtools.BedTool().from_dataframe(ppn_pt_clustering_3d_modifying_chr7_variants_BED).sort()
ppn_pt_clustering_3d_modifying_chr7_variants_pbtBED.head()

# %% [markdown]
# And intersect with the gene annotations.

# %%
ppn_pt_clustering_3d_modifying_chr7_variants_TAD_gene_intersection = ppn_pt_clustering_3d_modifying_chr7_variants_pbtBED.intersect(genes_pbtBED, wa = True, wb = True).to_dataframe(names = ['variant_chr','variant_start','variant_end','gene_chr','gene_start','gene_end','gene_transcript','gene'])
ppn_pt_clustering_3d_modifying_chr7_variants_TAD_gene_intersection.head(5)

# %% [markdown]
# Now combine chr7 with the rest of the autosomes and save the gene list for phenotype enrichment analyses.

# %%
ppn_pt_clustering_3d_modified_genes = list([x for x in ppn_pt_clustering_3d_modified_genes['gene'] if str(x) != '.']) + list([x for x in ppn_pt_clustering_3d_modifying_chr7_variants_TAD_gene_intersection['gene'] if str(x) != '.'])
ppn_pt_clustering_3d_modified_genes = pd.DataFrame(ppn_pt_clustering_3d_modified_genes, columns = ['gene'])
ppn_pt_clustering_3d_modified_genes.head(5)

# %%
len(ppn_pt_clustering_3d_modified_genes)

# %%
ppn_pt_clustering_3d_modified_genes.to_csv('clustering_windows/ppn_pt_clustering_3d_modified_genes.txt', sep = '\t', header = False, index = False)

# %% [markdown]
# ### Divergent Windows: In Silico Mutagenesis <a class = 'anchor' id = 'divergentwindowsinsilicomutagenesis'></a>

# %% [markdown]
# Now for variants in divergent windows.

# %%
ppn_pt_divergent_window_variants = pd.read_csv('in_silico_mutagenesis/ppn_pt_divergent_window_variants.txt', sep = '\t', header = 0)
ppn_pt_divergent_window_variants.head(5)

# %%
len(ppn_pt_divergent_window_variants)

# %%
ppn_pt_divergent_window_variants['window'] = ppn_pt_divergent_window_variants['chr'] + '_' + ppn_pt_divergent_window_variants['window'].astype(str)
ppn_pt_divergent_window_variants.head(5)

# %% [markdown]
# Now map these values to the windows in the in silico mutagenesis dataframe.

# %%
ppn_pt_divergent_window_variants['empirical_max'] = ppn_pt_divergent_window_variants['window'].map(ppn_pt_divergent_windows_chimp_maxes)
ppn_pt_divergent_window_variants.head(5)

# %% [markdown]
# Which variants cause a 3D change that is greater or equal to the observed maximum difference in chimpanzees?

# %%
ppn_pt_divergent_3d_modifying_variants = ppn_pt_divergent_window_variants[ppn_pt_divergent_window_variants['1-spearman'] >= ppn_pt_divergent_window_variants['empirical_max']]
ppn_pt_divergent_3d_modifying_variants.head(5)

# %%
len(ppn_pt_divergent_3d_modifying_variants)

# %% [markdown]
# How many windows are represented by these variants?

# %%
len(ppn_pt_divergent_3d_modifying_variants['window'].unique())

# %% [markdown]
# Output these variants in the original in silico mutagenesis input format so that we can generate some maps.

# %%
ppn_pt_divergent_3d_modifying_variants_with_window = ppn_pt_divergent_3d_modifying_variants[['chr','pos','ref','alt','window']].copy()
ppn_pt_divergent_3d_modifying_variants_with_window['window'] = ppn_pt_divergent_3d_modifying_variants_with_window['window'].str.split('_').str[1]
ppn_pt_divergent_3d_modifying_variants_with_window.head(5)

# %%
ppn_pt_divergent_3d_modifying_variants_with_window.to_csv('divergent_windows/ppn_pt_divergent_3d_modifying_variants_with_window.txt', sep = '\t', header = False, index = False)

# %% [markdown]
# Let's create a BED file of the variants to complete intersections we will complete in the following steps.

# %%
ppn_pt_divergent_3d_modifying_variants_BED = dataframe_to_BED(ppn_pt_divergent_3d_modifying_variants)
ppn_pt_divergent_3d_modifying_variants_BED.head(5)

# %%
len(ppn_pt_divergent_3d_modifying_variants_BED)

# %% [markdown]
# We will be shuffling these variants in our phenotype enrichment momentarily so go ahead and save the frame.

# %%
ppn_pt_divergent_3d_modifying_variants_BED.to_csv('divergent_windows/ppn_pt_divergent_3d_modifying_variants.bed', sep = '\t', header = False, index = False)

# %% [markdown]
# Now let's get these variants in pybedtools BED format.

# %%
ppn_pt_divergent_3d_modifying_variants_pbtBED = pybedtools.BedTool().from_dataframe(ppn_pt_divergent_3d_modifying_variants_BED).sort()
ppn_pt_divergent_3d_modifying_variants_pbtBED.head()

# %%
len(ppn_pt_divergent_3d_modifying_variants_pbtBED)

# %%
ppn_pt_divergent_3d_modifying_variant_TAD_intersection_pbtBED = TADs_pbtBED.intersect(ppn_pt_divergent_3d_modifying_variants_pbtBED, wa = True, wb = True)
ppn_pt_divergent_3d_modifying_variant_TAD_intersection_pbtBED.head(5)

# %%
len(ppn_pt_divergent_3d_modifying_variant_TAD_intersection_pbtBED)

# %% [markdown]
# Intersect with genes and convert to a dataframe.

# %%
ppn_pt_divergent_3d_modifying_variant_TAD_gene_intersection = genes_pbtBED.intersect(ppn_pt_divergent_3d_modifying_variant_TAD_intersection_pbtBED, wa = True, wb = True).to_dataframe(names=['gene_chr','gene_start','gene_end','transcript','gene','TAD_chr','TAD_start','TAD_end','variant_chr','variant_start','variant_end'])
ppn_pt_divergent_3d_modifying_variant_TAD_gene_intersection.head(5)

# %% [markdown]
# Now subset this dataframe to variants and genes. We will remove any duplicates because they represent nested TADs.

# %%
ppn_pt_divergent_3d_modified_genes = ppn_pt_divergent_3d_modifying_variant_TAD_gene_intersection[['variant_end','gene']]
ppn_pt_divergent_3d_modified_genes = ppn_pt_divergent_3d_modified_genes.drop_duplicates()

# %% [markdown]
# Tackle the chromosome 7 situation again.

# %%
ppn_pt_divergent_3d_modifying_chr7_variants = ppn_pt_divergent_3d_modifying_variants[ppn_pt_divergent_3d_modifying_variants['chr'] == 'chr7']
ppn_pt_divergent_3d_modifying_chr7_variants.head(9)

# %%
ppn_pt_divergent_3d_modifying_chr7_variants_BED = dataframe_to_BED(ppn_pt_divergent_3d_modifying_chr7_variants)
ppn_pt_divergent_3d_modifying_chr7_variants_BED.head(5)

# %% [markdown]
# Add 150,000 bp to both the start and end coordinate to generate an average sized TAD around the variant.

# %%
ppn_pt_divergent_3d_modifying_chr7_variants_BED['start'] = ppn_pt_divergent_3d_modifying_chr7_variants_BED['start'] - 150000
ppn_pt_divergent_3d_modifying_chr7_variants_BED['end'] = ppn_pt_divergent_3d_modifying_chr7_variants_BED['end'] + 150000
ppn_pt_divergent_3d_modifying_chr7_variants_BED.head(5)

# %% [markdown]
# Convert to pybedtools format.

# %%
ppn_pt_divergent_3d_modifying_chr7_variants_pbtBED = pybedtools.BedTool().from_dataframe(ppn_pt_divergent_3d_modifying_chr7_variants_BED).sort()
ppn_pt_divergent_3d_modifying_chr7_variants_pbtBED.head()

# %% [markdown]
# And intersect with the gene annotations.

# %%
ppn_pt_divergent_3d_modifying_chr7_variants_TAD_gene_intersection = ppn_pt_divergent_3d_modifying_chr7_variants_pbtBED.intersect(genes_pbtBED, wa = True, wb = True).to_dataframe(names = ['variant_chr','variant_start','variant_end','gene_chr','gene_start','gene_end','gene_transcript','gene'])
ppn_pt_divergent_3d_modifying_chr7_variants_TAD_gene_intersection.head(5)

# %% [markdown]
# Now combine chr7 with the rest of the autosomes and save the gene list for phenotype enrichment analyses.

# %%
ppn_pt_divergent_3d_modified_genes = list([x for x in ppn_pt_divergent_3d_modified_genes['gene'] if str(x) != '.']) + list([x for x in ppn_pt_clustering_3d_modifying_chr7_variants_TAD_gene_intersection['gene'] if str(x) != '.'])
ppn_pt_divergent_3d_modified_genes = pd.DataFrame(ppn_pt_divergent_3d_modified_genes, columns = ['gene'])
ppn_pt_divergent_3d_modified_genes.head(5)

# %%
len(ppn_pt_divergent_3d_modified_genes)

# %%
ppn_pt_divergent_3d_modified_genes.to_csv('divergent_windows/ppn_pt_divergent_3d_modified_genes.txt', sep = '\t', header = False, index = False)

# %% [markdown]
# ### Divergent Windows: Differential Gene Expression <a class = 'anchor' id = 'divergentwindowsexpression'></a>

# %% [markdown]
# Let's consider whether genes topologically associated with 3d modifying variants between bonobos and chimpanzees exhibit differential gene expression. Download the SRA data from Brawand et al. 2011 and run the RNAseq pipeline to generate read counts per gene per sample. Below we will gather and analyze these data.

# %% [markdown]
# Write a tissue dictionary.

# %%
tissue_dict = dict({'SRR306811': 'prefrontal_cortex',
                 'SRR306817': 'cerebellum',
                 'SRR306818': 'cerebellum', 
                 'SRR306819': 'heart', 
                 'SRR306820': 'heart', 
                 'SRR306821': 'kidney', 
                 'SRR306822': 'kidney', 
                 'SRR306823': 'liver', 
                 'SRR306824': 'liver', 
                 'SRR306825': 'testis',
                 'SRR306827': 'prefrontal_cortex',
                 'SRR306828': 'prefrontal_cortex',
                 'SRR306829': 'cerebellum',
                 'SRR306830': 'cerebellum', 
                 'SRR306831': 'heart', 
                 'SRR306832': 'heart', 
                 'SRR306833': 'kidney', 
                 'SRR306834': 'kidney', 
                 'SRR306835': 'liver', 
                 'SRR306836': 'liver', 
                 'SRR306837': 'testis'})

# %% [markdown]
# Define which samples belong to which individual.

# %%
ppn_female = ['SRR306827','SRR306829','SRR306831','SRR306833','SRR306835']
ppn_male = ['SRR306828','SRR306830','SRR306832','SRR306834','SRR306836','SRR306837']
ptr_female = ['SRR306811','SRR306817','SRR306819','SRR306821','SRR306823']
ptr_male = ['SRR306818','SRR306820','SRR306822','SRR306824','SRR306825']

# %% [markdown]
# Now let's write a function to gather the read count data per individual.

# %%
def reads_per_individual(individual, SRR_ids_list):
    individual_read_counts_dfs_list = []
    
    for i in range(len(SRR_ids_list)):
        individual_temp_df = pd.read_csv('RNAseq/read_counts/'+SRR_ids_list[i]+'_read_counts.txt', sep = '\t', names = ['gene',SRR_ids_list[i]])
        individual_read_counts_dfs_list.append(individual_temp_df)
        
    for df in individual_read_counts_dfs_list:
        df.set_index('gene', inplace = True)
        
    individual_read_counts_df = pd.concat(individual_read_counts_dfs_list, axis = 1, sort = False).reset_index()
    
    individual_read_counts_df = individual_read_counts_df.set_index(['gene']).stack().to_frame().reset_index()
    individual_read_counts_df.rename(columns={ 'level_1': 'sample', 0: individual}, inplace = True)
    individual_read_counts_df['tissue'] = individual_read_counts_df['sample'].map(tissue_dict)
    individual_read_counts_df = individual_read_counts_df.drop('sample', axis = 1)
    individual_read_counts_df = individual_read_counts_df[~individual_read_counts_df['gene'].str.startswith('_')]
    individual_read_counts_df = individual_read_counts_df[~individual_read_counts_df['gene'].str.startswith('unassigned')]
    individual_read_counts_df = individual_read_counts_df[['gene','tissue',individual]]
    
    return individual_read_counts_df

# %% [markdown]
# Apply the function to all four individuals.

# %%
ppn_female_reads = reads_per_individual('ppn_female', ppn_female).set_index(['gene','tissue'])
ppn_male_reads = reads_per_individual('ppn_male', ppn_male).set_index(['gene','tissue'])
ptr_female_reads = reads_per_individual('ptr_female', ptr_female).set_index(['gene','tissue'])
ptr_male_reads = reads_per_individual('ptr_male', ptr_male).set_index(['gene','tissue'])

# %% [markdown]
# Gather those data and check out the dataframe.

# %%
gene_expression = pd.concat([ppn_female_reads, ppn_male_reads, ptr_female_reads, ptr_male_reads], axis = 1, sort = False).reset_index()
gene_expression.head(12)
# Out:
#     gene             tissue  ppn_female  ppn_male  ptr_female  ptr_male
# 0   A1BG  prefrontal_cortex        57.0        19        25.0       NaN
# 1   A1BG         cerebellum        77.0       106        33.0      60.0
# 2   A1BG              heart        10.0        13         1.0       2.0
# 3   A1BG             kidney        71.0        41         4.0      47.0
# 4   A1BG              liver     20096.0      7430     14688.0   26935.0
# 5   A1CF  prefrontal_cortex         0.0         0         0.0       NaN
# 6   A1CF         cerebellum         0.0         0         0.0       2.0
# 7   A1CF              heart         0.0         1         0.0       0.0
# 8   A1CF             kidney        97.0       141       208.0     643.0
# 9   A1CF              liver      1493.0       922       512.0    1287.0
# 10   A2M  prefrontal_cortex      2390.0      3149      1089.0       NaN
# 11   A2M         cerebellum       856.0      1020      1371.0     488.0

# %% [markdown]
# Now let's calculate means per species and the species difference.

# %%
gene_expression['ppn_mean'] = gene_expression[['ppn_female', 'ppn_male']].mean(axis=1, skipna=True)
gene_expression['ptr_mean'] = gene_expression[['ptr_female', 'ptr_male']].mean(axis=1, skipna=True)
gene_expression['fold_change'] = np.log2(gene_expression['ptr_mean']/gene_expression['ppn_mean'])
gene_expression.head(12)
# Out:
# /wynton/home/capra/cbrand/miniconda3/envs/jupyter/lib/python3.10/site-packages/pandas/core/arraylike.py:405: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#     gene             tissue  ppn_female  ppn_male  ptr_female  ptr_male  \
# 0   A1BG  prefrontal_cortex        57.0        19        25.0       NaN
# 1   A1BG         cerebellum        77.0       106        33.0      60.0
# 2   A1BG              heart        10.0        13         1.0       2.0
# 3   A1BG             kidney        71.0        41         4.0      47.0
# 4   A1BG              liver     20096.0      7430     14688.0   26935.0
# 5   A1CF  prefrontal_cortex         0.0         0         0.0       NaN
# 6   A1CF         cerebellum         0.0         0         0.0       2.0
# 7   A1CF              heart         0.0         1         0.0       0.0
# 8   A1CF             kidney        97.0       141       208.0     643.0
# 9   A1CF              liver      1493.0       922       512.0    1287.0
# 10   A2M  prefrontal_cortex      2390.0      3149      1089.0       NaN
# 11   A2M         cerebellum       856.0      1020      1371.0     488.0
#
#     ppn_mean  ptr_mean  fold_change
# 0       38.0      25.0    -0.604071
# 1       91.5      46.5    -0.976541
# 2       11.5       1.5    -2.938599
# 3       56.0      25.5    -1.134930
# 4    13763.0   20811.5     0.596586
# 5        0.0       0.0          NaN
# 6        0.0       1.0          inf
# 7        0.5       0.0         -inf
# 8      119.0     425.5     1.838198
# 9     1207.5     899.5    -0.424828
# 10    2769.5    1089.0    -1.346622
# 11     938.0     929.5    -0.013133

# %%
gene_expression.replace([np.inf, -np.inf], np.nan, inplace=True)
gene_expression.dropna(inplace=True)

# %%
gene_expression.head(12)
# Out:
#      gene      tissue  ppn_female  ppn_male  ptr_female  ptr_male  ppn_mean  \
# 1    A1BG  cerebellum        77.0       106        33.0      60.0      91.5
# 2    A1BG       heart        10.0        13         1.0       2.0      11.5
# 3    A1BG      kidney        71.0        41         4.0      47.0      56.0
# 4    A1BG       liver     20096.0      7430     14688.0   26935.0   13763.0
# 8    A1CF      kidney        97.0       141       208.0     643.0     119.0
# 9    A1CF       liver      1493.0       922       512.0    1287.0    1207.5
# 11    A2M  cerebellum       856.0      1020      1371.0     488.0     938.0
# 12    A2M       heart      2891.0      2344      3479.0    2896.0    2617.5
# 13    A2M      kidney      2403.0      1464      2333.0    2353.0    1933.5
# 14    A2M       liver     44463.0     22529      3188.0    8520.0   33496.0
# 16  A2ML1  cerebellum        15.0        17         8.0      13.0      16.0
# 17  A2ML1       heart         3.0         1         2.0       0.0       2.0
#
#     ptr_mean  fold_change
# 1       46.5    -0.976541
# 2        1.5    -2.938599
# 3       25.5    -1.134930
# 4    20811.5     0.596586
# 8      425.5     1.838198
# 9      899.5    -0.424828
# 11     929.5    -0.013133
# 12    3187.5     0.284236
# 13    2343.0     0.277142
# 14    5854.0    -2.516494
# 16      10.5    -0.607683
# 17       1.0    -1.000000

# %%
gene_expression[gene_expression['gene'] == 'ZNF804B']
# Out:
#            gene      tissue  ppn_female  ppn_male  ptr_female  ptr_male  \
# 173091  ZNF804B  cerebellum        24.0        32         9.0       3.0
#
#         ppn_mean  ptr_mean  fold_change
# 173091      28.0       6.0    -2.222392

# %%
len(gene_expression)
# Out:
# 87023

# %% [markdown]
# Let's test for enrichment of differently expressed genes in 3d clustering and divergent windows. First, we need to intersect the windows with the genes.

# %%
ppn_pt_clustering_windows_pbtBED = pybedtools.BedTool().from_dataframe(ppn_pt_clustering_windows_BED)

# %%
ppn_pt_clustering_windows_genes_intersect = ppn_pt_clustering_windows_pbtBED.intersect(genes_pbtBED, wa = True, wb = True).to_dataframe(names = ['window_chr','window_start','window_end','gene_chr','gene_start','gene_end','gene_transcript','gene'])

# %%
len(ppn_pt_clustering_windows_genes_intersect)

# %%
339/4420

# %%
2412/20920

# %% [markdown]
# Let's test for enrichment of

# %%
genes = pd.read_csv('annotations/panTro6_genes.bed', sep = '\t', names = ['chr','start','end','transcript','gene'])
genes.head(5)
# Out:
#     chr  start    end      transcript    gene
# 0  chr1    344  12299  NM_001280424.1  INTS11
# 1  chr1  12400  16513  XM_016952033.2    CPTP
# 2  chr1  17887  23426  XM_003307748.4  TAS1R3
# 3  chr1  22943  36942  XM_016958290.2    DVL1
# 4  chr1  39619  45507  NM_001280245.1   MXRA8

# %%
ppn_pt_divergent_3d_modified_genes.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [133], line 1
# ----> 1 ppn_pt_divergent_3d_modified_genes.head(5)
#
# NameError: name 'ppn_pt_divergent_3d_modified_genes' is not defined

# %%
ppn_pt_divergent_3d_modified_genes = ppn_pt_divergent_3d_modified_genes.drop_duplicates()
ppn_pt_non_divergent_3d_modified_genes = genes[~genes['gene'].isin(ppn_pt_divergent_3d_modified_genes['gene'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [134], line 1
# ----> 1 ppn_pt_divergent_3d_modified_genes = ppn_pt_divergent_3d_modified_genes.drop_duplicates()
#       2 ppn_pt_non_divergent_3d_modified_genes = genes[~genes['gene'].isin(ppn_pt_divergent_3d_modified_genes['gene'])]
#
# NameError: name 'ppn_pt_divergent_3d_modified_genes' is not defined

# %%
len(ppn_pt_divergent_3d_modified_genes)

# %%
len(ppn_pt_non_divergent_3d_modified_genes)

# %%
differently_expressed_genes = gene_expression[(gene_expression['fold_change'] >= 2) | (gene_expression['fold_change'] <= -2)]['gene'].to_frame('gene')
differently_expressed_genes = differently_expressed_genes.drop_duplicates()
differently_expressed_genes.head(5)

# %%
len(differently_expressed_genes)

# %%
non_differently_expressed_genes = genes[~genes['gene'].isin(differently_expressed_genes['gene'])]

# %%
len(non_differently_expressed_genes)

# %%
len(list(set(ppn_pt_divergent_3d_modified_genes['gene']).intersection(differently_expressed_genes['gene'])))

# %%
len(list(set(ppn_pt_divergent_3d_modified_genes['gene']).intersection(non_differently_expressed_genes['gene'])))

# %%
len(list(set(ppn_pt_non_divergent_3d_modified_genes['gene']).intersection(differently_expressed_genes['gene'])))

# %%
len(list(set(ppn_pt_non_divergent_3d_modified_genes['gene']).intersection(non_differently_expressed_genes['gene'])))

# %%
list(set(ppn_pt_divergent_3d_modified_genes['gene']).intersection(differently_expressed_genes['gene']))

# %%
fisher_exact([[35,118],[3655,17100]])

# %%
fisher_exact([[55,98],[6066,14689]])

# %%
fisher_exact([[96,57],[10948,9807]])

# %%
#def fisher_exact(A, B, C, D):
#    OR, p = fisher_exact([[A, B], [C, D]])
#    lCI = np.exp((np.log(OR)) - (1.96 * (sqrt((1/A) + (1/B) + (1/C) + (1/D)))))
#    uCI = np.exp((np.log(OR)) + (1.96 * (sqrt((1/A) + (1/B) + (1/C) + (1/D)))))
#    return OR, p, lCI, uCI

# %%
fisher_exact(35,118,3655,17100)

# %%
len(ppn_pt_divergent_3d_modified_genes)

# %%
len(ppn_pt_divergent_3d_modified_genes.drop_duplicates())

# %%
len(ppn_pt_non_divergent_3d_modified_genes)

# %%
ppn_pt_non_divergent_3d_modified_genes = ~genes['gene'].isin(ppn_pt_divergent_3d_modified_genes['gene'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [135], line 1
# ----> 1 ppn_pt_non_divergent_3d_modified_genes = ~genes['gene'].isin(ppn_pt_divergent_3d_modified_genes['gene'])
#
# NameError: name 'ppn_pt_divergent_3d_modified_genes' is not defined

# %%
len(genes)

# %%
gene_expression_subset = gene_expression[gene_expression['gene'].isin(ppn_pt_divergent_3d_modified_genes['gene'])]
gene_expression_subset.head(12)

# %%
len(gene_expression_subset)

# %%
len(gene_expression_subset['gene'].unique())

# %%
gene_expression_others = gene_expression[~gene_expression['gene'].isin(divergent_genes['gene'])]
gene_expression_others.head(12)

# %%
len(gene_expression_others)

# %%
gene_expression_subset.to_csv('divergent_windows/gene_expression_subset.txt', sep = '\t', header = True, index = False)

# %%
gene_expression_others.to_csv('divergent_windows/gene_expression_others.txt', sep = '\t', header = True, index = False)

# %%
len(gene_expression_subset[gene_expression_subset['fold_change'] > 2])

# %%
gene_expression_subset[gene_expression_subset['fold_change'] > 2].head(30)

# %%
len(gene_expression_subset[gene_expression_subset['fold_change'] < -2])

# %%
gene_expression_subset[gene_expression_subset['fold_change'] < -2]

# %% [markdown]
# ## Lineage-Specific Substitutions

# %%
pte_specific_variants = pd.read_csv('in_silico_mutagenesis/pte_specific_variants.txt', sep = '\t', header = 0)
pte_specific_variants.head(5)

# %%
pte_specific_variants[pte_specific_variants['1-spearman'] > 0.001]

# %%
pts_specific_variants = pd.read_csv('in_silico_mutagenesis/pts_variants.txt', sep = '\t', header = 0)
pts_specific_variants.head(5)

# %%
pts_specific_variants[pts_specific_variants['1-spearman'] > 0.001]

# %%
ptt_specific_variants = pd.read_csv('in_silico_mutagenesis/ptt_variants.txt', sep = '\t', header = 0)
ptt_specific_variants.head(5)

# %%
ptt_specific_variants[ptt_specific_variants['1-spearman'] > 0.001]

# %%
ptv_specific_variants = pd.read_csv('in_silico_mutagenesis/ptv_specific_variants.txt', sep = '\t', header = 0)
ptv_specific_variants.head(5)

# %%
ptv_specific_variants[ptv_specific_variants['1-spearman'] > 0.001]

# %% [markdown]
# ## Phenotype Enrichment

# %%
fdr_table = []

# %%
def reportFDRcorrectedPthreshold(set_name, ontology, q_value_threshold, resolution=0.0001, minStart=0):
    fdr_empiric = pd.read_csv(f'phenotype_enrichment/empiric_FDR/{set_name}_{ontology}_empiric_FDR.txt', sep = '\t', header = None, index_col = 0)
    obs = pd.read_csv(f'phenotype_enrichment/enrichment/{set_name}_{ontology}_enrichment.txt', sep = '\t')

    fdr_threshold = []
    for i in np.arange(minStart,0.05,resolution):
        
        observed_positive = sum(obs['p_value'] <= i)
        average_false_positive = (fdr_empiric <= i).sum().mean()
        q = average_false_positive/observed_positive
        fdr_threshold.append([set_name, ontology, q_value_threshold, i, observed_positive, average_false_positive, q])
        
        if (q != np.inf) & (q > q_value_threshold):
            break
    
    threshold = fdr_threshold[-2]
    fdr_table.append(threshold)
    #fdr_threshold = pd.DataFrame(fdr_threshold, columns = ['pval_threshold','obsPos','avgFalsePos','q'])
    #return fdr_threshold.tail(2).head(1)

# %%
combinations = [(set_name,ontology,q_value_threshold) for set_name in ['ppn_pt_clustering','ppn_pt_divergent'] for ontology in ['BP','GWAS','HPO','MP'] for q_value_threshold in [0.05,0.1]]

# %%
[reportFDRcorrectedPthreshold(set_name, ontology, q_value_threshold) for set_name, ontology, q_value_threshold in combinations]
# Out:
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q = average_false_positive/observed_positive
# /scratch/cbrand/ipykernel_23978/3214691365.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q = average_false_positive/observed_positive
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
fdr_table = pd.DataFrame(fdr_table, columns = ['set', 'ontology', 'q_value_threshold', 'p_value_threshold','observed_positive','average_false_positive','q'])
fdr_table
# Out:
#                   set ontology  q_value_threshold  p_value_threshold  \
# 0   ppn_pt_clustering       BP               0.05             0.0006
# 1   ppn_pt_clustering       BP               0.10             0.0006
# 2   ppn_pt_clustering     GWAS               0.05             0.0010
# 3   ppn_pt_clustering     GWAS               0.10             0.0010
# 4   ppn_pt_clustering      HPO               0.05             0.0029
# 5   ppn_pt_clustering      HPO               0.10             0.0029
# 6   ppn_pt_clustering       MP               0.05             0.0024
# 7   ppn_pt_clustering       MP               0.10             0.0024
# 8    ppn_pt_divergent       BP               0.05             0.0004
# 9    ppn_pt_divergent       BP               0.10             0.0050
# 10   ppn_pt_divergent     GWAS               0.05             0.0028
# 11   ppn_pt_divergent     GWAS               0.10             0.0028
# 12   ppn_pt_divergent      HPO               0.05             0.0038
# 13   ppn_pt_divergent      HPO               0.10             0.0038
# 14   ppn_pt_divergent       MP               0.05             0.0012
# 15   ppn_pt_divergent       MP               0.10             0.0012
#
#     observed_positive  average_false_positive         q
# 0                   0                  0.3842       inf
# 1                   0                  0.3842       inf
# 2                   0                  0.2080       inf
# 3                   0                  0.2080       inf
# 4                   0                  0.7464       inf
# 5                   0                  0.7464       inf
# 6                   0                  1.6404       inf
# 7                   0                  1.6404       inf
# 8                   3                  0.1459  0.048633
# 9                  22                  2.1960  0.099818
# 10                  0                  0.2654       inf
# 11                  0                  0.2654       inf
# 12                  0                  0.4408       inf
# 13                  0                  0.4408       inf
# 14                  0                  0.4586       inf
# 15                  0                  0.4586       inf

# %% [markdown]
# Let's go ahead and split the first column but keep the window column.

# %%
divergent_windows['window_split'] = divergent_windows['window']
divergent_windows = divergent_windows['window_split'].str.split('_', expand=True)
divergent_windows.rename(columns = {0:'chr', 1:'window_start'}, inplace = True)
divergent_windows.head(5)

# %% [markdown]
# Let's output these divergent windows.

# %%
divergent_windows['window_start'] = divergent_windows['window_start'].astype(int)

# %%
divergent_windows['window_end'] = divergent_windows['window_start'] + 1048576
divergent_windows.head(5)

# %% [markdown]
# Note that we do not need to conver the start coordinate here because the windows are already in 0-based coordinates.

# %%
divergent_windows.to_csv('divergent_windows/ppn_pt_divergent_windows.bed', sep = '\t', header = False, index = False)

# %% [markdown]
# Now let's intersect our

# %%
genes_header = ['chr','window_start','genes']
genes = pd.read_csv('windows/pantro6_windows_with_genes.txt', sep = '\t', header = None, names = genes_header)
genes.head(5)

# %%
len(genes)

# %%
divergent_windows_genes = pd.merge(divergent_windows, genes, on = ['chr','window_start'])
divergent_windows_genes.head(5)

# %%
divergent_windows_genes.to_csv('divergent_windows/ppn_pt_divergent_windows_with_genes.bed', sep = '\t', header = False, index = False)

# %%
divergent_genes = divergent_windows_genes['genes']
divergent_genes.head(5)

# %%
divergent_genes = divergent_genes.str.split(',').explode().reset_index(drop = True).to_frame('gene')
divergent_genes = divergent_genes.drop_duplicates()
divergent_genes = divergent_genes['gene'].str.strip().dropna() # exploding created white space and at least one NA
divergent_genes = divergent_genes.sort_values(ascending = True)
divergent_genes.head(20)

# %%
len(divergent_genes)

# %%
divergent_genes.to_csv('divergent_windows/ppn_pt_genes.txt', sep = '\t', header = False, index = False)

# %% [markdown]
# ## Non-Bonobo Divergent Windows

# %%
#get_divergent_windows(['pte-pts','pte-ptt','pts-ptv','ptt-ptv'], ['ppn-pt','ppn'])

# %%
#get_divergent_windows(['pte-pts','pts-ptv'], ['ppn-pt','ppn','pte-ptt','pts-ptt','ptt-ptv','ptt'])

# %%
#get_divergent_windows(['pts-ptt'], ['ppn-pt','ppn','ptt','pts',])

# %%
#get_divergent_windows(['pte'], ['ppn-pt','ppn','ptt','pts'])

# %%
#get_divergent_windows(['ptv'], ['ppn-pt','ppn'])

# %% [markdown]
# ## Sequence Divergence <a class = 'anchor' id = 'sequencedivergence'></a>

# %%
rho, p = spearmanr(comparisons['divergence'], comparisons['seq_diff'])
print(rho,p)

# %% [markdown]
# ## TADs

# %%
TADs_header = ['chr','start','end','score','C3624_overlap','C3649_overlap','C3651_overlap','C40300_overlap']
TADs = pd.read_csv('annotations/panTro6_TADs.bed', sep = '\t', header = None, names = TADs_header)
TADs.head(5)

# %%
len(TADs)

# %%
#TADs_BED = pybedtools.BedTool().from_dataframe(TADs)
#TADs_BED.head(5)

# %%
#ppn_pt_divergent_loci_header = ['chr','end','ref_allele','alt_allele']
#ppn_pt_divergent_loci = pd.read_csv('variant_loci/subset_ppn_specific_loci.txt', sep = '\t', header = None, names = ppn_pt_divergent_loci_header)
#ppn_pt_divergent_loci.head(5)

# %%
#ppn_pt_divergent_loci['start'] = ppn_pt_divergent_loci['end'] - 1
#ppn_pt_divergent_loci = ppn_pt_divergent_loci[['chr','start','end','ref_allele','alt_allele']]
#ppn_pt_divergent_loci.head(5)

# %%
#ppn_pt_divergent_loci_BED = pybedtools.BedTool().from_dataframe(ppn_pt_divergent_loci)
#ppn_pt_divergent_loci_BED.head(5)

# %%
#TADs_ppn_pt_variant_intersection = TADs_BED.intersect(ppn_pt_divergent_loci_BED, c = True).to_dataframe(names=['chr','start','end','score','C3624_overlap','C3649_overlap','C3651_overlap','C40300_overlap','N_variants'])
#TADs_ppn_pt_variant_intersection['length'] = (TADs_ppn_pt_variant_intersection['end'] - TADs_ppn_pt_variant_intersection['start'])
#TADs_ppn_pt_variant_intersection['variants/bp'] = TADs_ppn_pt_variant_intersection['N_variants'] / TADs_ppn_pt_variant_intersection['length']
#TADs_ppn_pt_variant_intersection.head(5)

# %%
#TADs_ppn_pt_variant_intersection['length'].min()

# %%
#TADs_ppn_pt_variant_intersection['length'].mean()

# %%
#TADs_ppn_pt_variant_intersection['length'].max()

# %%
#TADs_ppn_pt_variant_intersection['variants/bp'].min()

# %%
#TADs_ppn_pt_variant_intersection['variants/bp'].mean()

# %%
#TADs_ppn_pt_variant_intersection['variants/bp'].max()

# %% [markdown]
# ## Individually Driven Windows <a class = 'anchor' id = 'individuallydrivenwindows'></a>

# %% [markdown]
# Some of these highly divergent windows appear to be driven by individuals that are different to all others, regardless of population. Let's try to write a function to identify windows where a single individual is very divergent. Start with a list of unique windows.

# %%
windows_list = comparisons['window'].unique().tolist()

# %% [markdown]
# Windows where a single individual is unique should be characterized by 55 comparisons that include that individual as ind1 or ind2 with a divergence score higher than all other comparisons. Therefore, we can sort each window by decreasing divergence and count the number of times each individual appears in the top 55 comparisons. If this count = 55, we have an individually driven window ('max'). We should also consider the mean value for those 55 comparisons because IDWs should have a relatively large value ('55_mean'). Further, there should be a considerable difference in the divergence score between the 55th and 56th comparisons ('55_56_diff'). Finally, the variance of the divergence score for the entire window should be large for IDWs ('window_variance').

# %%
def individual_driven_windows():
    
    counts_list = []
    means_list = []
    diffs_list = []
    variance_list = []
    
    for window in windows_list:
        subset = comparisons[comparisons['window'] == window].sort_values(by = 'divergence', ascending = False).reset_index()
        top_subset = subset[0:55]
        id1 = top_subset.groupby(['ind1']).size().reset_index(name='N').rename(columns={'ind1': 'ind'})
        id2 = top_subset.groupby(['ind2']).size().reset_index(name='N').rename(columns={'ind2': 'ind'})
        id_total = pd.concat([id1, id2]).groupby(['ind']).sum().reset_index()
        window_dict = dict(zip(id_total.ind, id_total.N))
        counts_list.append(window_dict)
        
        subset_mean = subset['divergence'].iloc[0:55].mean()
        means_list.append(subset_mean)
        
        subset_diff = subset['divergence'].iloc[54] - subset['divergence'].iloc[55]
        diffs_list.append(subset_diff)
        
        variance = subset['divergence'].var()
        variance_list.append(variance)
        
    df = pd.DataFrame.from_dict(counts_list)
    df['window'] = windows_list
    df['max'] = df[['Akwaya-Jean','Alfred','Alice','Andromeda','Athanga','Berta','Bihati','Blanquita','Bono','Bosco','Brigitta','Bwamble','Cindy-schwein','Cindy-troglodytes','Cindy-verus','Cleo','Clint','Coco-chimp','Damian','Desmond','Doris','Dzeeta','Frederike','Gamin','Hermien','Hortense','Ikuru','Jimmie','Julie-A959','Julie-LWC21','Kidongo','Koby','Kombote','Kosana','Koto','Kumbuka','Lara','Linda','Luky','Marlin','Maya','Mgbadolite','Mirinda','Nakuu','Natalie','Negrita','SeppToni','Taweh','Tibe','Tongo','Trixie','Ula','Vaillant','Vincent','Washu','Yogui']].max(axis=1)
    df['55_mean'] = means_list
    df['55_56_diff'] = diffs_list
    df['window_variance'] = variance_list
    df = df[['window','Akwaya-Jean','Alfred','Alice','Andromeda','Athanga','Berta','Bihati','Blanquita','Bono','Bosco','Brigitta','Bwamble','Cindy-schwein','Cindy-troglodytes','Cindy-verus','Cleo','Clint','Coco-chimp','Damian','Desmond','Doris','Dzeeta','Frederike','Gamin','Hermien','Hortense','Ikuru','Jimmie','Julie-A959','Julie-LWC21','Kidongo','Koby','Kombote','Kosana','Koto','Kumbuka','Lara','Linda','Luky','Marlin','Maya','Mgbadolite','Mirinda','Nakuu','Natalie','Negrita','SeppToni','Taweh','Tibe','Tongo','Trixie','Ula','Vaillant','Vincent','Washu','Yogui','max','55_mean','55_56_diff','window_variance']]
    return df

#individual_driven_windows_df = individual_driven_windows()

# %%
#individual_driven_windows_df

# %% [markdown]
# Save dataframe.

# %%
#individual_driven_windows_df.to_csv('dataframes/individual_driven_windows_dataframe.txt', sep = '\t', header = True, index = False)

# %% [markdown]
# Load the dataframe.

# %%
individual_driven_windows_df = pd.read_csv('dataframes/individual_driven_windows_dataframe.txt', sep = '\t', header = 0)
individual_driven_windows_df.head(10)

# %%
individual_driven_windows_df[(individual_driven_windows_df['max'] >= 55) & (individual_driven_windows_df['55_mean'] >= 0.3)]

# %%
len(individual_driven_windows_df[(individual_driven_windows_df['max'] >= 55) & (individual_driven_windows_df['55_mean'] >= 0.3)])

# %%
len(individual_driven_windows_df[(individual_driven_windows_df['max'] >= 55)])

# %% [markdown]
# Let's assess how many of these comparisons are 'highly divergent' or >= 0.3.

# %%
IDWs_list = [['chr11_20971520','Jimmie'],
        ['chr14_26738688','Luky'],
        ['chr1_72351744','Lara'],
        ['chr1_168820736','Berta'],
        ['chr1_169345024','Berta'],
        ['chr2A_76021760','Coco-chimp'],
        ['chr4_82837504','Frederike'],
        ['chr5_95420416','Desmond'],
        ['chr6_142606336','Bono'],
        ['chr7_105906176','Alice'],
        ['chr8_112197632','Athanga'],
        ['chr8_128974848','Damian']]

# %%
def retrieve_IDWs():
    df_rows = []
    for window, ind in IDWs_list:
        match = comparisons[(comparisons['divergence'] >= 0.3) & (comparisons['window'] == window) & (comparisons['ind1'] == ind) | (comparisons['divergence'] >= 0.3) & (comparisons['window'] == window) & (comparisons['ind2'] == ind)]
        df_rows.append(match)
    IDWs = pd.concat(df_rows)
    return IDWs

# %%
IDWs_df = retrieve_IDWs()

# %%
IDWs_df.groupby(['window'])['divergence'].count().to_frame('N')

# %%
41+44+55+55+52+55+55+49+46+55+55+55

# %%
617/5251

# %% [markdown]
# Now let's estimate how many IDWs make up the highly divergent windows per 0.02 divergence score bin. We only need the raw data to plot using ggplot so let's start with that. We need to create two levels (IDW and all) to distinguish the two.

# %%
high_divergence_dist = comparisons[comparisons['divergence'] >= 0.3]['divergence'].to_frame('divergence')
high_divergence_dist['type'] = 'all'
high_divergence_dist = high_divergence_dist[['type','divergence']]
high_divergence_dist.head()

# %% [markdown]
# Now the IDWs. We can use the function from before after updating our IDWs_list.

# %%
IDWs_list = [['chr11_20971520','Jimmie'],
        ['chr14_26738688','Luky'],
        ['chr1_72351744','Lara'],
        ['chr1_168820736','Berta'],
        ['chr1_169345024','Berta'],
        ['chr2A_76021760','Coco-chimp'],
        ['chr4_82837504','Frederike'],
        ['chr5_95420416','Desmond'],
        ['chr6_142606336','Bono'],
        ['chr7_105906176','Alice'],
        ['chr8_112197632','Athanga'],
        ['chr8_128974848','Damian']]

# %%
IDWs_df = retrieve_IDWs()

# %% [markdown]
# Check that everything made it during filtering.

# %%
len(IDWs_df)

# %%
IDWs_dist = IDWs_df[IDWs_df['divergence'] >= 0.3]['divergence'].to_frame('divergence')
IDWs_dist['type'] = 'IDW'
IDWs_dist = IDWs_dist[['type','divergence']]
IDWs_dist.head()

# %%
len(IDWs_dist)

# %% [markdown]
# Concat the two dataframes.

# %%
high_divergence_IDWs_dist = pd.concat([high_divergence_dist,IDWs_dist], axis = 0)
high_divergence_IDWs_dist

# %% [markdown]
# Save dataframe for plotting.

# %%
high_divergence_IDWs_dist.to_csv('dataframes/high_divergence_IDWs_dist.txt', sep = '\t', header = True, index = False)

# %% [markdown]
# ## IDW In Silico Mutagenesis <a class = 'anchor' id = 'idwindividuallydrivenwindows'></a>

# %% [markdown]
# Let's read in the ISM IDW data. Note that 'pos' in any in silico mutagenesis analysis is noted in 1-based coordinates.

# %%
in_silico_IDW = pd.read_csv('in_silico_mutagenesis/IDW_variants.txt', sep = '\t', header = 0)
in_silico_IDW.head(5)

# %%
len(in_silico_IDW)

# %% [markdown]
# Filter for variants with divergence score >= 0.01.

# %%
in_silico_IDW[in_silico_IDW['1-spearman'] >= 0.01]

# %% [markdown]
# Each of the IDWs has a variant private that that individual that induces a major change in chromatin contact compared to the chimpanzee reference. Do these fall within CREs or CTCF binding sites?

# %%
IDW_3d_modifying_variants = in_silico_IDW[in_silico_IDW['1-spearman'] >= 0.01]
IDW_3d_modifying_variants_BED = IDW_3d_modifying_variants[['chr','pos']]
IDW_3d_modifying_variants_BED = IDW_3d_modifying_variants_BED.rename(columns={'pos': 'end'})
IDW_3d_modifying_variants_BED['start'] = IDW_3d_modifying_variants_BED['end']-1
IDW_3d_modifying_variants_BED = IDW_3d_modifying_variants_BED[['chr','start','end']]
IDW_3d_modifying_variants_BED = pybedtools.BedTool().from_dataframe(IDW_3d_modifying_variants_BED).sort()
IDW_3d_modifying_variants_BED.head()

# %%
CTCF = pybedtools.BedTool('annotations/panTro6_CTCF.bed')
enhancers = pybedtools.BedTool('annotations/panTro6_enhancers.bed')
promoters = pybedtools.BedTool('annotations/panTro6_promoters.bed')

# %%
IDW_variants_CTCF_intersect = IDW_3d_modifying_variants_BED.intersect(CTCF, u = True)
IDW_variants_enhancers_intersect = IDW_3d_modifying_variants_BED.intersect(enhancers, u = True)
IDW_variants_promoters_intersect = IDW_3d_modifying_variants_BED.intersect(promoters, u = True)

# %%
len(IDW_variants_CTCF_intersect)

# %%
IDW_variants_CTCF_intersect.head()

# %%
len(IDW_variants_enhancers_intersect)

# %%
len(IDW_variants_promoters_intersect)

# %% [markdown]
# Now let's check these variants. How divergent are the predictions with the 3d modifying variant compared to the individual with the IDW? Let's create and export a dataframe.

# %%
IDW_3d_modifying_variants = IDW_3d_modifying_variants[['chr','pos','ref','alt','window']]
IDW_3d_modifying_variants['individual'] = ['Lara','Berta','Berta','Jimmie','Luky','Coco-chimp','Frederike','Desmond','Bono','Alice','Athanga','Damian']
IDW_3d_modifying_variants.head(12)

# %%
IDW_3d_modifying_variants.to_csv('IDWs/IDW_3d_modifying_variants.txt', sep = '\t', header = False, index = False)

# %% [markdown]
# Run the IDW_3d_modifying_variant_prediction_and_comparison script and read in the results.

# %% [markdown]
# ## Compare Cell Types <a class = 'anchor' id = 'comparecelltypes'></a>

# %% [markdown]
# Are the cell type specific predictions variable across cell types for the reference sequence?

# %%
#reference_comparisons_header = ['cell_type_1','cell_type_2','chr','window_start','mse','spearman']
#reference_comparisons = pd.read_csv('comparisons/reference/all_reference_comparisons.txt', sep = '\t', names = reference_comparisons_header)
#reference_comparisons['window'] = reference_comparisons['chr'] + '_' + reference_comparisons['window_start'].astype(str)
#reference_comparisons = reference_comparisons[['cell_type_1','cell_type_2','chr','window_start','window','mse','spearman']]
#reference_comparisons.head()

# %%
#excluded_header = ['chr','start','end','N_missing']
#excluded = pd.read_csv('metadata/panTro6_excluded_windows.bed', sep = '\t', header = None, names = excluded_header)
#excluded['window'] = excluded['chr'] + '_' + excluded['start'].astype(str)
#excluded_windows = excluded['window'].tolist()

# %%
#reference_comparisons = reference_comparisons[~(reference_comparisons['window'].isin(excluded_windows))]
#reference_comparisons.head()

# %% [markdown]
# Let's save this dataframe for plotting.

# %%
#reference_comparisons.to_csv('dataframes/reference_cell_type_comparisons.txt', sep = '\t', header = True, index = False)

# %%
#len(reference_comparisons)

# %%
#reference_comparisons.groupby(['cell_type_1','cell_type_2'])['spearman'].mean().to_frame('Mean Rho')

# %% [markdown]
# Most of the maps for the different cell types are nearly identical when predicting the reference sequence.

# %% [markdown]
# Let's compare sample predictions from HFF to GM12878. Load the data and run a correlation.

# %%
#GM12878_comparisons = pd.read_csv('dataframes/GM12878_comparisons.txt', sep = '\t', header = 0)
#GM12878_comparisons.head(5)

# %%
#rho, p = spearmanr(comparisons['divergence'], GM12878_comparisons['divergence'])
#print(rho, p)

# %%
#HFF_divergence = comparisons[['ind1','ind2','window','divergence']].copy()
#HFF_divergence['cell_type'] = 'HFF'
#GM12878_divergence = GM12878_comparisons[['ind1','ind2','window','divergence']].copy()
#GM12878_divergence['cell_type'] = 'GM12878'
#cell_type_correlation = HFF_divergence.merge(GM12878_divergence, how = 'outer', on = ['ind1','ind2','window'])
#cell_type_correlation = cell_type_correlation[['ind1','ind2','window','cell_type_x','divergence_x','cell_type_y','divergence_y']]
#cell_type_correlation.head()

# %%
#len(cell_type_correlation)

# %% [markdown]
# Save this dataframe for plotting.

# %%
#cell_type_correlation.to_csv('dataframes/cell_type_correlation.txt', sep = '\t', header = True, index = False)

# %% [markdown]
# After plotting, there is a noticeable cluster of windows with low HFF divergence but high GM12878 divergence. Let's take a look.

# %%
#high_GM12878_windows = cell_type_correlation[(cell_type_correlation['divergence_x'] < 0.075) & (cell_type_correlation['divergence_y'] > 0.1)]
#high_GM12878_windows.head(200)

# %%
#len(high_GM12878_windows)

# %%
#high_GM12878_windows.groupby('window')['divergence_y'].count().to_frame()

# %% [markdown]
# Two windows stick out in particular. Are these maps very different in the reference sequence?

# %%
#reference_comparisons[(reference_comparisons['cell_type_1'] == 'GM12878') & (reference_comparisons['cell_type_2'] == 'HFF') & (reference_comparisons['window'] == 'chr4_94371840')]

# %%
#reference_comparisons[(reference_comparisons['cell_type_1'] == 'GM12878') & (reference_comparisons['cell_type_2'] == 'HFF') & (reference_comparisons['window'] == 'chr11_23068672')]

# %% [markdown]
# double and quadruple windows

# %% [markdown]
# 'chr2A_21495808','Bono'], ['chr2A_21495808','Dzeeta'], ['chr2A_21495808','Kombote'], ['chr2A_21495808','Kumbuka'], ['chr2A_22020096','Bono'], ['chr2A_22020096','Dzeeta'], ['chr2A_22020096','Kombote'], ['chr2A_22020096','Kumbuka'], ['chr10_52428800','Julie-A959'], ['chr10_52428800','Vaillant']] chr13_49807360, lara, ikuru
