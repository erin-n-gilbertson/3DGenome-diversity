# %%
import pandas as pd

# %%
txt_file = open("/wynton/group/capra/projects/modern_human_3Dgenome/data/reference/lists/runAkitaLists/listofIndivs.txt", "r")

indivs = txt_file.read().split('\n')
print(indivs)
# Out:
# ['AFR_ACB_female_HG01880', 'AFR_ACB_female_HG01883', 'AFR_ACB_female_HG01886', 'AFR_ACB_female_HG01889', 'AFR_ACB_female_HG01894', 'AFR_ACB_female_HG01896', 'AFR_ACB_female_HG01915', 'AFR_ACB_female_HG01956', 'AFR_ACB_female_HG01958', 'AFR_ACB_female_HG01985', 'AFR_ACB_female_HG01989', 'AFR_ACB_female_HG02010', 'AFR_ACB_female_HG02012', 'AFR_ACB_female_HG02052', 'AFR_ACB_female_HG02054', 'AFR_ACB_female_HG02095', 'AFR_ACB_female_HG02108', 'AFR_ACB_female_HG02111', 'AFR_ACB_female_HG02144', 'AFR_ACB_female_HG02256', 'AFR_ACB_female_HG02282', 'AFR_ACB_female_HG02308', 'AFR_ACB_female_HG02309', 'AFR_ACB_female_HG02315', 'AFR_ACB_female_HG02318', 'AFR_ACB_female_HG02322', 'AFR_ACB_female_HG02325', 'AFR_ACB_female_HG02337', 'AFR_ACB_female_HG02339', 'AFR_ACB_female_HG02419', 'AFR_ACB_female_HG02427', 'AFR_ACB_female_HG02450', 'AFR_ACB_female_HG02471', 'AFR_ACB_female_HG02476', 'AFR_ACB_female_HG02477', 'AFR_ACB_female_HG02479', 'AFR_ACB_female_HG02485', 'AFR_ACB_female_HG02497', 'AFR_ACB_
# ...

# %%
for i in indivs:
    indiv1=i
    
    GAGPa='GAGP_ancestral'
    # !echo "$indiv1" "$GAGPa" >> /wynton/group/capra/projects/modern_human_3Dgenome/data/reference/lists/listOfPairwiseComps_ancestral.txt
    
    ENSEMBLa='homo_sapiens_ancestor_ENSEMBL'
    # !echo "$indiv1" "$ENSEMBLa" >> /wynton/group/capra/projects/modern_human_3Dgenome/data/reference/lists/listOfPairwiseComps_ancestral.txt
