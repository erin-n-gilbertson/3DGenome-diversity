# %% [markdown]
# # Setup

# %%
# !source activate /home/gilbee3/anaconda3/envs/akita

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True) # Seaborn desaturates matplotlib colors (this is useful if you use both seaborn and basic matplot lib and want colors to be consistent)
import scipy.stats as stats
sns.set(palette='husl', context = 'poster', style='white')
import os
import scikit_posthocs as sp
import pybedtools

# %%
BASE_PATH = "/".join(os.getcwd().split("/")[:-2]) # base directory level

BIN_PATH = os.path.join(BASE_PATH, "bin")  # where my scripts live
DATA_PATH = os.path.join(BASE_PATH, "data")  # where I dump new data.
RESULTS_PATH = os.path.join(BASE_PATH, "results")  # where I analyze results

SRC_PATH = os.path.join(BASE_PATH, "src")  # where any packages needed to run analyses live. I haven't started structuring things this way yet. 

COMP_PATH = os.path.join(DATA_PATH,"pairwise/hsmrca")
#COMP_PATH = os.path.join(DATA_PATH,"pairwise/reference")

# %%
COMP_PATH
# Out:
# '/wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/hsmrca'

# %% [markdown]
# ## Formatting data for analysis
# The results of this are written out to files that can be loaded for any downstream analysis to make starting up faster each time.

# %%
COMP_PATH = os.path.join(DATA_PATH,"pairwise/hsmrca")
anc_list = os.path.join(DATA_PATH, "reference/lists/listOfPairwiseComps_hsmrca.txt")
anc_g, anc_m, anc_s = comp_data_setup(anc_list, 'hsmrca_ancestral')
anc_g = anc_g[anc_g.genome_avg_spearman!='']

# %%
write_comp_dfs('anc', anc_g, anc_m, anc_s)

# %% [markdown]
# ## Functions

# %%
def write_comp_dfs(base, g, m, s):
    g.to_csv('/wynton/group/capra/projects/modern_human_3Dgenome/results/comp_tables/%s_genomewide_averages.csv' % base)
    m.to_csv('/wynton/group/capra/projects/modern_human_3Dgenome/results/comp_tables/%s_window_mse.csv' % base)
    s.to_csv('/wynton/group/capra/projects/modern_human_3Dgenome/results/comp_tables/%s_window_spearman.csv' % base)
    return

# %%
def comp_data_setup(list_file, base):
    comp_list=pd.read_table(list_file, sep=' ', names=['1KG','ancestor'])
    if base != 'hg38_reference':
        base_df = comp_list[comp_list.ancestor==base].set_index('1KG')
    else:
        base_df = comp_list.set_index('1KG')
    
    comp_dict = {}
    print('first for')
    for row in base_df.index:
        ind = str(base_df.loc[row].name)
        filename = '3dcomp_%s_vs_%s.txt' % (ind,base)
        if os.path.exists('%s/%s' % (COMP_PATH,filename)):
            try:
                df = pd.read_table('%s/%s' % (COMP_PATH,filename))
                df = df[df.chr != 'chrX']
                comp_dict[ind] = df
            except:
                continue     
    print('done')
    
    indivs = list(comp_dict.keys())
    df = comp_dict[list(comp_dict.keys())[0]].set_index(['chr','windowStartPos'])
    windows = df.index
    ### Window by window
    mse = pd.DataFrame(index = windows, columns = indivs)
    spear = pd.DataFrame(index = windows, columns = indivs)
    
    ### Genome wide averages        
    base_df['genome_avg_mse']=''
    base_df['genome_avg_spearman']=''
    print('second for')
    for ind in comp_dict.keys():
        df = comp_dict[ind]

        avg_mse =float(np.mean(df['mse']))
        avg_spearman = float(np.mean(df['spearman']))

        base_df.genome_avg_mse.loc[ind]=avg_mse
        base_df.genome_avg_spearman.loc[ind]=avg_spearman
        
        
        df = comp_dict[ind]
        df = df.set_index(['chr','windowStartPos'])
        mse[ind]=df['mse']
        spear[ind]=df['spearman']
    print('done')  
    

    
    base_df['temp'] = base_df.index
    new = base_df.temp.str.split("_", expand = True)
    base_df['super_pop'] = new[0]
    base_df['sub_pop'] = new[1]
    base_df['sex'] = new[2]
    base_df['id'] = new[3]
    
    genome_wide = base_df.drop(columns=['temp'])

    mse.columns = mse.columns.str.split('_', expand=True)
    spear.columns = spear.columns.str.split('_', expand=True)
    
    return genome_wide, mse, spear

# %%
def corr_plot(df):
    g = sns.lmplot(x='genome_avg_mse',y='divergence', hue='super_pop', data=df,scatter_kws={'s':2}, line_kws={'color': 'gray'},aspect=1.2)
    slope, intercept, r, p, se = stats.linregress(df['genome_avg_mse'].values, df['divergence'].values)
    _ = plt.title('r = %0.2f, r2 = %0.2f' % (r, r**2))

# %%
def per_window_hists(mse, spear, div):
    mse_flat = mse.to_numpy().flatten()
    spear_flat = spear.to_numpy().flatten()
    div_flat = div.to_numpy().flatten()
    
    plt.figure(figsize=(10,4))
    plt.hist(mse_flat, bins=100)
    plt.xlim(0,0.1)
    plt.xlabel('MSE (per window per individual)')

    plt.figure(figsize=(10,4))
    plt.hist(spear_flat, bins=100)
    plt.xlim(0.5,1)
    plt.xlabel('Spearman Correlation (per window per individual)')

    plt.figure(figsize=(10,4))
    plt.hist(div_flat, bins=100)
    plt.xlim(0, .5)
    plt.xlabel('3D Divergence (per window per individual)')

# %%
def all_indivs_genomeplot(df):
    windows = pd.DataFrame(df.mean(axis=1), columns=['mean_div'])
    
    chroms = ['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8'] # did this to split the plot into a top panel and bottom, but you could just put all chroms here for 1 linear plot

    fig = plt.figure(figsize=(25,5))
    x_labels = []
    x_labels_pos = []
    ax = fig.add_subplot(111)
    ax.set_facecolor('white')


    maxLoc = 0
    num = 0
    for chrm in chroms:
        num+=1
        windows['center_loc'] = (windows.index.get_level_values(1) + 2**20)/2 + maxLoc # center_loc is the midway point in the region
        _ = plt.plot( 'center_loc','mean_div',data = windows.loc[chrm], lw=1.5)
        maxLoc = windows.loc[chrm]['center_loc'].max() + 10 # max loc iteratively becomes larger with each chromosome to place everything on the same x-axis. Remove the + 10 if you don't want space between the chroms
        x_labels_pos.append(windows.loc[chrm]['center_loc'].mean()) # save the position for the xlabels
        if (num % 2) == 0: # alternate gray and white background
            _ = ax.axvspan(windows.loc[chrm]['center_loc'].min(), windows.loc[chrm]['center_loc'].max(), facecolor='lightgray')
    _ = ax.set_xticks(x_labels_pos)
    _ = ax.set_xticklabels(chroms)
    _ = ax.set_xlim(0,maxLoc)
    #_ = ax.set_ylim(0,1.5)
    maxLocOld = maxLoc
    plt.show()


    chroms = ['chr9','chr10','chr11','chr12','chr13','chr14','chr15','chr16','chr17','chr18','chr19','chr20','chr21','chr22']
    fig = plt.figure(figsize=(25,5))
    x_labels = []
    x_labels_pos = []
    ax = fig.add_subplot(111)
    ax.set_facecolor('white')


    maxLoc = 0
    num = 0
    for chrm in chroms:
        num+=1
        windows['center_loc'] = (windows.index.get_level_values(1) + 2**20)/2 + maxLoc # center_loc is the midway point in the region
        _ = plt.plot( 'center_loc','mean_div',data = windows.loc[chrm], lw=1.5)
        maxLoc = windows.loc[chrm]['center_loc'].max() + 10 # max loc iteratively becomes larger with each chromosome to place everything on the same x-axis. Remove the + 10 if you don't want space between the chroms
        x_labels_pos.append(windows.loc[chrm]['center_loc'].mean()) # save the position for the xlabels
        if (num % 2) == 0: # alternate gray and white background
            _ = ax.axvspan(windows.loc[chrm]['center_loc'].min(), windows.loc[chrm]['center_loc'].max(), facecolor='lightgray')
    _ = ax.set_xticks(x_labels_pos)
    _ = ax.set_xticklabels(chroms)
    _ = ax.set_xlim(0,maxLoc)
    #_ = ax.set_ylim(0,1.5)
    maxLocOld = maxLoc
    plt.show()

# %%
def one_chrm_pop_plot(df, chrm):
    
    afr_avg = df['AFR'].mean(axis=1)
    amr_avg = df['AMR'].mean(axis=1)
    eur_avg = df['EUR'].mean(axis=1)
    eas_avg = df['EAS'].mean(axis=1)
    sas_avg = df['SAS'].mean(axis=1)
    
    windows = pd.DataFrame([afr_avg, amr_avg, eur_avg, eas_avg, sas_avg]).transpose()
    windows.columns = ['AFR','AMR','EUR','EAS','SAS']
    
    windows['AVERAGE'] = windows.mean(axis=1)
    
    df = windows.loc[chrm]
    
    fig, ax = plt.subplots(figsize=[40,10])
    sns.lineplot(y=df.AFR, 
                 x=df.index, 
                label='AFR')
    sns.lineplot(y=df.AMR, 
                 x=df.index, 
                label='AMR')
    sns.lineplot(y=df.EUR, 
                 x=df.index, 
                label='EUR')
    sns.lineplot(y=df.EAS, 
                 x=df.index, 
                label='EAS')
    sns.lineplot(y=df.SAS, 
                 x=df.index, 
                label='SAS')

# %%
def genome_wide_plots_stats(df, stat):
        plt.figure(figsize=(10,8))
        sns.violinplot(x='super_pop', y=stat, data=df)
        plt.figure(figsize=(30,8))
        sns.boxplot(x='sub_pop', y=stat, data=df, showfliers = False, 
                    hue='super_pop', dodge=False)
        plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

        kruskal = stats.kruskal(df[df.super_pop=='AFR'][stat], 
                  df[df.super_pop=='AMR'][stat],
                  df[df.super_pop=='EUR'][stat],
                  df[df.super_pop=='EAS'][stat],
                  df[df.super_pop=='SAS'][stat])
        conover = sp.posthoc_conover(df, val_col=stat, group_col='super_pop', p_adjust = 'holm')
        
        print(kruskal)
        print(conover)

# %%
def std_genomeplot(df):
    windows = pd.DataFrame(df.std(axis=1), columns=['std_div'])
    chroms = ['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8'] # did this to split the plot into a top panel and bottom, but you could just put all chroms here for 1 linear plot

    fig = plt.figure(figsize=(25,5))
    x_labels = []
    x_labels_pos = []
    ax = fig.add_subplot(111)
    ax.set_facecolor('white')


    maxLoc = 0
    num = 0
    for chrm in chroms:
        num+=1
        windows['center_loc'] = (windows.index.get_level_values(1) + 2**20)/2 + maxLoc # center_loc is the midway point in the region
        _ = plt.plot( 'center_loc','std_div',data = windows.loc[chrm], lw=1.5)
        maxLoc = windows.loc[chrm]['center_loc'].max() + 10 # max loc iteratively becomes larger with each chromosome to place everything on the same x-axis. Remove the + 10 if you don't want space between the chroms
        x_labels_pos.append(windows.loc[chrm]['center_loc'].mean()) # save the position for the xlabels
        if (num % 2) == 0: # alternate gray and white background
            _ = ax.axvspan(windows.loc[chrm]['center_loc'].min(), windows.loc[chrm]['center_loc'].max(), facecolor='lightgray')
    _ = ax.set_xticks(x_labels_pos)
    _ = ax.set_xticklabels(chroms)
    _ = ax.set_xlim(0,maxLoc)
    #_ = ax.set_ylim(0,1.5)
    maxLocOld = maxLoc
    plt.show()


    chroms = ['chr9','chr10','chr11','chr12','chr13','chr14','chr15','chr16','chr17','chr18','chr19','chr20','chr21','chr22']
    fig = plt.figure(figsize=(25,5))
    x_labels = []
    x_labels_pos = []
    ax = fig.add_subplot(111)
    ax.set_facecolor('white')


    maxLoc = 0
    num = 0
    for chrm in chroms:
        num+=1
        windows['center_loc'] = (windows.index.get_level_values(1) + 2**20)/2 + maxLoc # center_loc is the midway point in the region
        _ = plt.plot( 'center_loc','std_div',data = windows.loc[chrm], lw=1.5)
        maxLoc = windows.loc[chrm]['center_loc'].max() + 10 # max loc iteratively becomes larger with each chromosome to place everything on the same x-axis. Remove the + 10 if you don't want space between the chroms
        x_labels_pos.append(windows.loc[chrm]['center_loc'].mean()) # save the position for the xlabels
        if (num % 2) == 0: # alternate gray and white background
            _ = ax.axvspan(windows.loc[chrm]['center_loc'].min(), windows.loc[chrm]['center_loc'].max(), facecolor='lightgray')
    _ = ax.set_xticks(x_labels_pos)
    _ = ax.set_xticklabels(chroms)
    _ = ax.set_xlim(0,maxLoc)
    #_ = ax.set_ylim(0,1.5)
    maxLocOld = maxLoc
    plt.show()

# %% [markdown]
# # Genome wide average

# %% [markdown]
# ## Setup

# %%
anc = pd.read_table('/wynton/group/capra/projects/modern_human_3Dgenome/results/comp_tables/anc_genomewide_averages.csv',
                    sep=',', index_col=0)
drops = anc[np.isnan(anc.genome_avg_mse)].index
anc = anc.drop(index=drops)

ref = pd.read_table('/wynton/group/capra/projects/modern_human_3Dgenome/results/comp_tables/ref_genomewide_averages.csv',
                    sep=',', index_col=0)
drops = ref[np.isnan(ref.genome_avg_mse)].index
ref = ref.drop(index=drops)

# %%
anc['divergence'] = 1-anc.genome_avg_spearman
ref['divergence'] = 1-ref.genome_avg_spearman

# %% [markdown]
# ## Correlations

# %%
ref.index

# %%
anc.index.unique()

# %%
corr_plot(anc)

# %%
corr_plot(ref)

# %% [markdown]
# ## Divergence

# %%
def plot_pop_divergence(df, ref):
    sup_order = df.groupby(by=["super_pop"])["divergence"].mean().sort_values().index
    sub_order = df.groupby(by=["sub_pop"])["divergence"].mean().sort_values().index
    
    sup_mapping = pd.DataFrame({
    'super': sup_order,
    })
    sup_mapping = sup_mapping.reset_index().set_index('super')

    sub_mapping = pd.DataFrame({
        'sub': sub_order,
    })
    sub_mapping = sub_mapping.reset_index().set_index('sub')
    
    df['super_rank'] = df['super_pop'].map(sup_mapping['index'])
    df['sub_rank'] = df['sub_pop'].map(sub_mapping['index'])
    
    my_order = df.sort_values(['super_rank','sub_rank'])
    
    my_order = my_order['sub_pop'].drop_duplicates().values
    
    amr_pal = sns.diverging_palette(50,230, s=82, l=58, n=10)[-4:]
    eur_pal = sns.diverging_palette(50,230, s=82, l=58, n=15)[:5]
    afr_pal = sns.diverging_palette(50,369, s=82, l=58, n=17)[-7:]
    sas_pal = sns.diverging_palette(190,369, s=82, l=58, n=12)[:5]
    eas_pal = sns.diverging_palette(110,105, s=75, l=65, n=10)[:5]
    
    if ref:
        my_pal = eur_pal + eas_pal + amr_pal + afr_pal
    else:
        my_pal = eur_pal + amr_pal + eas_pal + sas_pal + afr_pal
    sns.set(font_scale=4, context = 'poster', style='white')
    plt.figure(figsize=(100,30))
    sns.stripplot(x='sub_pop', y='divergence', data=df, dodge=False,s=20, 
                  palette=my_pal, 
                  order = my_order)
    plt.xlabel('\nPopulation', fontsize=100)
    plt.ylabel('Genome-Wide\n3D Divergence\n', fontsize=100)
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, fontsize=100)
    plt.tick_params(axis='both', which='major', labelsize=80)
    #plt.savefig('fig2.svg', format='svg')
    
    return

# %%
sup_order = ref.groupby(by=["super_pop"])["divergence"].mean().sort_values().index
sub_order = ref.groupby(by=["sub_pop"])["divergence"].mean().sort_values().index

# %%
sup_order

# %%
sub_order

# %%
plot_pop_divergence(ref, True)

# %%
plot_pop_divergence(anc, False)

# %% [markdown]
# # Window wise metrics

# %% [markdown]
# ### Distributions

# %%
sns.set(palette='husl', font_scale=1, context = 'poster', style='white')

# %%
anc_mse = pd.read_table('/wynton/group/capra/projects/modern_human_3Dgenome/results/comp_tables/anc_window_mse.csv'
                    , sep=',', header=[0,1,2,3], index_col=[0,1])
anc_spear = pd.read_table('/wynton/group/capra/projects/modern_human_3Dgenome/results/comp_tables/anc_window_spearman.csv'
                    , sep=',', header=[0,1,2,3], index_col=[0,1])
anc_div = 1-anc_spear

# ref_mse = pd.read_table('/wynton/group/capra/projects/modern_human_3Dgenome/results/comp_tables/ref_window_mse.csv'
#                     , sep=',', header=[0,1,2,3], index_col=[0,1])
# ref_spear = pd.read_table('/wynton/group/capra/projects/modern_human_3Dgenome/results/comp_tables/ref_window_spearman.csv'
#                     , sep=',', header=[0,1,2,3], index_col=[0,1])
# ref_div = 1-ref_spear

# %% [markdown]
# ## HSMRCA

# %%
per_window_hists(anc_mse, anc_spear, anc_div)

# %%
div_flat = anc_div.to_numpy().flatten()
plt.figure(figsize=(10,4))
plt.hist(div_flat, bins=500)
plt.xlim(0, .1)
plt.xlabel('3D Divergence (per window per individual)')

# %%
df = anc_div
chrm='chr20'

afr_avg = df['AFR'].std(axis=1)
amr_avg = df['AMR'].std(axis=1)
eur_avg = df['EUR'].std(axis=1)
eas_avg = df['EAS'].std(axis=1)
sas_avg = df['SAS'].std(axis=1)

windows = pd.DataFrame([afr_avg, amr_avg, eur_avg, eas_avg, sas_avg]).transpose()
windows.columns = ['AFR','AMR','EUR','EAS','SAS']

windows['AVERAGE'] = windows.mean(axis=1)

df = windows.loc[chrm]

fig, ax = plt.subplots(figsize=[15,5])
sns.lineplot(y=df.AFR, 
             x=df.index, 
            label='AFR')
sns.lineplot(y=df.EUR, 
             x=df.index, 
            label='EUR')
sns.lineplot(y=df.EAS, 
             x=df.index, 
            label='EAS')
sns.lineplot(y=df.SAS, 
             x=df.index, 
            label='SAS')
sns.lineplot(y=df.AMR, 
             x=df.index, 
            label='AMR')



plt.ylabel('3D Divergence\nStandard Deviation')
plt.xlabel('Chromosome 20 Position')

plt.savefig('chr20std.svg', format='svg')

# %% [markdown]
# # Enrichment?

# %%
genes = pybedtools.BedTool('/wynton/group/capra/projects/modern_human_3Dgenome/data/phenotype_enrichment_divergent_from_ancestral/data/grch38_gene_annotations.bed')

# %%
mean_df = pd.DataFrame()
mean_df['AFR'] = anc_div['AFR'].mean(axis=1)
mean_df['AMR'] = anc_div['AMR'].mean(axis=1)
mean_df['EUR'] = anc_div['EUR'].mean(axis=1)
mean_df['EAS'] = anc_div['EAS'].mean(axis=1)
mean_df['SAS'] = anc_div['SAS'].mean(axis=1)
mean_df['All'] = anc_div.mean(axis=1)

# %%
mean_df

# %%
top_10 = mean_df[mean_df.All >= (mean_df.All.quantile(.9))]

# %%
all_windows = pd.DataFrame(index=mean_df.index).reset_index()
all_windows.columns = ['chr','start']

# %%
all_windows['end'] = all_windows['start'] + 2**20

# %%
all_windows

# %%
windows = pd.DataFrame(index=top_10.index).reset_index()
windows.columns = ['chr','start']

# %%
all_bed = pybedtools.BedTool.from_dataframe(all_windows)

# %%
all_bed.saveas('/wynton/group/capra/projects/modern_human_3Dgenome/data/phenotype_enrichment_divergent_from_ancestral//data/all_windows.bed')

# %%
gene_df = genes.to_dataframe(disable_auto_names=True, header=None)

# %%
gene_df

# %%
windows

# %%
windows['end'] = windows['start'] + 2**20

# %%
windows['chr'] = windows['chr'].str.strip('chr')

# %%
windows

# %%
genes = pybedtools.BedTool('/wynton/group/capra/projects/archaic_splicing/data/annotations/grch38_gene_annotations.bed')

# %%
window_bed = pybedtools.BedTool.from_dataframe(windows)

# %%
window_bed.saveas('/wynton/group/capra/projects/modern_human_3Dgenome/data/phenotype_enrichment/data/diff_windows.bed')

# %%
gene_overlap = window_bed.intersect(genes, wao=True).to_dataframe(names=['window_chrm','start','end','gene_chr','gene_start','gene_end','gene_name','overlap'])

# %%
gene_overlap.gene_name.unique().shape

# %%
gene_overlap

# %%
gene_map = gene_overlap.drop(columns=['gene_chr','gene_start','gene_end','overlap'])

# %%
gene_map['chr'] = 'chr' + gene_map['window_chrm'].astype('str')

# %%
gene_map = gene_map.drop(columns=['window_chrm'])

# %%
a = gene_map['gene_name'].unique()

# %%
pd.DataFrame(a).to_csv('/wynton/group/capra/projects/modern_human_3Dgenome/data/phenotype_enrichment/data/diff_window_genes_observed.txt', header=None, index=False)

# %%
np.savetxt('diff_window_genes_observed.txt', a, delimiter='\n')

# %%
gene_map.set_index(['chr','start'])

# %%
pops_out[pops_out.AFR_out].index

# %%
popsgene_map

# %%
def get_gene():
    gene_list=[]

# %%
all_windows = pd.DataFrame(index=pop_diffs.index).reset_index()
all_windows.columns = ['chr','start']

all_windows['end'] = all_windows['start'] + 2**20

all_windows



all_bed = pybedtools.BedTool.from_dataframe(all_windows)

all_bed.saveas('/wynton/group/capra/projects/modern_human_3Dgenome/data/phenotype_enrichment/data/all_windows.bed')

gene_df = genes.to_dataframe(disable_auto_names=True, header=None)

shuffled = all_windows.sample(n=windows.shape[0], random_state=1)
shuffled_bed = pybedtools.BedTool.from_dataframe(shuffled)

genes = pybedtools.BedTool('/wynton/group/capra/projects/modern_human_3Dgenome/data/phenotype_enrichment/data/grch38_gene_annotations.bed')





intersect = all_bed.intersect(shuffled_bed, wo = True).intersect(genes, loj = True).to_dataframe(disable_auto_names=True, header=None)

intersect










windows = pd.DataFrame(index=pops_out.index).reset_index()
windows.columns = ['chr','start']

windows

windows['end'] = windows['start'] + 2**20

windows['chr'] = windows['chr'].str.strip('chr')

windows

genes = pybedtools.BedTool('/wynton/group/capra/projects/archaic_splicing/data/annotations/grch38_gene_annotations.bed')

window_bed = pybedtools.BedTool.from_dataframe(windows)

window_bed.saveas('/wynton/group/capra/projects/modern_human_3Dgenome/data/phenotype_enrichment/data/diff_windows.bed')

gene_overlap = window_bed.intersect(genes, wao=True).to_dataframe(names=['window_chrm','start','end','gene_chr','gene_start','gene_end','gene_name','overlap'])

gene_overlap.gene_name.unique().shape

gene_overlap

gene_map = gene_overlap.drop(columns=['gene_chr','gene_start','gene_end','overlap'])

gene_map['chr'] = 'chr' + gene_map['window_chrm'].astype('str')

gene_map = gene_map.drop(columns=['window_chrm'])

a = gene_map['gene_name'].unique()

pd.DataFrame(a).to_csv('/wynton/group/capra/projects/modern_human_3Dgenome/data/phenotype_enrichment/data/diff_window_genes_observed.txt', header=None, index=False)

np.savetxt('diff_window_genes_observed.txt', a, delimiter='\n')

gene_map.set_index(['chr','start'])

pops_out[pops_out.AFR_out].index

popsgene_map

def get_gene():
    gene_list=[]

# %% [markdown]
# # Sequence

# %%
list_file = os.path.join(DATA_PATH, "reference/lists/listOfPairwiseComps_hsmrca.txt")
base = 'hsmrca_ancestral'
COMP_PATH = os.path.join(DATA_PATH,"pairwise/sequence/1KGvsHSMRCA")

# %%
comp_list=pd.read_table(list_file, sep=' ', names=['1KG','ancestor'])
if base != 'hg38_reference':
    base_df = comp_list[comp_list.ancestor==base].set_index('1KG')
else:
    base_df = comp_list.set_index('1KG')

# %%
comp_dict_seq = {}
print('first for')
for row in base_df.index:
    ind = str(base_df.loc[row].name)
    filename = 'SeqComps_%s_vs_%s.txt' % (ind,base)
    if os.path.exists('%s/%s' % (COMP_PATH,filename)):
        try:
            df = pd.read_table('%s/%s' % (COMP_PATH,filename))
            df = df[df.chrm != 'chrX']
            comp_dict_seq[ind] = df
        except:
            print('broken')
            continue     
print('done')
# Out:
# first for
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01880_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01883_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01886_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01889_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01894_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01896_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01915_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01956_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01958_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01985_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG01989_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02010_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02012_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02052_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02054_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02095_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02108_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02111_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02144_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02256_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02282_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02308_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02309_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02315_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02318_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02322_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02325_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02337_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02339_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02419_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02427_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02450_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02471_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02476_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02477_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02479_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02485_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02497_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02502_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02505_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02508_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02511_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02537_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02546_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02549_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02555_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02558_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02577_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_female_HG02580_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG01879_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG01882_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG01885_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG01890_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG01912_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG01914_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG01986_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG01988_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG01990_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02009_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02013_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02014_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02051_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02053_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02107_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02143_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02255_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02281_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02283_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02284_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02307_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02314_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02317_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02323_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02330_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02332_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02334_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02343_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02420_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02429_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02433_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02439_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02442_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02445_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02449_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02455_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02470_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02481_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02484_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02489_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02496_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02501_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02536_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02541_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02545_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02554_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ACB_male_HG02557_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19625_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19701_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19704_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19707_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19712_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19713_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19819_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19835_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19901_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19909_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19913_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19914_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19917_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19921_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA19923_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20127_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20274_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20276_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20282_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20287_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20289_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20294_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20296_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20299_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20314_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20317_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20320_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20321_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20332_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20334_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20339_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20355_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20357_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20359_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_female_NA20412_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19700_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19703_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19711_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19818_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19834_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19900_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19904_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19908_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19916_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19920_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19922_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19982_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA19984_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20126_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20278_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20281_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20291_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20298_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20318_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20340_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20342_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20346_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20348_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20351_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20356_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ASW_male_NA20362_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG02922_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG02943_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG02946_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG02952_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG02970_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG02974_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG02976_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG02979_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03099_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03105_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03108_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03111_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03114_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03117_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03121_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03123_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03126_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03129_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03132_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03135_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03159_vs_hsmrca_ancestral.txt
# broken
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03162_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03168_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03189_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03195_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03198_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03267_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03270_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03279_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03291_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03294_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03297_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03300_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03303_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03342_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03351_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03354_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03363_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03366_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03369_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03372_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03499_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03511_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03514_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03517_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_female_HG03520_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02923_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02938_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02941_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02944_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02947_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02953_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02968_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02971_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02973_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02977_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG02981_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03100_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03103_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03109_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03112_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03115_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03118_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03120_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03124_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03127_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03130_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03133_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03136_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03139_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03157_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03160_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03163_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03166_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03169_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03172_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03175_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03190_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03193_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03196_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03199_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03202_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03265_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03268_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03271_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03280_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03295_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03298_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03301_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03304_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03311_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03313_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03343_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03352_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03367_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03370_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03515_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03518_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_ESN_male_HG03521_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02462_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02465_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02562_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02568_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02571_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02574_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02583_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02586_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02589_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02595_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02611_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02614_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02621_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02624_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02629_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02635_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02643_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02646_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02667_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02676_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02679_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02703_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02716_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02722_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02757_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02760_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02763_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02769_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02772_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02799_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02805_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02808_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02811_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02814_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02817_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02820_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02837_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02840_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02852_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02855_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02861_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02870_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02879_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02882_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02885_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02888_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02891_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02896_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG02983_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG03025_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG03028_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG03040_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG03046_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG03049_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG03241_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG03247_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG03259_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_female_HG03539_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02461_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02464_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02561_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02570_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02573_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02582_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02585_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02588_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02594_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02610_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02613_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02620_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02623_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02628_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02634_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02642_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02645_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02666_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02675_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02678_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02702_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02715_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02721_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02756_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02759_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AFR_GWD_male_HG02768_vs_hsmrca_ancestral.txt
# ...
# SeqComps_AMR_PEL_male_HG01950_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG01953_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG01961_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG01967_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG01970_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG01974_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG01977_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG01979_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG01982_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG01991_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02002_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02008_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02090_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02104_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02146_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02150_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02253_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02259_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02262_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02265_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02271_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02274_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02277_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02285_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02291_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02299_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PEL_male_HG02304_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG00551_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG00554_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG00638_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG00641_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG00732_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG00734_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG00737_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG00740_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG00743_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01049_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01052_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01055_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01058_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01061_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01064_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01067_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01070_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01073_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01077_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01080_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01083_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01086_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01089_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01092_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01095_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01098_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01102_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01105_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01108_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01111_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01162_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01168_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01171_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01174_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01177_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01183_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01188_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01191_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01198_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01205_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01242_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01248_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01303_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01312_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01323_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01326_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01393_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01396_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01403_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_female_HG01414_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG00553_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG00637_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG00640_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG00731_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG00736_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG00739_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG00742_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01047_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01048_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01051_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01054_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01060_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01063_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01066_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01069_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01072_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01075_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01079_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01082_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01085_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01088_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01094_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01097_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01101_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01104_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01107_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01110_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01161_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01164_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01167_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01170_vs_hsmrca_ancestral.txt
# /wynton/group/capra/projects/modern_human_3Dgenome/data/pairwise/sequence/1KGvsHSMRCA
# SeqComps_AMR_PUR_male_HG01173_vs_hsmrca_ancestral.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-eded6fa25e40> in <module>
#       4     ind = str(base_df.loc[row].name)
#       5     filename = 'SeqComps_%s_vs_%s.txt' % (ind,base)
# ----> 6     if os.path.exists('%s/%s' % (COMP_PATH,filename)):
#       7         try:
#       8             print(COMP_PATH)
#
# /usr/lib64/python3.6/genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:

# %%
comp_dict_seq['AFR_ACB_female_HG01880']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-08f223f4b17b> in <module>
# ----> 1 comp_dict_seq['AFR_ACB_female_HG01880']
#
# NameError: name 'comp_dict_seq' is not defined

# %%
indivs = list(comp_dict.keys())
df = comp_dict[list(comp_dict.keys())[0]].set_index(['chr','windowStartPos'])
windows = df.index
### Window by window
mse = pd.DataFrame(index = windows, columns = indivs)
spear = pd.DataFrame(index = windows, columns = indivs)

### Genome wide averages        
base_df['genome_avg_mse']=''
base_df['genome_avg_spearman']=''
print('second for')
for ind in comp_dict.keys():
    df = comp_dict[ind]

    avg_mse =float(np.mean(df['mse']))
    avg_spearman = float(np.mean(df['spearman']))

    base_df.genome_avg_mse.loc[ind]=avg_mse
    base_df.genome_avg_spearman.loc[ind]=avg_spearman


    df = comp_dict[ind]
    df = df.set_index(['chr','windowStartPos'])
    mse[ind]=df['mse']
    spear[ind]=df['spearman']
print('done')  



base_df['temp'] = base_df.index
new = base_df.temp.str.split("_", expand = True)
base_df['super_pop'] = new[0]
base_df['sub_pop'] = new[1]
base_df['sex'] = new[2]
base_df['id'] = new[3]

genome_wide = base_df.drop(columns=['temp'])

mse.columns = mse.columns.str.split('_', expand=True)
spear.columns = spear.columns.str.split('_', expand=True)

return genome_wide, mse, spear
